# %% [markdown]
# # MODEL 3 1-3-2 PYSURFER BRAINS
# ### Contains only fixed-before-conditional trials without intervening BLs
# ### Combines A & C trials into single regressor
# ### Accounts for last three noisy volumes in Lvl 1 analysis (FSL ROI -- ExtractROI)

# %%
import os
from os.path import join
import nibabel as nb
# %matplotlib inline
import matplotlib.pyplot as plt
from nipy.labs.viz_tools.activation_maps import plot_map
from surfer import Brain, io
from IPython.core.display import Image


#All Correct minus All Incorrect
grplvl_file = join("/home/data/madlab/data/mri/wmaze/grplvl/grplvl_MRthesis_randomise/model3_1-3-2/",
                   "all_corr_minus_all_incorr/output/corrected/",
                   "_contrast_all_corr_minus_all_incorr/oneSampT_tfce_corrp_tstat1.nii.gz")
grplvl_nii = nb.load(grplvl_file)

plot_map(grplvl_nii.get_data(), grplvl_nii.get_affine(), threshold = 0.95,
         draw_cross = False, vmin = 0.95, vmax = 1, cmap = 'autumn')

# %%
#If this cell fails, first load emu_env, THEN wmaze_env
#A bug in the PySurfer code requires this for project_volume_data() to run

reg_file = os.path.join(os.environ["FREESURFER_HOME"], "average/mni152.register.dat")
surf_data = io.project_volume_data(grplvl_file, "lh", reg_file)
# Out:
# mri_vol2surf --mov /home/data/madlab/data/mri/wmaze/grplvl/grplvl_MRthesis_randomise/model3_1-3-2/all_corr_minus_all_incorr/output/corrected/_contrast_all_corr_minus_all_incorr/oneSampT_tfce_corrp_tstat1.nii.gz --hemi lh --surf white --reg /home/applications/freesurfer/6.0/freesurfer/average/mni152.register.dat --projfrac-avg 0 1 0.1 --surf-fwhm 3 --o /scratch/R/pysurfer-v2s5vp1cg.mgz

# %%
#possible views using Brain()

#brain.show_view('lateral')
#brain.show_view('m')
#brain.show_view('rostral')
#brain.show_view('caudal')
#brain.show_view('ve')
#brain.show_view('frontal')
#brain.show_view('par')
#brain.show_view('dor')

# %% [markdown]
# ## Left Hemisphere

# %%
#Pial -- LH lateral view
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "lh", "pial")
brain.add_overlay(surf_data, min=.95, max=1)
brain.save_image("/home/arenf001/lh_lat.png")
Image("/home/arenf001/lh_lat.png")

# %%
#Inflated -- LH lateral view
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "lh", "inflated")
brain.add_overlay(surf_data, min=.95, max=1)
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")

# %%
#Pial -- LH medial view
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "lh", "pial")
brain.add_overlay(surf_data, min=.95, max=1)
brain.show_view("medial")
brain.save_image("/home/arenf001/lh_med.png")
Image("/home/arenf001/lh_med.png")

# %%
#Inflated -- LH medial view
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "lh", "inflated")
brain.add_overlay(surf_data, min=.95, max=1)
brain.show_view("medial")
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")

# %%
#Pial -- LH dorsal view

brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "lh", "pial")
brain.add_overlay(surf_data, min=.95, max=1)
brain.show_view('dor')
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")

# %%
#Inflated -- LH dorsal view

brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "lh", "inflated")
brain.add_overlay(surf_data, min=.95, max=1)
brain.show_view('dor')
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")

# %% [markdown]
# ## Right Hemisphere

# %%
#Pial -- RH Lateral view
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "rh", "pial")
surf_data = io.project_volume_data(grplvl_file, "rh", reg_file)
brain.add_overlay(surf_data, min=.95, max=1)
brain.save_image("/home/arenf001/rh_lat.png")
Image("/home/arenf001/rh_lat.png")
# Out:
# mri_vol2surf --mov /home/data/madlab/data/mri/wmaze/grplvl/grplvl_MRthesis_randomise/model3_1-3-2/all_corr_minus_all_incorr/output/corrected/_contrast_all_corr_minus_all_incorr/oneSampT_tfce_corrp_tstat1.nii.gz --hemi rh --surf white --reg /home/applications/freesurfer/6.0/freesurfer/average/mni152.register.dat --projfrac-avg 0 1 0.1 --surf-fwhm 3 --o /scratch/R/pysurfer-v2sMLCrFF.mgz

# %%
#Inflated -- RH lateral view
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "rh", "inflated")
surf_data = io.project_volume_data(grplvl_file, "rh", reg_file)
brain.add_overlay(surf_data, min=.95, max=1)
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")
# Out:
# mri_vol2surf --mov /home/data/madlab/data/mri/wmaze/grplvl/grplvl_MRthesis_randomise/model3_1-3-2/all_corr_minus_all_incorr/output/corrected/_contrast_all_corr_minus_all_incorr/oneSampT_tfce_corrp_tstat1.nii.gz --hemi rh --surf white --reg /home/applications/freesurfer/6.0/freesurfer/average/mni152.register.dat --projfrac-avg 0 1 0.1 --surf-fwhm 3 --o /scratch/R/pysurfer-v2suhgYCT.mgz

# %%
#Pial -- RH medial view
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "rh", "pial")
brain.add_overlay(surf_data, min=.95, max=1)
brain.show_view("medial")
brain.save_image("/home/arenf001/rh_med.png")
Image("/home/arenf001/rh_med.png")

# %%
# Inflated -- RH medial view
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "rh", "inflated")
brain.add_overlay(surf_data, min=.95, max=1)
brain.show_view("medial")
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")

# %%
#Pial -- RH dorsal view

brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "rh", "pial")
brain.add_overlay(surf_data, min=.99, max=1, hemi = 'rh')
brain.show_view('dor')
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")

# %%
#Inflated -- dorsal view

brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", "rh", "inflated")
brain.add_overlay(surf_data, min=.95, max=1, hemi = 'rh')
brain.show_view('dor')
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")

# %%
#Pial -- Medial and Lateral
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", 'split', "pial", views=['lat', 'med'])
surf_data2 = io.project_volume_data(grplvl_file, "lh", reg_file)
brain.add_overlay(surf_data, min=.95, max=1, hemi = 'rh')
brain.add_overlay(surf_data, min=.95, max=1, hemi = 'lh')
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")
# Out:
# mri_vol2surf --mov /home/data/madlab/data/mri/wmaze/grplvl/grplvl_MRthesis_randomise/model3_1-3-2/all_corr_minus_all_incorr/output/corrected/_contrast_all_corr_minus_all_incorr/oneSampT_tfce_corrp_tstat1.nii.gz --hemi lh --surf white --reg /home/applications/freesurfer/6.0/freesurfer/average/mni152.register.dat --projfrac-avg 0 1 0.1 --surf-fwhm 3 --o /scratch/R/pysurfer-v2syCRxTT.mgz

# %%
#Inflated -- medial and lateral view
brain = Brain("/home/data/madlab/surfaces/wmaze/fsaverage/", 'split', "inflated", views=['lat', 'med'])
surf_data2 = io.project_volume_data(grplvl_file, "lh", reg_file)
brain.add_overlay(surf_data, min=.95, max=1, hemi = 'rh')
brain.add_overlay(surf_data, min=.95, max=1, hemi = 'lh')
brain.save_image("/tmp/my3dbrain.png")
Image("/tmp/my3dbrain.png")
# Out:
# mri_vol2surf --mov /home/data/madlab/data/mri/wmaze/grplvl/grplvl_MRthesis_randomise/model3_1-3-2/all_corr_minus_all_incorr/output/corrected/_contrast_all_corr_minus_all_incorr/oneSampT_tfce_corrp_tstat1.nii.gz --hemi lh --surf white --reg /home/applications/freesurfer/6.0/freesurfer/average/mni152.register.dat --projfrac-avg 0 1 0.1 --surf-fwhm 3 --o /scratch/R/pysurfer-v2sHlZpTv.mgz
