# %% [markdown]
# # WMAZE Model 5 Version 2.3.2
# ## LSS Model
# ## Removes last 3 noisy volumes (FSL ROI)

# %%
# %matplotlib inline
import os
from os.path import join
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from glob import glob
from pylab import *

# %% [markdown]
# ## Subjects and sets are affected by different index slices
# ### Beginning and end 10 trials removed to avoid selecting a target trial without a complete surrounding window

# %%
import seaborn as sns
#sns.set_style("ticks")
sns.set_palette('muted')
import matplotlib.pyplot as plt


#subs = ['WMAZE_001']

subs = ['WMAZE_001', 'WMAZE_002', 'WMAZE_004', 'WMAZE_005', 'WMAZE_006',
        'WMAZE_007', 'WMAZE_008', 'WMAZE_009', 'WMAZE_010', 'WMAZE_012',
        'WMAZE_017', 'WMAZE_018', 'WMAZE_019', 'WMAZE_020', 'WMAZE_021',
        'WMAZE_022', 'WMAZE_023', 'WMAZE_024', 'WMAZE_026', 'WMAZE_027']


sets = ['set1', 'set2', 'set3']


for sub in subs:
    sub_dir = '/home/data/madlab/data/mri/wmaze/scanner_behav/{0}/'.format(sub)
    #new derivative files combining behavioral runs into set
    frst_deriv_files = glob(join(sub_dir, 'Bprime_pmode_set*.txt'))    
    frst_deriv_files.sort() 
    upper_95_files = glob(join(sub_dir, 'B_p95_set*.txt'))
    upper_95_files.sort()
    #new learning files combining behavioral runs into set
    learning_files = glob(join(sub_dir, 'B_pmode_set*')) 
    learning_files.sort()
    #print upper_95
    #print frst_deriv_files
    
    for i, curr_set in enumerate(sets): 
        #load learning curve and derivative files
        deriv_file = np.loadtxt(frst_deriv_files[i])
        learning_curve = np.loadtxt(learning_files[i]) 
        #print len(learning_curve)
        upper_95 = np.loadtxt(upper_95_files[i])
        #plt.plot(deriv_file) #before shaving
        alt_upper_95 = upper_95[10:-10]
        alt_deriv_file = deriv_file[10:-10]
        #plt.plot(learning_curve #)
        alt_learning_curve = learning_curve[10:-10] 
        #plt.plot(alt_deriv_file) #after shaving
        target_trial = np.argmax(deriv_file)
        #grabs the index of the largest derivative
        alt_target_trial = np.argmax(alt_deriv_file)+10
        #print target_trial
        #plt.plot(learning_curve)
        
        print len(deriv_file)
        print len(learning_curve)
        
        #print upper_95
        #print upper_95[:10]
        #print learning_curve
        #print learning_curve[-10:]
        #print sub, curr_set        
        #print "lc ", np.median(learning_curve[-10:])
        #print "p95", np.median(upper_95[:10])
        
        
        #pos_ind = np.where(alt_deriv_file > 0)
        #mean_pos = np.mean(alt_deriv_file[pos_ind])
        #std_pos = np.std(alt_deriv_file[pos_ind])
        #print sub, curr_set
        #print max(stats.zscore(alt_deriv_file[pos_ind]))
        #print ""
        
        '''
        if max(stats.zscore(alt_deriv_file[pos_ind])) < 2.5:
            print sub, curr_set
            print max(stats.zscore(alt_deriv_file[pos_ind]))
        '''
        

        '''
        if np.mean(alt_upper_95[:10]) > np.mean(alt_learning_curve[-10:]):
            print sub, curr_set
            print ""
        '''
        #print sub, curr_set
        #plt.plot(scnd_deriv)
        #plt.show()
        #print stats.describe(deriv_file)
        #print stats.zscore(deriv_file)[target_trial]
        #print ""
        
        '''
        if target_trial != alt_target_trial: 
            print 'Subject ' + sub
            print 'Stimulus ' + curr_set
            print target_trial, alt_target_trial
            print "Maximum Derivative"
            print max((deriv_file))
            print "Standard Deviation"
            print np.std(deriv_file)
            print "Range"
            print np.ptp(deriv_file)
            print "z-score"
            print stats.zscore(alt_deriv_file)[alt_target_trial]
            print ""
        '''
# Out:
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81

# %% [markdown]
# # Learning curve and derivative
# ### Visually demonstrates which potential target trials are affected by window-related index slicing

# %%
import seaborn as sns
#sns.set_style("ticks")
sns.set_palette('muted')
import matplotlib.pyplot as plt


#subs = ['WMAZE_001']

subs = ['WMAZE_001', 'WMAZE_002', 'WMAZE_004', 'WMAZE_005', 'WMAZE_006',
        'WMAZE_007', 'WMAZE_008', 'WMAZE_009', 'WMAZE_010', 'WMAZE_012',
        'WMAZE_017', 'WMAZE_018', 'WMAZE_019', 'WMAZE_020', 'WMAZE_021',
        'WMAZE_022', 'WMAZE_023', 'WMAZE_024', 'WMAZE_026', 'WMAZE_027']


sets = ['set1', 'set2', 'set3']


for sub in subs:
    sub_dir = '/home/data/madlab/data/mri/wmaze/scanner_behav/{0}/'.format(sub)
    #new derivative files combining behavioral runs into set
    frst_deriv_files = glob(join(sub_dir, 'Bprime_pmode_set*.txt'))    
    frst_deriv_files.sort()
    upper_95_files = glob(join(sub_dir, 'B_p95_set*.txt'))
    upper_95_files.sort()
    #new learning files combining behavioral runs into set
    learning_files = glob(join(sub_dir, 'B_pmode_set*')) 
    learning_files.sort()
    #print learning_curves
    #print frst_deriv_files
    
    for i, curr_set in enumerate(sets):  
        deriv_file = np.loadtxt(frst_deriv_files[i])
        learning_curve = np.loadtxt(learning_files[i])
        upper_95 =np.loadtxt(upper_95_files[i])
        print len(learning_curve)
        
        #plt.plot(deriv_file) #before shaving
        alt_deriv_file = deriv_file[10:-10]
        alt_learning_curve = learning_curve[10:-10]
        alt_upper_95 = upper_95[10:-10]
        #print alt_deriv_file 
        #plt.plot(alt_deriv_file) #after shaving
        target_trial = np.argmax(deriv_file)
        #grabs the index of the largest derivative
        alt_target_trial = np.argmax(alt_deriv_file)+10
        #print target_trial
        #plt.plot(learning_curve)
        
        x = range(len(learning_curve))
        x1 = range(len(alt_learning_curve))
        chance = np.ones(len(x)) * 0.5
        chance1 = np.ones(len(x1)) * 0.5
        

        fig, (ax0, ax1) = plt.subplots(ncols = 2, figsize=(11, 5), sharex = False, sharey = True)  
        ax0.plot(x, learning_curve, "#B266FF", linewidth = 3)
        ax0.plot(x, chance, 'b', linewidth = 1)
        ax0.fill_between(x, learning_curve, upper_95, color = "#B266FF", alpha = 0.2)
        ax0.plot(x, deriv_file, "#00CCCC", linewidth = 3)
        ax0.set_ylim(0,1)
        ax0.set_xlabel('Trials')
        ax0.set_ylabel('Probability of Correct Response')
        
        ax1.plot(x1, alt_learning_curve, "#B266FF", linewidth = 3)
        ax1.plot(x1, chance1, 'b', linewidth = 1)
        ax1.fill_between(x1, alt_learning_curve, alt_upper_95, color = "#B266FF", alpha = 0.2)
        ax1.plot(x1, alt_deriv_file, "#00CCCC", linewidth = 3)
        
        ax1.set_ylim(0,1)
        ax1.set_xlabel('Trials')
        ax1.set_ylabel('Probability of Correct Response')
        
        print 'Subject ' + sub
        print 'Stimulus ' + curr_set
        print "Maximum Derivative"
        print max((deriv_file))
        print "Mean"
        print np.mean(deriv_file)
        print "STD"
        print np.std(deriv_file)
        print "One-Sample t-test"
        print stats.ttest_1samp(deriv_file, 0)
        print ""
        print 'Target Trial'
        print target_trial
        print 'Alternative Target Trial'
        print alt_target_trial
        plt.show()
# Out:
# Subject WMAZE_001
# Stimulus set1
# Maximum Derivative
# 0.277
# Mean
# 0.0415432098765
# STD
# 0.098886491779
# One-Sample t-test
# Ttest_1sampResult(statistic=3.7575785980990464, pvalue=0.00032455385524802978)
#
# Target Trial
# 25
# Alternative Target Trial
# 25
# Subject WMAZE_001
# Stimulus set2
# Maximum Derivative
# 0.1715
# Mean
# 0.0306234567901
# STD
# 0.0665072413612
# One-Sample t-test
# Ttest_1sampResult(statistic=4.1184165625998954, pvalue=9.2273250333492463e-05)
#
# Target Trial
# 67
# Alternative Target Trial
# 67
# Subject WMAZE_001
# Stimulus set3
# Maximum Derivative
# 0.104
# Mean
# 0.0116543209877
# STD
# 0.0440036223239
# One-Sample t-test
# Ttest_1sampResult(statistic=2.3688826131786183, pvalue=0.020253193480268959)
#
# Target Trial
# 24
# Alternative Target Trial
# 24
# Subject WMAZE_002
# Stimulus set1
# Maximum Derivative
# 0.3325
# Mean
# 0.0523456790123
# STD
# 0.0930662395849
# One-Sample t-test
# Ttest_1sampResult(statistic=5.0307607623180219, pvalue=2.9395982891758002e-06)
#
# Target Trial
# 13
# Alternative Target Trial
# 13
# Subject WMAZE_002
# Stimulus set2
# Maximum Derivative
# 0.0595
# Mean
# 0.0116790123457
# STD
# 0.0248147841042
# One-Sample t-test
# Ttest_1sampResult(statistic=4.2095978599513222, pvalue=6.6465721150752891e-05)
#
# Target Trial
# 30
# Alternative Target Trial
# 30
# Subject WMAZE_002
# Stimulus set3
# Maximum Derivative
# 0.337
# Mean
# -0.0976481481481
# STD
# 0.263321242625
# One-Sample t-test
# Ttest_1sampResult(statistic=-3.316829207694528, pvalue=0.0013710819528573765)
#
# Target Trial
# 19
# Alternative Target Trial
# 19
# Subject WMAZE_004
# Stimulus set1
# Maximum Derivative
# 0.199
# Mean
# 0.0263641975309
# STD
# 0.0608805251933
# One-Sample t-test
# Ttest_1sampResult(statistic=3.8733002163868226, pvalue=0.00021841331545214955)
#
# Target Trial
# 31
# Alternative Target Trial
# 31
# Subject WMAZE_004
# Stimulus set2
# Maximum Derivative
# 0.16
# Mean
# 0.0141172839506
# STD
# 0.06106403599
# One-Sample t-test
# Ttest_1sampResult(statistic=2.0678100331536875, pvalue=0.04188991777728001)
#
# Target Trial
# 4
# Alternative Target Trial
# 11
# Subject WMAZE_004
# Stimulus set3
# Maximum Derivative
# 0.471
# Mean
# 0.0401358024691
# STD
# 0.117785403641
# One-Sample t-test
# Ttest_1sampResult(statistic=3.0477930160632245, pvalue=0.003123441924287255)
#
# Target Trial
# 7
# Alternative Target Trial
# 12
# Subject WMAZE_005
# Stimulus set1
# Maximum Derivative
# 0.5785
# Mean
# 0.010537037037
# STD
# 0.181870218579
# One-Sample t-test
# Ttest_1sampResult(statistic=0.51820537260730204, pvalue=0.60574526239746485)
#
# Target Trial
# 51
# Alternative Target Trial
# 51
# Subject WMAZE_005
# Stimulus set2
# Maximum Derivative
# 0.4385
# Mean
# 0.0378209876543
# STD
# 0.104304170242
# One-Sample t-test
# Ttest_1sampResult(statistic=3.2432183363316236, pvalue=0.0017250756474277555)
#
# Target Trial
# 10
# Alternative Target Trial
# 10
# Subject WMAZE_005
# Stimulus set3
# Maximum Derivative
# 0.277
# Mean
# 0.031012345679
# STD
# 0.0747096013839
# One-Sample t-test
# Ttest_1sampResult(statistic=3.7128139781471958, pvalue=0.00037756654891773746)
#
# Target Trial
# 4
# Alternative Target Trial
# 25
# Subject WMAZE_006
# Stimulus set1
# Maximum Derivative
# 0.095
# Mean
# 0.0167407407407
# STD
# 0.0410754433195
# One-Sample t-test
# Ttest_1sampResult(statistic=3.6453346588422653, pvalue=0.00047331234859188928)
#
# Target Trial
# 77
# Alternative Target Trial
# 15
# Subject WMAZE_006
# Stimulus set2
# Maximum Derivative
# 0.3695
# Mean
# 0.016549382716
# STD
# 0.143875259006
# One-Sample t-test
# Ttest_1sampResult(statistic=1.0288230233467992, pvalue=0.30666343785323558)
#
# Target Trial
# 36
# Alternative Target Trial
# 36
# Subject WMAZE_006
# Stimulus set3
# Maximum Derivative
# 0.173
# Mean
# 0.00866666666667
# STD
# 0.0606566943371
# One-Sample t-test
# Ttest_1sampResult(statistic=1.2779632003884756, pvalue=0.20495815168364762)
#
# Target Trial
# 17
# Alternative Target Trial
# 17
# Subject WMAZE_007
# Stimulus set1
# Maximum Derivative
# 0.246
# Mean
# 0.0525740740741
# STD
# 0.08130012646
# One-Sample t-test
# Ttest_1sampResult(statistic=5.7839616543060783, pvalue=1.3587073230272597e-07)
#
# Target Trial
# 45
# Alternative Target Trial
# 45
# Subject WMAZE_007
# Stimulus set2
# Maximum Derivative
# 0.1655
# Mean
# 0.0192098765432
# STD
# 0.0794732218352
# One-Sample t-test
# Ttest_1sampResult(statistic=2.161965441846363, pvalue=0.033609145303461221)
#
# Target Trial
# 41
# Alternative Target Trial
# 41
# Subject WMAZE_007
# Stimulus set3
# Maximum Derivative
# 0.1545
# Mean
# 0.0492901234568
# STD
# 0.0453502735368
# One-Sample t-test
# Ttest_1sampResult(statistic=9.721314388927583, pvalue=3.3824246147067076e-15)
#
# Target Trial
# 41
# Alternative Target Trial
# 41
# Subject WMAZE_008
# Stimulus set1
# Maximum Derivative
# 0.3205
# Mean
# 0.0437777777778
# STD
# 0.124051935559
# One-Sample t-test
# Ttest_1sampResult(statistic=3.1564227216129979, pvalue=0.0022520812965260623)
#
# Target Trial
# 5
# Alternative Target Trial
# 34
# Subject WMAZE_008
# Stimulus set2
# Maximum Derivative
# 0.155
# Mean
# 0.0274012345679
# STD
# 0.0389184347884
# One-Sample t-test
# Ttest_1sampResult(statistic=6.2973779386980278, pvalue=1.5304439536264781e-08)
#
# Target Trial
# 16
# Alternative Target Trial
# 16
# Subject WMAZE_008
# Stimulus set3
# Maximum Derivative
# 0.143
# Mean
# 0.044475308642
# STD
# 0.0399486476876
# One-Sample t-test
# Ttest_1sampResult(statistic=9.9577652011179989, pvalue=1.1683081378159196e-15)
#
# Target Trial
# 28
# Alternative Target Trial
# 28
# Subject WMAZE_009
# Stimulus set1
# Maximum Derivative
# 0.105
# Mean
# 0.00901234567901
# STD
# 0.0433654421859
# One-Sample t-test
# Ttest_1sampResult(statistic=1.8588273573787828, pvalue=0.06672904097952842)
#
# Target Trial
# 77
# Alternative Target Trial
# 42
# Subject WMAZE_009
# Stimulus set2
# Maximum Derivative
# 0.1495
# Mean
# -0.019962962963
# STD
# 0.0824569389221
# One-Sample t-test
# Ttest_1sampResult(statistic=-2.1654232039662404, pvalue=0.033334310261702693)
#
# Target Trial
# 59
# Alternative Target Trial
# 59
# Subject WMAZE_009
# Stimulus set3
# Maximum Derivative
# 0.0845
# Mean
# 0.0189012345679
# STD
# 0.0339222440362
# One-Sample t-test
# Ttest_1sampResult(statistic=4.983685077838623, pvalue=3.5405431995916224e-06)
#
# Target Trial
# 18
# Alternative Target Trial
# 18
# Subject WMAZE_010
# Stimulus set1
# Maximum Derivative
# 0.188
# Mean
# 0.0464259259259
# STD
# 0.0694452493781
# One-Sample t-test
# Ttest_1sampResult(statistic=5.9794746058785728, pvalue=5.9584633204007448e-08)
#
# Target Trial
# 45
# Alternative Target Trial
# 45
# Subject WMAZE_010
# Stimulus set2
# Maximum Derivative
# 0.247
# Mean
# 0.0116728395062
# STD
# 0.092185774608
# One-Sample t-test
# Ttest_1sampResult(statistic=1.1325505583578215, pvalue=0.26078611678673125)
#
# Target Trial
# 40
# Alternative Target Trial
# 40
# Subject WMAZE_010
# Stimulus set3
# Maximum Derivative
# 0.1125
# Mean
# -0.021037037037
# STD
# 0.0565215886744
# One-Sample t-test
# Ttest_1sampResult(statistic=-3.3290108054778003, pvalue=0.001319535358112314)
#
# Target Trial
# 59
# Alternative Target Trial
# 59
# Subject WMAZE_012
# Stimulus set1
# Maximum Derivative
# 0.1565
# Mean
# 0.0374691358025
# STD
# 0.0713745271191
# One-Sample t-test
# Ttest_1sampResult(statistic=4.6954306021633556, pvalue=1.0860587120849364e-05)
#
# Target Trial
# 39
# Alternative Target Trial
# 39
# Subject WMAZE_012
# Stimulus set2
# Maximum Derivative
# 0.1045
# Mean
# 0.0092962962963
# STD
# 0.0351282287544
# One-Sample t-test
# Ttest_1sampResult(statistic=2.3670024017274378, pvalue=0.020349416156550549)
#
# Target Trial
# 6
# Alternative Target Trial
# 20
# Subject WMAZE_012
# Stimulus set3
# Maximum Derivative
# 0.2355
# Mean
# 0.0461481481481
# STD
# 0.0724902907268
# One-Sample t-test
# Ttest_1sampResult(statistic=5.6940257935442258, pvalue=1.978681198410001e-07)
#
# Target Trial
# 7
# Alternative Target Trial
# 22
# Subject WMAZE_017
# Stimulus set1
# Maximum Derivative
# 0.178
# Mean
# 0.0364567901235
# STD
# 0.0624012403689
# One-Sample t-test
# Ttest_1sampResult(statistic=5.2255282411445583, pvalue=1.3504600170856026e-06)
#
# Target Trial
# 31
# Alternative Target Trial
# 31
# Subject WMAZE_017
# Stimulus set2
# Maximum Derivative
# 0.123
# Mean
# 0.00327160493827
# STD
# 0.0542190373258
# One-Sample t-test
# Ttest_1sampResult(statistic=0.53970202337175976, pvalue=0.59090165229272351)
#
# Target Trial
# 10
# Alternative Target Trial
# 10
# Subject WMAZE_017
# Stimulus set3
# Maximum Derivative
# 0.4475
# Mean
# 0.0448765432099
# STD
# 0.119055141568
# One-Sample t-test
# Ttest_1sampResult(statistic=3.3714462018540212, pvalue=0.0011538450275884872)
#
# Target Trial
# 10
# Alternative Target Trial
# 10
# Subject WMAZE_018
# Stimulus set1
# Maximum Derivative
# 0.1375
# Mean
# 0.0378888888889
# STD
# 0.0447394376803
# One-Sample t-test
# Ttest_1sampResult(statistic=7.5747157801022338, pvalue=5.4783584872874055e-11)
#
# Target Trial
# 31
# Alternative Target Trial
# 31
# Subject WMAZE_018
# Stimulus set2
# Maximum Derivative
# 0.1565
# Mean
# 0.00148148148148
# STD
# 0.0514117033107
# One-Sample t-test
# Ttest_1sampResult(statistic=0.25773845927471967, pvalue=0.79727060183522591)
#
# Target Trial
# 74
# Alternative Target Trial
# 14
# Subject WMAZE_018
# Stimulus set3
# Maximum Derivative
# 0.203
# Mean
# 0.00200617283951
# STD
# 0.0947415748828
# One-Sample t-test
# Ttest_1sampResult(statistic=0.18939684501962487, pvalue=0.85026149978643228)
#
# Target Trial
# 75
# Alternative Target Trial
# 22
# Subject WMAZE_019
# Stimulus set1
# Maximum Derivative
# 0.1395
# Mean
# 0.0200987654321
# STD
# 0.0463042421165
# One-Sample t-test
# Ttest_1sampResult(statistic=3.8823402535722455, pvalue=0.00021169644210381248)
#
# Target Trial
# 53
# Alternative Target Trial
# 53
# Subject WMAZE_019
# Stimulus set2
# Maximum Derivative
# 0.38
# Mean
# 0.0669938271605
# STD
# 0.108743880027
# One-Sample t-test
# Ttest_1sampResult(statistic=5.5102963611825739, pvalue=4.2352195896299571e-07)
#
# Target Trial
# 4
# Alternative Target Trial
# 22
# Subject WMAZE_019
# Stimulus set3
# Maximum Derivative
# 0.1045
# Mean
# 0.0110864197531
# STD
# 0.0415654169912
# One-Sample t-test
# Ttest_1sampResult(statistic=2.3856359434821437, pvalue=0.019413516888371191)
#
# Target Trial
# 63
# Alternative Target Trial
# 63
# Subject WMAZE_020
# Stimulus set1
# Maximum Derivative
# 0.2245
# Mean
# 0.0414259259259
# STD
# 0.0699514872066
# One-Sample t-test
# Ttest_1sampResult(statistic=5.2968816018258762, pvalue=1.0123675996793091e-06)
#
# Target Trial
# 8
# Alternative Target Trial
# 35
# Subject WMAZE_020
# Stimulus set2
# Maximum Derivative
# 0.4295
# Mean
# 0.0213827160494
# STD
# 0.111107368593
# One-Sample t-test
# Ttest_1sampResult(statistic=1.7213334177784705, pvalue=0.089055461511951262)
#
# Target Trial
# 8
# Alternative Target Trial
# 10
# Subject WMAZE_020
# Stimulus set3
# Maximum Derivative
# 0.1675
# Mean
# 0.0242222222222
# STD
# 0.0382411129029
# One-Sample t-test
# Ttest_1sampResult(statistic=5.6653723015411863, pvalue=2.2294049449143115e-07)
#
# Target Trial
# 10
# Alternative Target Trial
# 10
# Subject WMAZE_021
# Stimulus set1
# Maximum Derivative
# 0.1755
# Mean
# 0.0322098765432
# STD
# 0.0616743670967
# One-Sample t-test
# Ttest_1sampResult(statistic=4.6712095729884737, pvalue=1.1915528952850876e-05)
#
# Target Trial
# 36
# Alternative Target Trial
# 36
# Subject WMAZE_021
# Stimulus set2
# Maximum Derivative
# 0.096
# Mean
# 0.0161975308642
# STD
# 0.037238527027
# One-Sample t-test
# Ttest_1sampResult(statistic=3.890463234893355, pvalue=0.00020582989455469021)
#
# Target Trial
# 61
# Alternative Target Trial
# 61
# Subject WMAZE_021
# Stimulus set3
# Maximum Derivative
# 0.09
# Mean
# 0.0197222222222
# STD
# 0.0269983995868
# One-Sample t-test
# Ttest_1sampResult(statistic=6.5337546271232858, pvalue=5.4965976544640418e-09)
#
# Target Trial
# 21
# Alternative Target Trial
# 21
# Subject WMAZE_022
# Stimulus set1
# Maximum Derivative
# 0.1895
# Mean
# 0.0105061728395
# STD
# 0.0559284978832
# One-Sample t-test
# Ttest_1sampResult(statistic=1.6801821998895519, pvalue=0.096822999149681982)
#
# Target Trial
# 45
# Alternative Target Trial
# 45
# Subject WMAZE_022
# Stimulus set2
# Maximum Derivative
# 0.26
# Mean
# -0.0109320987654
# STD
# 0.111224601847
# One-Sample t-test
# Ttest_1sampResult(statistic=-0.87911902835343769, pvalue=0.3819697293393326)
#
# Target Trial
# 73
# Alternative Target Trial
# 51
# Subject WMAZE_022
# Stimulus set3
# Maximum Derivative
# 0.1355
# Mean
# 0.0283580246914
# STD
# 0.0507226320154
# One-Sample t-test
# Ttest_1sampResult(statistic=5.0005662875121528, pvalue=3.3123913689765107e-06)
#
# Target Trial
# 32
# Alternative Target Trial
# 32
# Subject WMAZE_023
# Stimulus set1
# Maximum Derivative
# 0.093
# Mean
# -0.00253086419753
# STD
# 0.0389449869735
# One-Sample t-test
# Ttest_1sampResult(statistic=-0.58124907232384904, pvalue=0.56270670189687411)
#
# Target Trial
# 70
# Alternative Target Trial
# 70
# Subject WMAZE_023
# Stimulus set2
# Maximum Derivative
# 0.268
# Mean
# 0.0169012345679
# STD
# 0.0966153254385
# One-Sample t-test
# Ttest_1sampResult(statistic=1.5646507104736129, pvalue=0.12161216021724298)
#
# Target Trial
# 10
# Alternative Target Trial
# 10
# Subject WMAZE_023
# Stimulus set3
# Maximum Derivative
# 0.0745
# Mean
# 0.00669135802469
# STD
# 0.0256220834415
# One-Sample t-test
# Ttest_1sampResult(statistic=2.3358492979931609, pvalue=0.022003917030438733)
#
# Target Trial
# 7
# Alternative Target Trial
# 10
# Subject WMAZE_024
# Stimulus set1
# Maximum Derivative
# 0.1725
# Mean
# 0.0386111111111
# STD
# 0.057916500133
# One-Sample t-test
# Ttest_1sampResult(statistic=5.9628650856315923, pvalue=6.3930051607670175e-08)
#
# Target Trial
# 15
# Alternative Target Trial
# 15
# Subject WMAZE_024
# Stimulus set2
# Maximum Derivative
# 0.255
# Mean
# 0.0265864197531
# STD
# 0.118700988329
# One-Sample t-test
# Ttest_1sampResult(statistic=2.0033208714737429, pvalue=0.048528860637248053)
#
# Target Trial
# 11
# Alternative Target Trial
# 11
# Subject WMAZE_024
# Stimulus set3
# Maximum Derivative
# 0.506
# Mean
# -0.0136975308642
# STD
# 0.180600672637
# One-Sample t-test
# Ttest_1sampResult(statistic=-0.6783720057973972, pvalue=0.49949345755349706)
#
# Target Trial
# 22
# Alternative Target Trial
# 22
# Subject WMAZE_026
# Stimulus set1
# Maximum Derivative
# 0.15
# Mean
# -0.014037037037
# STD
# 0.0507000242152
# One-Sample t-test
# Ttest_1sampResult(statistic=-2.4763514024601352, pvalue=0.015383061767621019)
#
# Target Trial
# 49
# Alternative Target Trial
# 49
# Subject WMAZE_026
# Stimulus set2
# Maximum Derivative
# 0.228
# Mean
# 0.0502654320988
# STD
# 0.0603497566362
# One-Sample t-test
# Ttest_1sampResult(statistic=7.4497018285459289, pvalue=9.5898017342361046e-11)
#
# Target Trial
# 8
# Alternative Target Trial
# 19
# Subject WMAZE_026
# Stimulus set3
# Maximum Derivative
# 0.282
# Mean
# 0.0143456790123
# STD
# 0.137671658101
# One-Sample t-test
# Ttest_1sampResult(statistic=0.93201211919601779, pvalue=0.35413452576205129)
#
# Target Trial
# 51
# Alternative Target Trial
# 51
# Subject WMAZE_027
# Stimulus set1
# Maximum Derivative
# 0.5315
# Mean
# 0.0466419753086
# STD
# 0.216760866055
# One-Sample t-test
# Ttest_1sampResult(statistic=1.9246025224600292, pvalue=0.057834267648285025)
#
# Target Trial
# 6
# Alternative Target Trial
# 30
# Subject WMAZE_027
# Stimulus set2
# Maximum Derivative
# 0.1685
# Mean
# 0.0141049382716
# STD
# 0.0528173369901
# One-Sample t-test
# Ttest_1sampResult(statistic=2.3885794014692983, pvalue=0.019269233938661767)
#
# Target Trial
# 7
# Alternative Target Trial
# 10
# Subject WMAZE_027
# Stimulus set3
# Maximum Derivative
# 0.1
# Mean
# 0.0260432098765
# STD
# 0.0403523981213
# One-Sample t-test
# Ttest_1sampResult(statistic=5.7725825821968479, pvalue=1.4250571259876609e-07)
#
# Target Trial
# 28
# Alternative Target Trial
# 28
