# %% [markdown]
# # MODEL 3 Version 2.3.2.5
# ### Contains only fixed-before-conditional trials without intervening BLs
# ### Combines A & C trials into single regressor
# ### Accounts for last three noisy volumes via FSL ROI -- removal and recreation of EPI files
# ### Compares positive derivative to negative derivatives

# %% [markdown]
# #  WMAZE Beta Series correlation Analysis
#
# ## Obtains Correlation values for the regions of interest:
# ### Hippocampus (FS labels: hippocampus [17, 53])
# ### Dorsal caudate (hand-drawn by Mandy)
# ### Medial PFC (FS labels: rostral anterior cingulate [1026, 2026] & caudal anterior cingulate [1002, 2002])
# ### Dorsolateral PFC (Lausanne atlas: dlPFC)

# %%
import nipype.pipeline as pe
import nipype.interfaces.io as nio
import os
import nipype.interfaces.freesurfer as fs
from nipype import IdentityInterface


subjects_dir = '/home/data/madlab/surfaces/wmaze'
work_dir = '/scratch/madlab/wmaze/regions_workdir'
sink_dir = '/home/data/madlab/data/mri/wmaze/roi_analysis/model3_betaseries/mask'

sids = ['WMAZE_001', 'WMAZE_002', 'WMAZE_004', 'WMAZE_005', 'WMAZE_006', 
        'WMAZE_007', 'WMAZE_008', 'WMAZE_009', 'WMAZE_010', 'WMAZE_012', 
        'WMAZE_017', 'WMAZE_018', 'WMAZE_019', 'WMAZE_020', 'WMAZE_021', 
        'WMAZE_022', 'WMAZE_023', 'WMAZE_024', 'WMAZE_026', 'WMAZE_027']

wf = pe.Workflow(name = 'wf')
wf.base_dir = work_dir

# Node: subject_iterable
subj_iterable = pe.Node(IdentityInterface(fields = ['subject_id'], 
                                          mandatory_inputs = True),
                        name = 'subj_iterable')
subj_iterable.iterables = ('subject_id', sids)

info = dict(ref_epi_file = [['subject_id']],
            bbreg_xfm = [['subject_id']],
            aparc_aseg = [['subject_id']])

# Node: Datagrabber
datasource = pe.Node(nio.DataGrabber(infields = ['subject_id'],
                                     outfields = info.keys()),
                     name = 'datasource')
datasource.inputs.base_directory = os.path.abspath('/home/data/madlab/')
datasource.inputs.field_template = dict(ref_epi_file = 'data/mri/wmaze/preproc/%s/ref/*.nii.gz',
                                        bbreg_xfm = 'data/mri/wmaze/preproc/%s/bbreg/_fs_register0/*.dat',
                                        aparc_aseg = 'surfaces/wmaze/%s/mri/aparc+aseg.mgz')
datasource.inputs.template = '*'
datasource.inputs.template_args = info
datasource.inputs.sort_filelist = True
datasource.inputs.ignore_exception = False
datasource.inputs.raise_on_empty = True
wf.connect(subj_iterable, 'subject_id', datasource, 'subject_id')


# MapNode: Create binarized ROI masks
anat_mask = pe.MapNode(fs.Binarize(),
                       iterfield = ['match', 'binary_file'], 
                       name = 'anat_mask')
anat_mask.inputs.match = [[1017,1022,1024], [2017,2022,2024]] #paracentral, postcentral, precentral --> motor
                          
anat_mask.inputs.binary_file = ['lh-motor.nii.gz','rh-motor.nii.gz']
wf.connect(datasource, 'aparc_aseg', anat_mask, 'in_file')


# MapNode: Transform the masks to 1st volume of 1st run (EPI space)
anatmask_xfm = pe.MapNode(fs.ApplyVolTransform(inverse = True,
                                               interp = 'nearest'),
                          iterfield = ['target_file'],
                          name = 'anatmask_xfm')
anatmask_xfm.inputs.subjects_dir = subjects_dir
wf.connect(datasource, 'ref_epi_file', anatmask_xfm, 'source_file')
wf.connect(datasource, 'bbreg_xfm', anatmask_xfm, 'reg_file')
wf.connect(anat_mask, 'binary_file', anatmask_xfm, 'target_file')

# Node: Datasink
sinker = pe.Node(nio.DataSink(infields = None),
                 name = "sinker")
sinker.inputs._outputs = {}
sinker.inputs.base_directory = sink_dir
sinker.inputs.ignore_exception = False
sinker.inputs.parameterization = True
sinker.inputs.remove_dest_dir = False
wf.connect(anatmask_xfm, 'transformed_file', sinker, 'anat_masks')

wf.run(plugin = 'LSF', plugin_args = {'bsub_args': '-q PQ_madlab'})
# Out:
# 190114-14:08:43,244 workflow INFO:
# 	 ['check', 'execution', 'logging']
# 190114-14:08:43,525 workflow INFO:
# 	 Running in parallel.
# 190114-14:08:43,533 workflow INFO:
# 	 Submitting 20 jobs
# 190114-14:08:43,535 workflow INFO:
# 	 Executing: datasource.a04 ID: 0
# 190114-14:08:43,732 workflow INFO:
# 	 Executing: datasource.a09 ID: 1
# 190114-14:08:43,876 workflow INFO:
# 	 Executing: datasource.a03 ID: 8
# 190114-14:08:44,22 workflow INFO:
# 	 Executing: datasource.a08 ID: 9
# 190114-14:08:44,163 workflow INFO:
# 	 Executing: datasource.a02 ID: 16
# 190114-14:08:44,260 workflow INFO:
# 	 Executing: datasource.a18 ID: 17
# 190114-14:08:44,368 workflow INFO:
# 	 Executing: datasource.a07 ID: 18
# 190114-14:08:44,447 workflow INFO:
# 	 Executing: datasource.a17 ID: 20
# 190114-14:08:44,521 workflow INFO:
# 	 Executing: datasource.a01 ID: 25
# 190114-14:08:44,594 workflow INFO:
# 	 Executing: datasource.a06 ID: 27
# 190114-14:08:44,692 workflow INFO:
# 	 Executing: datasource.a16 ID: 30
# 190114-14:08:44,831 workflow INFO:
# 	 Executing: datasource.a05 ID: 34
# 190114-14:08:44,962 workflow INFO:
# 	 Executing: datasource.a00 ID: 39
# 190114-14:08:45,84 workflow INFO:
# 	 Executing: datasource.a14 ID: 45
# 190114-14:08:45,217 workflow INFO:
# 	 Executing: datasource.a13 ID: 51
# 190114-14:08:45,344 workflow INFO:
# 	 Executing: datasource.a19 ID: 52
# 190114-14:08:45,464 workflow INFO:
# 	 Executing: datasource.a12 ID: 58
# 190114-14:08:45,580 workflow INFO:
# 	 Executing: datasource.a11 ID: 65
# 190114-14:08:45,685 workflow INFO:
# 	 Executing: datasource.a15 ID: 72
# 190114-14:08:45,782 workflow INFO:
# 	 Executing: datasource.a10 ID: 76
# 190114-14:09:46,93 workflow INFO:
# 	 [Job finished] jobname: datasource.a04 jobid: 0
# 190114-14:09:46,212 workflow INFO:
# 	 [Job finished] jobname: datasource.a09 jobid: 1
# 190114-14:09:46,312 workflow INFO:
# 	 [Job finished] jobname: datasource.a03 jobid: 8
# 190114-14:09:46,391 workflow INFO:
# 	 [Job finished] jobname: datasource.a08 jobid: 9
# 190114-14:09:46,471 workflow INFO:
# 	 [Job finished] jobname: datasource.a02 jobid: 16
# 190114-14:09:46,562 workflow INFO:
# 	 [Job finished] jobname: datasource.a18 jobid: 17
# 190114-14:09:46,640 workflow INFO:
# 	 [Job finished] jobname: datasource.a07 jobid: 18
# 190114-14:09:46,773 workflow INFO:
# 	 [Job finished] jobname: datasource.a17 jobid: 20
# 190114-14:09:46,906 workflow INFO:
# 	 [Job finished] jobname: datasource.a01 jobid: 25
# 190114-14:09:47,44 workflow INFO:
# 	 [Job finished] jobname: datasource.a06 jobid: 27
# 190114-14:09:47,189 workflow INFO:
# 	 [Job finished] jobname: datasource.a16 jobid: 30
# 190114-14:09:47,318 workflow INFO:
# 	 [Job finished] jobname: datasource.a05 jobid: 34
# 190114-14:09:47,447 workflow INFO:
# 	 [Job finished] jobname: datasource.a00 jobid: 39
# 190114-14:09:47,573 workflow INFO:
# 	 [Job finished] jobname: datasource.a14 jobid: 45
# 190114-14:09:47,694 workflow INFO:
# 	 [Job finished] jobname: datasource.a13 jobid: 51
# 190114-14:09:47,797 workflow INFO:
# 	 [Job finished] jobname: datasource.a19 jobid: 52
# 190114-14:09:47,874 workflow INFO:
# 	 [Job finished] jobname: datasource.a12 jobid: 58
# 190114-14:09:47,965 workflow INFO:
# 	 [Job finished] jobname: datasource.a11 jobid: 65
# 190114-14:09:48,201 workflow INFO:
# 	 [Job finished] jobname: datasource.a15 jobid: 72
# 190114-14:09:48,327 workflow INFO:
# 	 [Job finished] jobname: datasource.a10 jobid: 76
# 190114-14:09:48,335 workflow INFO:
# 	 Submitting 20 jobs
# 190114-14:09:48,364 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a04
# 190114-14:09:48,402 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a09
# 190114-14:09:48,437 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a03
# 190114-14:09:48,473 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a08
# 190114-14:09:48,510 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a02
# 190114-14:09:48,548 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a17
# 190114-14:09:48,584 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a01
# 190114-14:09:48,619 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a06
# 190114-14:09:48,655 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a05
# 190114-14:09:48,672 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a18
# 190114-14:09:48,695 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a00
# 190114-14:09:48,712 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a16
# 190114-14:09:48,730 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a14
# 190114-14:09:48,748 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a13
# 190114-14:09:48,768 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a12
# 190114-14:09:48,786 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a07
# 190114-14:09:48,802 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a19
# 190114-14:09:48,824 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a11
# 190114-14:09:48,842 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a15
# 190114-14:09:48,860 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a10
# 190114-14:09:48,864 workflow INFO:
# 	 Submitting 40 jobs
# 190114-14:09:48,865 workflow INFO:
# 	 Executing: _anat_mask0 ID: 80
# 190114-14:09:49,6 workflow INFO:
# 	 Executing: _anat_mask1 ID: 81
# 190114-14:09:49,117 workflow INFO:
# 	 Executing: _anat_mask0 ID: 82
# 190114-14:09:49,257 workflow INFO:
# 	 Executing: _anat_mask1 ID: 83
# 190114-14:09:49,401 workflow INFO:
# 	 Executing: _anat_mask0 ID: 84
# 190114-14:09:49,547 workflow INFO:
# 	 Executing: _anat_mask1 ID: 85
# 190114-14:09:49,686 workflow INFO:
# 	 Executing: _anat_mask0 ID: 86
# 190114-14:09:49,831 workflow INFO:
# 	 Executing: _anat_mask1 ID: 87
# 190114-14:09:49,976 workflow INFO:
# 	 Executing: _anat_mask0 ID: 88
# 190114-14:09:50,127 workflow INFO:
# 	 Executing: _anat_mask1 ID: 89
# 190114-14:09:50,263 workflow INFO:
# 	 Executing: _anat_mask0 ID: 90
# 190114-14:09:50,388 workflow INFO:
# 	 Executing: _anat_mask1 ID: 91
# 190114-14:09:50,512 workflow INFO:
# 	 Executing: _anat_mask0 ID: 92
# 190114-14:09:50,639 workflow INFO:
# 	 Executing: _anat_mask1 ID: 93
# 190114-14:09:50,771 workflow INFO:
# 	 Executing: _anat_mask0 ID: 94
# 190114-14:09:50,917 workflow INFO:
# 	 Executing: _anat_mask1 ID: 95
# 190114-14:09:51,56 workflow INFO:
# 	 Executing: _anat_mask0 ID: 96
# 190114-14:09:51,201 workflow INFO:
# 	 Executing: _anat_mask1 ID: 97
# 190114-14:09:51,332 workflow INFO:
# 	 Executing: _anat_mask0 ID: 98
# 190114-14:09:51,468 workflow INFO:
# 	 Executing: _anat_mask1 ID: 99
# 190114-14:09:51,573 workflow INFO:
# 	 Executing: _anat_mask0 ID: 100
# 190114-14:09:51,695 workflow INFO:
# 	 Executing: _anat_mask1 ID: 101
# 190114-14:09:51,806 workflow INFO:
# 	 Executing: _anat_mask0 ID: 102
# 190114-14:09:51,934 workflow INFO:
# 	 Executing: _anat_mask1 ID: 103
# 190114-14:09:52,48 workflow INFO:
# 	 Executing: _anat_mask0 ID: 104
# 190114-14:09:52,179 workflow INFO:
# 	 Executing: _anat_mask1 ID: 105
# 190114-14:09:52,289 workflow INFO:
# 	 Executing: _anat_mask0 ID: 106
# 190114-14:09:52,428 workflow INFO:
# 	 Executing: _anat_mask1 ID: 107
# 190114-14:09:52,559 workflow INFO:
# 	 Executing: _anat_mask0 ID: 108
# 190114-14:09:52,673 workflow INFO:
# 	 Executing: _anat_mask1 ID: 109
# 190114-14:09:52,846 workflow INFO:
# 	 Executing: _anat_mask0 ID: 110
# 190114-14:09:52,997 workflow INFO:
# 	 Executing: _anat_mask1 ID: 111
# 190114-14:09:53,143 workflow INFO:
# 	 Executing: _anat_mask0 ID: 112
# 190114-14:09:53,288 workflow INFO:
# 	 Executing: _anat_mask1 ID: 113
# 190114-14:09:53,420 workflow INFO:
# 	 Executing: _anat_mask0 ID: 114
# 190114-14:09:53,556 workflow INFO:
# 	 Executing: _anat_mask1 ID: 115
# 190114-14:09:53,690 workflow INFO:
# 	 Executing: _anat_mask0 ID: 116
# 190114-14:09:53,811 workflow INFO:
# 	 Executing: _anat_mask1 ID: 117
# 190114-14:09:53,939 workflow INFO:
# 	 Executing: _anat_mask0 ID: 118
# 190114-14:09:54,70 workflow INFO:
# 	 Executing: _anat_mask1 ID: 119
# 190114-14:10:54,336 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 80
# 190114-14:10:54,420 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 81
# 190114-14:10:54,508 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 82
# 190114-14:10:54,589 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 83
# 190114-14:10:54,676 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 84
# 190114-14:10:54,806 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 85
# 190114-14:10:54,943 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 86
# 190114-14:10:55,74 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 87
# 190114-14:10:55,209 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 88
# 190114-14:10:55,349 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 89
# 190114-14:10:55,481 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 90
# 190114-14:10:55,610 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 91
# 190114-14:10:55,729 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 92
# 190114-14:10:55,833 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 93
# 190114-14:10:55,922 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 94
# 190114-14:10:56,1 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 95
# 190114-14:10:56,97 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 96
# 190114-14:10:56,175 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 97
# 190114-14:10:56,304 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 98
# 190114-14:10:56,423 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 99
# 190114-14:10:56,540 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 100
# 190114-14:10:56,657 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 101
# 190114-14:10:56,773 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 102
# 190114-14:10:56,885 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 103
# 190114-14:10:56,997 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 104
# 190114-14:10:57,111 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 105
# 190114-14:10:57,219 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 106
# 190114-14:10:57,318 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 107
# 190114-14:10:57,403 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 108
# 190114-14:10:57,483 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 109
# 190114-14:10:57,567 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 110
# 190114-14:10:57,646 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 111
# 190114-14:10:57,772 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 112
# 190114-14:10:57,897 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 113
# 190114-14:10:58,23 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 114
# 190114-14:10:58,138 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 115
# 190114-14:10:58,252 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 116
# 190114-14:10:58,389 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 117
# 190114-14:10:58,506 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 118
# 190114-14:10:58,647 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 119
# 190114-14:10:58,653 workflow INFO:
# 	 Submitting 20 jobs
# 190114-14:10:58,654 workflow INFO:
# 	 Executing: anat_mask.a04 ID: 2
# 190114-14:10:58,792 workflow INFO:
# 	 Executing: anat_mask.a09 ID: 3
# 190114-14:10:58,905 workflow INFO:
# 	 Executing: anat_mask.a03 ID: 10
# 190114-14:10:59,21 workflow INFO:
# 	 Executing: anat_mask.a08 ID: 11
# 190114-14:10:59,141 workflow INFO:
# 	 Executing: anat_mask.a02 ID: 19
# 190114-14:10:59,288 workflow INFO:
# 	 Executing: anat_mask.a17 ID: 21
# 190114-14:10:59,434 workflow INFO:
# 	 Executing: anat_mask.a01 ID: 28
# 190114-14:10:59,579 workflow INFO:
# 	 Executing: anat_mask.a06 ID: 29
# 190114-14:10:59,719 workflow INFO:
# 	 Executing: anat_mask.a05 ID: 35
# 190114-14:10:59,845 workflow INFO:
# 	 Executing: anat_mask.a18 ID: 38
# 190114-14:10:59,975 workflow INFO:
# 	 Executing: anat_mask.a00 ID: 40
# 190114-14:11:00,90 workflow INFO:
# 	 Executing: anat_mask.a16 ID: 44
# 190114-14:11:00,226 workflow INFO:
# 	 Executing: anat_mask.a14 ID: 46
# 190114-14:11:00,373 workflow INFO:
# 	 Executing: anat_mask.a13 ID: 53
# 190114-14:11:00,519 workflow INFO:
# 	 Executing: anat_mask.a12 ID: 59
# 190114-14:11:00,657 workflow INFO:
# 	 Executing: anat_mask.a07 ID: 60
# 190114-14:11:00,795 workflow INFO:
# 	 Executing: anat_mask.a19 ID: 66
# 190114-14:11:00,927 workflow INFO:
# 	 Executing: anat_mask.a11 ID: 69
# 190114-14:11:01,64 workflow INFO:
# 	 Executing: anat_mask.a15 ID: 73
# 190114-14:11:01,198 workflow INFO:
# 	 Executing: anat_mask.a10 ID: 77
# 190114-14:12:01,773 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a04 jobid: 2
# 190114-14:12:01,919 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a09 jobid: 3
# 190114-14:12:02,64 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a03 jobid: 10
# 190114-14:12:02,206 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a08 jobid: 11
# 190114-14:12:02,353 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a02 jobid: 19
# 190114-14:12:02,492 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a17 jobid: 21
# 190114-14:12:02,632 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a01 jobid: 28
# 190114-14:12:02,748 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a06 jobid: 29
# 190114-14:12:02,868 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a05 jobid: 35
# 190114-14:12:02,980 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a18 jobid: 38
# 190114-14:12:03,95 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a00 jobid: 40
# 190114-14:12:03,232 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a16 jobid: 44
# 190114-14:12:03,376 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a14 jobid: 46
# 190114-14:12:03,521 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a13 jobid: 53
# 190114-14:12:03,657 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a12 jobid: 59
# 190114-14:12:03,762 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a07 jobid: 60
# 190114-14:12:03,875 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a19 jobid: 66
# 190114-14:12:03,979 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a11 jobid: 69
# 190114-14:12:04,83 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a15 jobid: 73
# 190114-14:12:04,210 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a10 jobid: 77
# 190114-14:12:04,219 workflow INFO:
# 	 Submitting 20 jobs
# 190114-14:12:04,308 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a04
# 190114-14:12:04,405 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a09
# 190114-14:12:04,501 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a03
# 190114-14:12:04,597 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a08
# 190114-14:12:04,689 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a17
# 190114-14:12:04,782 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a02
# 190114-14:12:04,875 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a01
# 190114-14:12:04,972 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a06
# 190114-14:12:05,65 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a05
# 190114-14:12:05,159 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a00
# 190114-14:12:05,252 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a18
# 190114-14:12:05,345 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a14
# 190114-14:12:05,438 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a13
# 190114-14:12:05,533 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a16
# 190114-14:12:05,628 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a07
# 190114-14:12:05,715 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a12
# 190114-14:12:05,808 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a19
# 190114-14:12:05,895 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a11
# 190114-14:12:05,983 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a15
# 190114-14:12:06,69 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a10
# 190114-14:12:06,82 workflow INFO:
# 	 Submitting 40 jobs
# 190114-14:12:06,83 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 120
# 190114-14:12:06,244 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 121
# 190114-14:12:06,385 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 122
# 190114-14:12:06,529 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 123
# 190114-14:12:06,659 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 124
# 190114-14:12:06,816 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 125
# 190114-14:12:06,967 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 126
# 190114-14:12:07,122 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 127
# 190114-14:12:07,260 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 128
# 190114-14:12:07,400 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 129
# 190114-14:12:07,530 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 130
# 190114-14:12:07,657 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 131
# 190114-14:12:07,799 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 132
# 190114-14:12:07,948 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 133
# 190114-14:12:08,95 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 134
# 190114-14:12:08,268 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 135
# 190114-14:12:08,412 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 136
# 190114-14:12:08,567 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 137
# 190114-14:12:08,700 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 138
# 190114-14:12:08,823 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 139
# 190114-14:12:08,906 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 140
# 190114-14:12:09,19 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 141
# 190114-14:12:09,94 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 142
# 190114-14:12:09,212 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 143
# 190114-14:12:09,356 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 144
# 190114-14:12:09,508 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 145
# 190114-14:12:09,652 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 146
# 190114-14:12:09,798 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 147
# 190114-14:12:09,957 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 148
# 190114-14:12:10,117 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 149
# 190114-14:12:10,256 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 150
# 190114-14:12:10,378 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 151
# 190114-14:12:10,491 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 152
# 190114-14:12:10,623 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 153
# 190114-14:12:10,751 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 154
# 190114-14:12:10,901 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 155
# 190114-14:12:11,49 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 156
# 190114-14:12:11,196 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 157
# 190114-14:12:11,323 workflow INFO:
# 	 Executing: _anatmask_xfm0 ID: 158
# 190114-14:12:11,456 workflow INFO:
# 	 Executing: _anatmask_xfm1 ID: 159
# 190114-14:13:11,784 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 120
# 190114-14:13:11,916 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 121
# 190114-14:13:12,0 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 122
# 190114-14:13:12,88 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 123
# 190114-14:13:12,174 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 124
# 190114-14:13:12,302 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 125
# 190114-14:13:12,430 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 126
# 190114-14:13:12,558 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 127
# 190114-14:13:12,681 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 128
# 190114-14:13:12,798 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 129
# 190114-14:13:12,920 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 130
# 190114-14:13:13,33 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 131
# 190114-14:13:13,153 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 132
# 190114-14:13:13,259 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 133
# 190114-14:13:13,361 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 134
# 190114-14:13:13,445 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 135
# 190114-14:13:13,527 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 136
# 190114-14:13:13,603 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 137
# 190114-14:13:13,723 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 138
# 190114-14:13:13,849 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 139
# 190114-14:13:13,979 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 140
# 190114-14:13:14,91 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 141
# 190114-14:13:14,212 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 142
# 190114-14:13:14,326 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 143
# 190114-14:13:14,446 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 144
# 190114-14:13:14,575 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 145
# 190114-14:13:14,697 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 146
# 190114-14:13:14,809 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 147
# 190114-14:13:14,920 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 148
# 190114-14:13:15,33 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 149
# 190114-14:13:15,156 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 150
# 190114-14:13:15,267 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 151
# 190114-14:13:15,384 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 152
# 190114-14:13:15,497 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 153
# 190114-14:13:15,611 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 154
# 190114-14:13:15,727 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 155
# 190114-14:13:15,847 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 156
# 190114-14:13:15,965 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 157
# 190114-14:13:16,98 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 158
# 190114-14:13:16,215 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 159
# 190114-14:13:16,220 workflow INFO:
# 	 Submitting 20 jobs
# 190114-14:13:16,221 workflow INFO:
# 	 Executing: anatmask_xfm.a04 ID: 4
# 190114-14:13:16,385 workflow INFO:
# 	 Executing: anatmask_xfm.a09 ID: 6
# 190114-14:13:16,533 workflow INFO:
# 	 Executing: anatmask_xfm.a03 ID: 12
# 190114-14:13:16,658 workflow INFO:
# 	 Executing: anatmask_xfm.a08 ID: 14
# 190114-14:13:16,808 workflow INFO:
# 	 Executing: anatmask_xfm.a17 ID: 22
# 190114-14:13:16,927 workflow INFO:
# 	 Executing: anatmask_xfm.a02 ID: 23
# 190114-14:13:17,47 workflow INFO:
# 	 Executing: anatmask_xfm.a01 ID: 31
# 190114-14:13:17,174 workflow INFO:
# 	 Executing: anatmask_xfm.a06 ID: 33
# 190114-14:13:17,301 workflow INFO:
# 	 Executing: anatmask_xfm.a05 ID: 36
# 190114-14:13:17,399 workflow INFO:
# 	 Executing: anatmask_xfm.a00 ID: 42
# 190114-14:13:17,483 workflow INFO:
# 	 Executing: anatmask_xfm.a18 ID: 47
# 190114-14:13:17,600 workflow INFO:
# 	 Executing: anatmask_xfm.a14 ID: 49
# 190114-14:13:17,710 workflow INFO:
# 	 Executing: anatmask_xfm.a13 ID: 54
# 190114-14:13:17,859 workflow INFO:
# 	 Executing: anatmask_xfm.a16 ID: 56
# 190114-14:13:18,3 workflow INFO:
# 	 Executing: anatmask_xfm.a07 ID: 61
# 190114-14:13:18,157 workflow INFO:
# 	 Executing: anatmask_xfm.a12 ID: 63
# 190114-14:13:18,304 workflow INFO:
# 	 Executing: anatmask_xfm.a19 ID: 67
# 190114-14:13:18,446 workflow INFO:
# 	 Executing: anatmask_xfm.a11 ID: 70
# 190114-14:13:18,589 workflow INFO:
# 	 Executing: anatmask_xfm.a15 ID: 74
# 190114-14:13:18,731 workflow INFO:
# 	 Executing: anatmask_xfm.a10 ID: 78
# 190114-14:14:19,145 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a04 jobid: 4
# 190114-14:14:19,254 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a09 jobid: 6
# 190114-14:14:19,350 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a03 jobid: 12
# 190114-14:14:19,457 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a08 jobid: 14
# 190114-14:14:19,544 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a17 jobid: 22
# 190114-14:14:19,646 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a02 jobid: 23
# 190114-14:14:19,781 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a01 jobid: 31
# 190114-14:14:19,927 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a06 jobid: 33
# 190114-14:14:20,76 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a05 jobid: 36
# 190114-14:14:20,226 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a00 jobid: 42
# 190114-14:14:20,376 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a18 jobid: 47
# 190114-14:14:20,518 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a14 jobid: 49
# 190114-14:14:20,672 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a13 jobid: 54
# 190114-14:14:20,817 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a16 jobid: 56
# 190114-14:14:20,960 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a07 jobid: 61
# 190114-14:14:21,99 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a12 jobid: 63
# 190114-14:14:21,213 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a19 jobid: 67
# 190114-14:14:21,317 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a11 jobid: 70
# 190114-14:14:21,420 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a15 jobid: 74
# 190114-14:14:21,524 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a10 jobid: 78
# 190114-14:14:21,528 workflow INFO:
# 	 Submitting 20 jobs
# 190114-14:14:21,528 workflow INFO:
# 	 Executing: sinker.a04 ID: 5
# 190114-14:14:21,688 workflow INFO:
# 	 Executing: sinker.a09 ID: 7
# 190114-14:14:21,879 workflow INFO:
# 	 Executing: sinker.a03 ID: 13
# 190114-14:14:22,72 workflow INFO:
# 	 Executing: sinker.a08 ID: 15
# 190114-14:14:22,263 workflow INFO:
# 	 Executing: sinker.a02 ID: 24
# 190114-14:14:22,456 workflow INFO:
# 	 Executing: sinker.a17 ID: 26
# 190114-14:14:22,648 workflow INFO:
# 	 Executing: sinker.a01 ID: 32
# 190114-14:14:22,842 workflow INFO:
# 	 Executing: sinker.a05 ID: 37
# 190114-14:14:23,31 workflow INFO:
# 	 Executing: sinker.a06 ID: 41
# 190114-14:14:23,187 workflow INFO:
# 	 Executing: sinker.a00 ID: 43
# 190114-14:14:23,355 workflow INFO:
# 	 Executing: sinker.a18 ID: 48
# 190114-14:14:23,480 workflow INFO:
# 	 Executing: sinker.a14 ID: 50
# 190114-14:14:23,609 workflow INFO:
# 	 Executing: sinker.a13 ID: 55
# 190114-14:14:23,757 workflow INFO:
# 	 Executing: sinker.a16 ID: 57
# 190114-14:14:23,938 workflow INFO:
# 	 Executing: sinker.a07 ID: 62
# 190114-14:14:24,123 workflow INFO:
# 	 Executing: sinker.a12 ID: 64
# 190114-14:14:24,284 workflow INFO:
# 	 Executing: sinker.a19 ID: 68
# 190114-14:14:24,428 workflow INFO:
# 	 Executing: sinker.a11 ID: 71
# 190114-14:14:24,560 workflow INFO:
# 	 Executing: sinker.a15 ID: 75
# 190114-14:14:24,683 workflow INFO:
# 	 Executing: sinker.a10 ID: 79
# 190114-14:15:25,8 workflow INFO:
# 	 [Job finished] jobname: sinker.a04 jobid: 5
# 190114-14:15:25,135 workflow INFO:
# 	 [Job finished] jobname: sinker.a09 jobid: 7
# 190114-14:15:25,251 workflow INFO:
# 	 [Job finished] jobname: sinker.a03 jobid: 13
# 190114-14:15:25,362 workflow INFO:
# 	 [Job finished] jobname: sinker.a08 jobid: 15
# 190114-14:15:25,477 workflow INFO:
# 	 [Job finished] jobname: sinker.a02 jobid: 24
# 190114-14:15:25,593 workflow INFO:
# 	 [Job finished] jobname: sinker.a17 jobid: 26
# 190114-14:15:25,715 workflow INFO:
# 	 [Job finished] jobname: sinker.a01 jobid: 32
# 190114-14:15:25,821 workflow INFO:
# 	 [Job finished] jobname: sinker.a05 jobid: 37
# 190114-14:15:25,921 workflow INFO:
# 	 [Job finished] jobname: sinker.a06 jobid: 41
# 190114-14:15:26,5 workflow INFO:
# 	 [Job finished] jobname: sinker.a00 jobid: 43
# 190114-14:15:26,85 workflow INFO:
# 	 [Job finished] jobname: sinker.a18 jobid: 48
# 190114-14:15:26,165 workflow INFO:
# 	 [Job finished] jobname: sinker.a14 jobid: 50
# 190114-14:15:26,302 workflow INFO:
# 	 [Job finished] jobname: sinker.a13 jobid: 55
# 190114-14:15:26,441 workflow INFO:
# 	 [Job finished] jobname: sinker.a16 jobid: 57
# 190114-14:15:26,575 workflow INFO:
# 	 [Job finished] jobname: sinker.a07 jobid: 62
# 190114-14:15:26,705 workflow INFO:
# 	 [Job finished] jobname: sinker.a12 jobid: 64
# 190114-14:15:26,843 workflow INFO:
# 	 [Job finished] jobname: sinker.a19 jobid: 68
# 190114-14:15:26,972 workflow INFO:
# 	 [Job finished] jobname: sinker.a11 jobid: 71
# 190114-14:15:27,111 workflow INFO:
# 	 [Job finished] jobname: sinker.a15 jobid: 75
# 190114-14:15:27,245 workflow INFO:
# 	 [Job finished] jobname: sinker.a10 jobid: 79

# %% [markdown]
# ### Use Glob to grab all previously created anatomy masks and beta series cope files

# %%
from glob import glob
 
sids = ['WMAZE_001', 'WMAZE_002', 'WMAZE_004', 'WMAZE_005', 'WMAZE_006',
        'WMAZE_007', 'WMAZE_008', 'WMAZE_009', 'WMAZE_010', 'WMAZE_012',
        'WMAZE_017', 'WMAZE_018', 'WMAZE_019', 'WMAZE_020', 'WMAZE_021',  
        'WMAZE_022', 'WMAZE_023', 'WMAZE_024', 'WMAZE_026', 'WMAZE_027']
proj_dir = '/home/data/madlab/data/mri/wmaze'
 
mask_filenames = []
cope_files = []

for SID in sids:
    # Grab the mask files for each subject
    mask_filenames_glob = glob(proj_dir + '/roi_analysis/model3_betaseries/mask/anat_masks/_subject_id_' + SID + 
                               '/_anatmask_xfm*/*')
    mask_filenames.append(sorted(mask_filenames_glob))
    # Grab the cope files for each subject
    subjcopes_glob = glob(proj_dir + '/frstlvl/wmaze_MRthesis/fixed_before_conditional/model3_2-3-2-5/merge_copes/'
                          + SID + '/merged/cope_*')
    cope_files.append(sorted(subjcopes_glob))
    # If there are no cope files, print subject id
    if len(cope_files[-1]) == 0:
        print(SID)
    if len(mask_filenames[-1]) < 15:
        print(SID)

# %% [markdown]
# ### Cell to double-check the array indexing for both the masks and the copes

# %% [raw]
# print '0. left dlPFC (Lausanne)'
# print(mask_filenames[2][0]) #lh-dlPFC Lausanne
# print""
# print '1. left hippocampus'
# print(mask_filenames[2][1]) #lh-HPC
# print""
# print '2. left mPFC-FS-3'
# print(mask_filenames[2][2]) #lh-mPFC-FS-3
# print""
# print '3. left mPFC Lausanne'
# print(mask_filenames[2][3]) #lh-mPFC-L
# print""
# print '4. left mPFC-rac-only'
# print(mask_filenames[2][4]) #lh-mPFC_rac
# print""
# print '5. left mPFC-orig'
# print(mask_filenames[2][5]) #lh-mPFC-orig
# print""
# print '6. left motor'
# print(mask_filenames[2][6]) #lh-putamen
# print""
# print '7. left putamen'
# print(mask_filenames[2][7]) #lh-caudate
# print""
# print '8. left caudate'
# print(mask_filenames[2][8]) #lh-caudate
# print""
# print '9. right dlPFC-Lausanne'
# print(mask_filenames[2][9]) #rh-dlPFC-Lausanne
# print""
# print '10. right hippocampus'
# print(mask_filenames[2][10]) #rh-HPC
# print""
# print '11. right mPFC-orig'
# print(mask_filenames[2][11]) #rh-mPFC-orig
# print""
# print '12. right putamen'
# print(mask_filenames[2][12]) #rh-putamen
# print""
# print '13. right caudate'
# print(mask_filenames[2][13]) #rh-caudate
# print""
# print '14. right mPFC-FS-3'
# print(mask_filenames[2][14]) #rh-mPFC-FS-3
# print""
# print '15. right mPFC-Lausanne'
# print(mask_filenames[2][15]) #rh-mPFC-L
# print""
# print '16. right mPFC-rac-only'
# print(mask_filenames[2][16]) #rh-mPFC_rac
# print""
# print '17. right motor'
# print(mask_filenames[2][17]) #rh-motor
# print""
# print '18. left mPFC (rac-cac)'
# print(mask_filenames[2][18]) #lh-mPFC_rac-cac
# print""
# print '19. right mPFC (rac-cac)'
# print(mask_filenames[2][19]) #rh-mPFC_rac-cac
#
# #print '-----'
#
# #print 'cope_learning'
# #print(cope_files[0][0])
# #print ""
# #print 'cope_nonlearning'
# #print(cope_files[0][1])

# %% [markdown]
# ### Use binarized mask to obtain activation in left & right hemisphere for each ROI

# %%
import nibabel as nb
import pandas as pd
import numpy as np
from scipy import stats


#Dictionary containing multiple arrays referenced by keywords
all_data = {'subjid':[],
            'lh_hp_nonlearning':[], 'rh_hp_nonlearning':[], 
            'lh_hp_learning':[], 'rh_hp_learning':[],
            'lh_mPFC_nonlearning':[], 'rh_mPFC_nonlearning':[], 
            'lh_mPFC_learning':[], 'rh_mPFC_learning':[],
            
            'lh_caudate_nonlearning':[], 'rh_caudate_nonlearning':[], 
            'lh_caudate_learning':[], 'rh_caudate_learning':[],
            'lh_dlPFC_nonlearning':[], 'rh_dlPFC_nonlearning':[], 
            'lh_dlPFC_learning':[], 'rh_dlPFC_learning':[], 
            
            'lh_putamen_nonlearning':[], 'rh_putamen_nonlearning':[], 
            'lh_putamen_learning':[], 'rh_putamen_learning':[],             
            'lh_motor_nonlearning':[], 'rh_motor_nonlearning':[], 
            'lh_motor_learning':[], 'rh_motor_learning':[]}

corr_matrix = np.zeros((len(sids), 9))

# For each interation in the length of subject ids
for i in range(len(sids)):
    #Append the subject id
    all_data['subjid'].append(sids[i])
    #Load the left and right hippocampus mask files using Nibabel 
    lh_hp_img = nb.load(mask_filenames[i][1])
    rh_hp_img = nb.load(mask_filenames[i][10])
    lh_mPFC_img = nb.load(mask_filenames[i][18]) #FS-2
    rh_mPFC_img = nb.load(mask_filenames[i][19]) #FS-2
    #lh_mPFC_img = nb.load(mask_filenames[i][2]) #FS-3
    #rh_mPFC_img = nb.load(mask_filenames[i][14]) #FS-3
    lh_caudate_img = nb.load(mask_filenames[i][8])
    rh_caudate_img = nb.load(mask_filenames[i][13]) 
    lh_dlPFC_img = nb.load(mask_filenames[i][0])
    rh_dlPFC_img = nb.load(mask_filenames[i][9])    
    lh_putamen_img = nb.load(mask_filenames[i][7])
    rh_putamen_img = nb.load(mask_filenames[i][12])    
    lh_motor_img = nb.load(mask_filenames[i][6])
    rh_motor_img = nb.load(mask_filenames[i][17])
    
    #Load copes for learning vs nonlearning betas
    cope_learning_img = nb.load(cope_files[i][0])
    cope_nonlearning_img = nb.load(cope_files[i][1])
     
  
    ########################
    ### Left Hippocampus ###
    ########################
    
    # cope_nonlearning
    lh_hp_nonlearning_data = cope_nonlearning_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lh_hp_nonlearning'].append(lh_hp_nonlearning_data[0:-1])
    
    # cope_learning
    lh_hp_learning_data = cope_learning_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lh_hp_learning'].append(lh_hp_learning_data[0:-1])
    
    #########################
    ### Right Hippocampus ###
    #########################
    
    # cope_nonlearning
    rh_hp_nonlearning_data = cope_nonlearning_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rh_hp_nonlearning'].append(rh_hp_nonlearning_data[0:-1])

    # cope_learning
    rh_hp_learning_data = cope_learning_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rh_hp_learning'].append(rh_hp_learning_data[0:-1])
    
    #####################
    ### Left Caudate ###
    ##################### 
    
    # cope_nonlearning
    lh_caudate_nonlearning_data = cope_nonlearning_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lh_caudate_nonlearning'].append(lh_caudate_nonlearning_data[0:-1])

    # cope_learning
    lh_caudate_learning_data = cope_learning_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lh_caudate_learning'].append(lh_caudate_learning_data[0:-1])
    
    #####################
    ### Right Caudate ###
    ##################### 
    
    # cope_nonlearning
    rh_caudate_nonlearning_data = cope_nonlearning_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rh_caudate_nonlearning'].append(rh_caudate_nonlearning_data[0:-1])

    # cope_learning
    rh_caudate_learning_data = cope_learning_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rh_caudate_learning'].append(rh_caudate_learning_data[0:-1])  
    
    
    #####################
    ### Left Putamen ####
    ##################### 
    
    # cope_nonlearning
    lh_putamen_nonlearning_data = cope_nonlearning_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lh_putamen_nonlearning'].append(lh_putamen_nonlearning_data[0:-1])

    # cope_learning
    lh_putamen_learning_data = cope_learning_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lh_putamen_learning'].append(lh_putamen_learning_data[0:-1])
    
    #####################
    ### Right Putamen ###
    ##################### 
    
    # cope_nonlearning
    rh_putamen_nonlearning_data = cope_nonlearning_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rh_putamen_nonlearning'].append(rh_putamen_nonlearning_data[0:-1])

    # cope_learning
    rh_putamen_learning_data = cope_learning_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rh_putamen_learning'].append(rh_putamen_learning_data[0:-1])  
    
    
    ####################
    #### Left mPFC #####
    ####################
    
    # cope_nonlearning
    lh_mPFC_nonlearning_data = cope_nonlearning_img.get_data()[lh_mPFC_img.get_data() > 0.]
    all_data['lh_mPFC_nonlearning'].append(lh_mPFC_nonlearning_data[0:-1])
    
    # cope_learning
    lh_mPFC_learning_data = cope_learning_img.get_data()[lh_mPFC_img.get_data() > 0.]
    all_data['lh_mPFC_learning'].append(lh_mPFC_learning_data[0:-1])    
    
    #####################
    #### Right mPFC #####
    #####################
    
    # cope_nonlearning
    rh_mPFC_nonlearning_data = cope_nonlearning_img.get_data()[rh_mPFC_img.get_data() > 0.]
    all_data['rh_mPFC_nonlearning'].append(rh_mPFC_nonlearning_data[0:-1])

    # cope_learning
    rh_mPFC_learning_data = cope_learning_img.get_data()[rh_mPFC_img.get_data() > 0.]
    all_data['rh_mPFC_learning'].append(rh_mPFC_learning_data[0:-1]) 
    
    ####################
    #### Left dlPFC ####
    ####################
    
    # cope_nonlearning
    lh_dlPFC_nonlearning_data = cope_nonlearning_img.get_data()[lh_dlPFC_img.get_data() > 0.]
    all_data['lh_dlPFC_nonlearning'].append(lh_dlPFC_nonlearning_data[0:-1])
    
    # cope_learning
    lh_dlPFC_learning_data = cope_learning_img.get_data()[lh_dlPFC_img.get_data() > 0.]
    all_data['lh_dlPFC_learning'].append(lh_dlPFC_learning_data[0:-1])  
    
    #####################
    ### Right dlPFC ###
    #####################
    
    # cope_nonlearning
    rh_dlPFC_nonlearning_data = cope_nonlearning_img.get_data()[rh_dlPFC_img.get_data() > 0.]
    all_data['rh_dlPFC_nonlearning'].append(rh_dlPFC_nonlearning_data[0:-1])

    # cope_learning
    rh_dlPFC_learning_data = cope_learning_img.get_data()[rh_dlPFC_img.get_data() > 0.]
    all_data['rh_dlPFC_learning'].append(rh_dlPFC_learning_data[0:-1])    
    
    ####################
    #### Left motor ####
    ####################
    
    # cope_nonlearning
    lh_motor_nonlearning_data = cope_nonlearning_img.get_data()[lh_motor_img.get_data() > 0.]
    all_data['lh_motor_nonlearning'].append(lh_motor_nonlearning_data[0:-1])
    
    # cope_learning
    lh_motor_learning_data = cope_learning_img.get_data()[lh_motor_img.get_data() > 0.]
    all_data['lh_motor_learning'].append(lh_motor_learning_data[0:-1])    
    
    #####################
    #### Right motor ####
    #####################
    
    # cope_nonlearning
    rh_motor_nonlearning_data = cope_nonlearning_img.get_data()[rh_motor_img.get_data() > 0.]
    all_data['rh_motor_nonlearning'].append(rh_motor_nonlearning_data[0:-1])

    # cope_learning
    rh_motor_learning_data = cope_learning_img.get_data()[rh_motor_img.get_data() > 0.]
    all_data['rh_motor_learning'].append(rh_motor_learning_data[0:-1]) 

    
    
    #array with keys for each part of all_data dictionary
    all_keys = ['lh_hp_nonlearning', 'rh_hp_nonlearning', 
                'lh_hp_learning', 'rh_hp_learning',                 
                'lh_caudate_nonlearning', 'rh_caudate_nonlearning', 
                'lh_caudate_learning', 'rh_caudate_learning', 
                'lh_putamen_nonlearning', 'rh_putamen_nonlearning', 
                'lh_putamen_learning', 'rh_putamen_learning', 
                'lh_dlPFC_nonlearning', 'rh_dlPFC_nonlearning', 
                'lh_dlPFC_learning', 'rh_dlPFC_learning',            
                'lh_mPFC_nonlearning', 'rh_mPFC_nonlearning', 
                'lh_mPFC_learning', 'rh_mPFC_learning',
                'lh_motor_nonlearning', 'rh_motor_nonlearning', 
                'lh_motor_learning', 'rh_motor_learning']
    
    for key in all_keys: 
        # averaging each column for only the current participant 
        all_data[key][-1] = np.mean(all_data[key][-1], axis = 0)
       
    #Combined Hippocampus average for nonlearning and learning
    all_data['hp_nonlearning'] = (np.array(all_data['lh_hp_nonlearning'][-1]) + 
                                  np.array(all_data['rh_hp_nonlearning'][-1]))/2.
    all_data['hp_learning'] = (np.array(all_data['lh_hp_learning'][-1]) + 
                               np.array(all_data['rh_hp_learning'][-1]))/2.
                             
    #Combined Caudate average for nonlearning and learning
    all_data['caudate_nonlearning'] = (np.array(all_data['lh_caudate_nonlearning'][-1]) + 
                                       np.array(all_data['rh_caudate_nonlearning'][-1]))/2.
    all_data['caudate_learning'] = (np.array(all_data['lh_caudate_learning'][-1]) + 
                                    np.array(all_data['rh_caudate_learning'][-1]))/2.

    #Combined Putamen average for nonlearning and learning
    all_data['putamen_nonlearning'] = (np.array(all_data['lh_putamen_nonlearning'][-1]) + 
                                       np.array(all_data['rh_putamen_nonlearning'][-1]))/2.
    all_data['putamen_learning'] = (np.array(all_data['lh_putamen_learning'][-1]) + 
                                    np.array(all_data['rh_putamen_learning'][-1]))/2.
    
    # Combined mPFC average for nonlearning and learning
    all_data['mPFC_nonlearning'] = (np.array(all_data['lh_mPFC_nonlearning'][-1]) + 
                                    np.array(all_data['rh_mPFC_nonlearning'][-1]))/2.
    all_data['mPFC_learning'] = (np.array(all_data['lh_mPFC_learning'][-1]) + 
                                 np.array(all_data['rh_mPFC_learning'][-1]))/2.

    #Combined dlPFC average for nonlearning and learning
    all_data['dlPFC_nonlearning'] = (np.array(all_data['lh_dlPFC_nonlearning'][-1]) + 
                                     np.array(all_data['rh_dlPFC_nonlearning'][-1]))/2.
    all_data['dlPFC_learning'] = (np.array(all_data['lh_dlPFC_learning'][-1]) + 
                                  np.array(all_data['rh_dlPFC_learning'][-1]))/2. 
    
    # Combined motor average for nonlearning and learning
    all_data['motor_nonlearning'] = (np.array(all_data['lh_motor_nonlearning'][-1]) + 
                                     np.array(all_data['rh_motor_nonlearning'][-1]))/2.
    all_data['motor_learning'] = (np.array(all_data['lh_motor_learning'][-1]) + 
                                  np.array(all_data['rh_motor_learning'][-1]))/2.
    
    # Creation of the correlation matrix (with subject id column)
    corr_matrix[i][0] = float(sids[i][-3:])
    corr_matrix[i][1] = stats.pearsonr(all_data['hp_learning'], all_data['mPFC_learning'])[0]
    corr_matrix[i][2] = stats.pearsonr(all_data['hp_nonlearning'], all_data['mPFC_nonlearning'])[0]
    corr_matrix[i][3] = stats.pearsonr(all_data['caudate_learning'], all_data['dlPFC_learning'])[0]
    corr_matrix[i][4] = stats.pearsonr(all_data['caudate_nonlearning'], all_data['dlPFC_nonlearning'])[0]
    corr_matrix[i][5] = stats.pearsonr(all_data['putamen_learning'], all_data['motor_learning'])[0]
    corr_matrix[i][6] = stats.pearsonr(all_data['putamen_nonlearning'], all_data['motor_nonlearning'])[0]

# %% [markdown]
# ##  Non-normalized correlation matrix for beta series

# %%
import pandas as pd
#create Pandas dataframe to store correlations
correlation_chart = {}
correlation_chart['1_HPC-mPFC_learning'] = corr_matrix[:, 1] 
correlation_chart['2_HPC-mPFC_nonlearning'] = corr_matrix[:, 2] 
correlation_chart['3_Caudate-dlPFC_learning'] = corr_matrix[:, 3] 
correlation_chart['4_Caudate-dlPFC_nonlearning'] = corr_matrix[:, 4] 
correlation_chart['5_Putamen-motor_learning'] = corr_matrix[:, 5] 
correlation_chart['6_Putamen-motor_nonlearning'] = corr_matrix[:, 6] 

correlation_chart_df = pd.DataFrame.from_dict(correlation_chart)

# %%
correlation_chart_df
# Out:
#     1_HPC-mPFC_learning  2_HPC-mPFC_nonlearning  3_Caudate-dlPFC_learning  \
# 0              0.508444                0.478921                  0.427086
# 1              0.747364                0.749617                  0.614353
# 2              0.817648                0.480613                  0.812812
# 3              0.931644                0.724352                  0.313278
# 4              0.692399                0.709682                  0.594177
# 5              0.621397                0.773556                  0.539163
# 6              0.816153                0.825394                  0.867424
# 7              0.702042                0.484855                  0.391024
# 8              0.616525                0.578907                  0.487706
# 9              0.646764                0.496666                  0.477658
# 10             0.823889                0.762547                  0.734428
# 11             0.514831                0.510944                  0.197251
# 12             0.760122                0.796332                  0.570693
# 13             0.650514                0.547457                  0.568732
# 14             0.439548                0.235248                  0.635592
# 15             0.134789                0.177017                  0.775426
# 16             0.532527                0.537573                  0.634598
# 17             0.672190                0.448425                  0.711137
# 18             0.503019                0.389342                  0.508264
# 19             0.878521                0.914735                  0.893535
#
#     4_Caudate-dlPFC_nonlearning  5_Putamen-motor_learning  \
# 0                      0.322565                  0.637825
# 1                      0.752490                  0.799806
# 2                      0.590179                  0.824935
# 3                      0.490330                  0.925039
# 4                      0.409685                  0.845417
# 5                      0.615859                  0.377932
# 6                      0.872432                  0.830993
# 7                      0.435615                  0.646179
# 8                      0.638167                  0.700446
# 9                      0.035840                  0.541279
# 10                     0.788036                  0.728436
# 11                     0.555163                  0.602672
# 12                     0.586831                  0.574615
# 13                     0.443410                  0.789711
# 14                     0.592736                  0.677321
# 15                     0.696419                  0.736628
# 16                     0.429210                  0.784123
# 17                     0.731811                  0.754139
# 18                     0.510863                  0.521456
# 19                     0.908312                  0.904229
#
#     6_Putamen-motor_nonlearning
# 0                      0.719949
# 1                      0.794689
# 2                      0.648430
# 3                      0.718490
# 4                      0.606881
# 5                      0.465896
# 6                      0.832536
# 7                      0.579340
# 8                      0.629201
# 9                      0.585783
# 10                     0.792169
# 11                     0.605885
# 12                     0.648679
# 13                     0.710134
# 14                     0.474863
# 15                     0.756612
# 16                     0.598617
# 17                     0.780327
# 18                     0.640845
# 19                     0.932568

# %%
from math import sqrt
# %matplotlib inline
import seaborn as sns
sns.set_palette('muted')
import matplotlib.pyplot as plt

N = 6
conditions = ['HPC-mPFC_l', 'HPC-mPFC_n', 
              'Caud-dlPFC_l', 'Caud-dlPFC_n', 
              'Put-motor_l', 'Put-motor_n']
means_allsubjs = [np.average(correlation_chart['1_HPC-mPFC_learning']),
                  np.average(correlation_chart['2_HPC-mPFC_nonlearning']),
                  np.average(correlation_chart['3_Caudate-dlPFC_learning']),
                  np.average(correlation_chart['4_Caudate-dlPFC_nonlearning']),
                  np.average(correlation_chart['5_Putamen-motor_learning']),
                  np.average(correlation_chart['6_Putamen-motor_nonlearning'])]
sem_allsubjs = [stats.sem(correlation_chart['1_HPC-mPFC_learning']),
                stats.sem(correlation_chart['2_HPC-mPFC_nonlearning']),
                stats.sem(correlation_chart['3_Caudate-dlPFC_learning']),
                stats.sem(correlation_chart['4_Caudate-dlPFC_nonlearning']),
                stats.sem(correlation_chart['5_Putamen-motor_learning']),
                stats.sem(correlation_chart['6_Putamen-motor_nonlearning'])]

cohens_d = ((np.average(correlation_chart['1_HPC-mPFC_learning']) - np.average(correlation_chart['2_HPC-mPFC_nonlearning'])) 
            / (sqrt((np.std(correlation_chart['1_HPC-mPFC_learning'], ddof = 1)) 
            ** 2 + np.std(correlation_chart['2_HPC-mPFC_nonlearning'], ddof = 1) ** 2) / 2))

print "HPC-mPFC Learning:", np.mean(correlation_chart['1_HPC-mPFC_learning'])
print np.std(correlation_chart['1_HPC-mPFC_learning'])
print "HPC-mPFC Non-Learning:", np.mean(correlation_chart['2_HPC-mPFC_nonlearning'])
print np.std(correlation_chart['2_HPC-mPFC_nonlearning'])
print "DC-dlPFC Learning:", np.mean(correlation_chart['3_Caudate-dlPFC_learning'])
print np.std(correlation_chart['3_Caudate-dlPFC_learning'])
print "DC-dlPFC Non-Learning:", np.mean(correlation_chart['4_Caudate-dlPFC_nonlearning'])
print np.std(correlation_chart['4_Caudate-dlPFC_nonlearning'])
print "PUT-motor Learning:", np.mean(correlation_chart['5_Putamen-motor_learning'])
print np.std(correlation_chart['5_Putamen-motor_learning'])
print "PUT-motor Non-Learning:", np.mean(correlation_chart['6_Putamen-motor_nonlearning'])
print np.std(correlation_chart['6_Putamen-motor_nonlearning'])


print ""
print 'T-test: HPC-mPFC_learning vs. HPC-mPFC_nonlearning'
print stats.ttest_rel(correlation_chart['1_HPC-mPFC_learning'], correlation_chart['2_HPC-mPFC_nonlearning'])
print "Cohen's d =", cohens_d
print ""

print 'T-test: Caudate-dlPFC_learning vs. Caudate-dlPFC_nonlearning'
print stats.ttest_rel(correlation_chart['3_Caudate-dlPFC_learning'], correlation_chart['4_Caudate-dlPFC_nonlearning'])
print ""

print 'T-test: PUT-motor_learning vs. PUT-motor_nonlearning'
print stats.ttest_rel(correlation_chart['5_Putamen-motor_learning'], correlation_chart['6_Putamen-motor_nonlearning'])


ind = np.arange(N)
width = 0.5

fig, ax = plt.subplots(figsize=(12,5))

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax = sns.barplot(ind, means_allsubjs, yerr = sem_allsubjs, ecolor = 'black')

ax.set_xticks(ind)
ax.set_xticklabels(conditions)
ax.set_ylim(0.3,0.8)
ax.set_ylabel("Pearsons r")
#ax.set_xlabel("Regional Correlations")
ax.set_title("Non-Normalized R Values")
#plt.savefig("/home/data/madlab/scripts/wmaze/anal_MR_thesis/fixed_before_conditional/model3/1model3_2-3-2-5_bar.jpg")
plt.show()
# Out:
# HPC-mPFC Learning: 0.65051657185
# 0.177410419907
# HPC-mPFC Non-Learning: 0.581109277904
# 0.191687922386
# DC-dlPFC Learning: 0.587716811895
# 0.176545676154
# DC-dlPFC Non-Learning: 0.570297472179
# 0.196609388881
# PUT-motor Learning: 0.710159081221
# 0.135579986002
# PUT-motor Non-Learning: 0.676094773412
# 0.114650156604
#
# T-test: HPC-mPFC_learning vs. HPC-mPFC_nonlearning
# Ttest_relResult(statistic=2.5601039968075847, pvalue=0.019144047923293234)
# Cohen's d = 0.518018342708
#
# T-test: Caudate-dlPFC_learning vs. Caudate-dlPFC_nonlearning
# Ttest_relResult(statistic=0.452761209050692, pvalue=0.65584816727264728)
#
# T-test: PUT-motor_learning vs. PUT-motor_nonlearning
# Ttest_relResult(statistic=1.3527066342739789, pvalue=0.19202918226657656)

# %% [markdown]
# ## Hippocampus

# %%
print 'HPC-mPFC Learn: ', np.average(correlation_chart['1_HPC-mPFC_learning'])
print 'HPC-mPFC Nonlearn: ', np.average(correlation_chart['2_HPC-mPFC_nonlearning'])
cohens_d = ((np.average(correlation_chart['1_HPC-mPFC_learning']) - np.average(correlation_chart['2_HPC-mPFC_nonlearning'])) 
            / (sqrt((np.std(correlation_chart['1_HPC-mPFC_learning'], ddof = 1)) 
            ** 2 + np.std(correlation_chart['2_HPC-mPFC_nonlearning'], ddof = 1) ** 2) / 2))
print ""
print 'T-test: HPC-mPFC_learning vs. HPC-mPFC_nonlearning'
print stats.ttest_rel(correlation_chart['1_HPC-mPFC_learning'], correlation_chart['2_HPC-mPFC_nonlearning'])
print "Cohen's d =", cohens_d

N = 2
conditions = ['HPC-mPFC Learn', 'HPC-mPFC Nonlearn']

hp_allsubjs = [correlation_chart['1_HPC-mPFC_learning'],
                correlation_chart['2_HPC-mPFC_nonlearning']]

pal = ["#4fb745", "#c93b2e"] #outline  for bars
pal = sns.color_palette(pal)
pal2 = ["white", "white"] #color-fill for bars
pal2 = sns.color_palette(pal2)
ind = np.arange(N)   

fig, ax = plt.subplots(figsize = (5,4))
ax = sns.boxplot(data = hp_allsubjs, color = "#278fea", width = 0.3, linewidth = 2)
ax = sns.swarmplot(data = hp_allsubjs, color='.25')
ax.set_xticklabels(conditions)
ax.set_ylabel('')
#plt.savefig("/home/arenf001/model3LSShpc_activation.png", dpi = 1080)
plt.tight_layout()
# Out:
# HPC-mPFC Learn:  0.65051657185
# HPC-mPFC Nonlearn:  0.581109277904
#
# T-test: HPC-mPFC_learning vs. HPC-mPFC_nonlearning
# Ttest_relResult(statistic=2.5601039968075847, pvalue=0.019144047923293234)
# Cohen's d = 0.518018342708

# %%
print 'Caudate-dlPFC Learn: ', np.average(correlation_chart['3_Caudate-dlPFC_learning'])
print 'Caudate-dlPFC Nonlearn: ', np.average(correlation_chart['4_Caudate-dlPFC_nonlearning'])
cohens_d = ((np.average(correlation_chart['3_Caudate-dlPFC_learning']) 
             - np.average(correlation_chart['4_Caudate-dlPFC_nonlearning'])) 
            / (sqrt((np.std(correlation_chart['3_Caudate-dlPFC_learning'], ddof = 1)) 
            ** 2 + np.std(correlation_chart['4_Caudate-dlPFC_nonlearning'], ddof = 1) ** 2) / 2))
print ""
print 'T-test: Caudate-dlPFC_learning vs. Caudate-dlPFC_nonlearning'
print stats.ttest_rel(correlation_chart['3_Caudate-dlPFC_learning'], correlation_chart['4_Caudate-dlPFC_nonlearning'])
print "Cohen's d =", cohens_d

N = 2
conditions = ['Caudate-dlPFC Learn', 'Caudate-dlPFC Nonlearn']

caudate_allsubjs = [correlation_chart['3_Caudate-dlPFC_learning'],
                    correlation_chart['4_Caudate-dlPFC_nonlearning']]

pal = ["#4fb745", "#c93b2e"] #outline  for bars
pal = sns.color_palette(pal)
pal2 = ["white", "white"] #color-fill for bars
pal2 = sns.color_palette(pal2)
ind = np.arange(N)   

fig, ax = plt.subplots(figsize = (5,4))
ax = sns.boxplot(data = caudate_allsubjs, color = "#f9f96d", width = 0.3, linewidth = 2)
ax = sns.swarmplot(data = caudate_allsubjs, color='.25')
ax.set_xticklabels(conditions)
ax.set_ylabel('')
plt.tight_layout()
# Out:
# Caudate-dlPFC Learn:  0.587716811895
# Caudate-dlPFC Nonlearn:  0.570297472179
#
# T-test: Caudate-dlPFC_learning vs. Caudate-dlPFC_nonlearning
# Ttest_relResult(statistic=0.452761209050692, pvalue=0.65584816727264728)
# Cohen's d = 0.128505667916

# %%
print 'Putamen-motor Learn: ', np.average(correlation_chart['5_Putamen-motor_learning'])
print 'Putamen-motor Nonlearn: ', np.average(correlation_chart['6_Putamen-motor_nonlearning'])
cohens_d = ((np.average(correlation_chart['5_Putamen-motor_learning']) - 
             np.average(correlation_chart['6_Putamen-motor_nonlearning'])) 
            / (sqrt((np.std(correlation_chart['5_Putamen-motor_learning'], ddof = 1)) 
            ** 2 + np.std(correlation_chart['6_Putamen-motor_nonlearning'], ddof = 1) ** 2) / 2))
print ""
print 'T-test: Putamen-motor_learning vs. Putamen-motor_nonlearning'
print stats.ttest_rel(correlation_chart['5_Putamen-motor_learning'], correlation_chart['6_Putamen-motor_nonlearning'])
print "Cohen's d =", cohens_d

N = 2
conditions = ['Putamen-motor Learn', 'Putamen-motor Nonlearn']

putamen_allsubjs = [correlation_chart['5_Putamen-motor_learning'],
                    correlation_chart['6_Putamen-motor_nonlearning']]

pal = ["#4fb745", "#c93b2e"] #outline  for bars
pal = sns.color_palette(pal)
pal2 = ["white", "white"] #color-fill for bars
pal2 = sns.color_palette(pal2)
ind = np.arange(N)   

fig, ax = plt.subplots(figsize = (5,4))
ax = sns.boxplot(data = putamen_allsubjs, color = "#c34aef", width = 0.3, linewidth = 2)
ax = sns.swarmplot(data = putamen_allsubjs, color='.25')
ax.set_xticklabels(conditions)
ax.set_ylabel('')
plt.savefig("/home/arenf001/model3LSSput_activation.png", dpi = 1080)
plt.tight_layout()
# Out:
# Putamen-motor Learn:  0.710159081221
# Putamen-motor Nonlearn:  0.676094773412
#
# T-test: Putamen-motor_learning vs. Putamen-motor_nonlearning
# Ttest_relResult(statistic=1.3527066342739789, pvalue=0.19202918226657656)
# Cohen's d = 0.37398386049

# %%
print 'Mean'
print 'HPC-mPFC Learning: ', np.average(correlation_chart['1_HPC-mPFC_learning'])
print 'HPC-mPFC Nonlearning: ', np.average(correlation_chart['2_HPC-mPFC_nonlearning'])
print 'Caudate-dlPFC Learning: ', np.average(correlation_chart['3_Caudate-dlPFC_learning'])
print 'Caudate-dlPFC Nonlearning: ', np.average(correlation_chart['4_Caudate-dlPFC_nonlearning'])
print 'Putamen-motor Learning: ', np.average(correlation_chart['5_Putamen-motor_learning'])
print 'Putamen-motor Nonllearning: ', np.average(correlation_chart['6_Putamen-motor_nonlearning'])
print ""
print 'STD'
print 'HPC-mPFC Learning: ', np.std(correlation_chart['1_HPC-mPFC_learning'])
print 'HPC-mPFC Nonlearning: ', np.std(correlation_chart['2_HPC-mPFC_nonlearning'])
print 'Caudate-dlPFC Learning: ', np.std(correlation_chart['3_Caudate-dlPFC_learning'])
print 'Caudate-dlPFC Nonlearning: ', np.std(correlation_chart['4_Caudate-dlPFC_nonlearning'])
print 'Putamen-motor Learning: ', np.std(correlation_chart['5_Putamen-motor_learning'])
print 'Putamen-motor Nonllearning: ', np.std(correlation_chart['6_Putamen-motor_nonlearning'])
print ""

print 'HPC-mPFC Learning', stats.normaltest(correlation_chart['1_HPC-mPFC_learning'])[:]
print 'HPC-mPFC Nonlearning', stats.normaltest(correlation_chart['2_HPC-mPFC_nonlearning'])[:]
print ""
print 'Caudate-dlPFC Learning', stats.normaltest(correlation_chart['3_Caudate-dlPFC_learning'])[:]
print 'Caudate-dlPFC Nonlearning', stats.normaltest(correlation_chart['4_Caudate-dlPFC_nonlearning'])[:]
print ""
print 'Putamen-motor Learning', stats.normaltest(correlation_chart['5_Putamen-motor_learning'])[:]
print 'Putamen-motor Nonlearning', stats.normaltest(correlation_chart['6_Putamen-motor_nonlearning'])[:]
# Out:
# Mean
# HPC-mPFC Learning:  0.65051657185
# HPC-mPFC Nonlearning:  0.581109277904
# Caudate-dlPFC Learning:  0.587716811895
# Caudate-dlPFC Nonlearning:  0.570297472179
# Putamen-motor Learning:  0.710159081221
# Putamen-motor Nonllearning:  0.676094773412
#
# STD
# HPC-mPFC Learning:  0.177410419907
# HPC-mPFC Nonlearning:  0.191687922386
# Caudate-dlPFC Learning:  0.176545676154
# Caudate-dlPFC Nonlearning:  0.196609388881
# Putamen-motor Learning:  0.135579986002
# Putamen-motor Nonllearning:  0.114650156604
#
# HPC-mPFC Learning (7.0595082749569134, 0.029312121733339368)
# HPC-mPFC Nonlearning (0.39204357768144127, 0.82199432417966001)
#
# Caudate-dlPFC Learning (0.19189910740816166, 0.90850984586925476)
# Caudate-dlPFC Nonlearning (3.5667733657053282, 0.16806798936389331)
#
# Putamen-motor Learning (1.6560911093102293, 0.43690235418503487)
# Putamen-motor Nonlearning (0.20142810409723672, 0.90419154764392529)

# %% [markdown]
# ## Normalized correlation matrix for beta series

# %%
# Use Numpy's arctangent function to normalize correlations
norm_corr = np.arctanh(corr_matrix[:, 1:])
#print(norm_nonlearning)

# %%
import pandas as pd
norm_chart = {}
norm_chart['1_HPC-mPFC_learning'] = norm_corr[:, 0]
norm_chart['2_HPC-mPFC_nonlearning'] = norm_corr[:, 1] 
norm_chart['3_Caudate-dlPFC_learning'] = norm_corr[:, 2]
norm_chart['4_Caudate-dlPFC_nonlearning'] = norm_corr[:, 3]
norm_chart['5_Putamen-motor_learning'] = norm_corr[:, 4]
norm_chart['6_Putamen-motor_nonlearning'] = norm_corr[:, 5]
norm_chart_df = pd.DataFrame.from_dict(norm_chart)

# %%
norm_chart_df

# %% [markdown]
# ### Descriptive Statistics

# %%
print "Mean: HPC-mPFC_learning: ", np.average(norm_corr[:, 0])
print stats.sem(norm_corr[:, 0])
print ""
print "Mean: HPC-mPFC_nonlearning: ", np.average(norm_corr[:, 1])
print stats.sem(norm_corr[:, 1])
print ""
print "Mean: Caudate-dlPFC_learning: ", np.average(norm_corr[:, 2])
print stats.sem(norm_corr[:, 2])
print ""
print "Mean: Caudate-dlPFC_nonlearning: ", np.average(norm_corr[:, 3])
print stats.sem(norm_corr[:, 3])
print ""
print "Mean: Putamen-motor_learning: ", np.average(norm_corr[:, 4])
print stats.sem(norm_corr[:, 2])
print ""
print "Mean: Putamen-motor_nonlearning:", np.average(norm_corr[:, 5])
print stats.sem(norm_corr[:, 3])

# %% [markdown]
# ### Inferential Statistics

# %%
print 'T-test: HPC-mPFC_learning vs. HPC-mPFC_nonlearning'
print stats.ttest_rel(norm_corr[:, 0], norm_corr[:, 1])
print ""

print 'T-test: Caudate-dlPFC_learning vs. Caudate-dlPFC_nonlearning'
print stats.ttest_rel(norm_corr[:, 2], norm_corr[:, 3])
print ""

print 'T-test: Putamen-motor_learning vs. Putamen-motor_nonlearning'
print stats.ttest_rel(norm_corr[:, 4], norm_corr[:, 5])
print ""

print "Bonferroni correction"
print '0.05/2 = 0.025'

# %% [markdown]
# ## Scatterplots

# %%
ax = []
for a in range(0,115,1):
    ax.append(a)
x = ax

y = all_data['hp_learning']
z = all_data['mPFC_learning']

fig, (ax, ax2) = plt.subplots(ncols = 2, figsize=(9, 4), sharex = True, sharey = True)
ax.plot(x, y, color = 'blue')
ax.set_ylabel('Activation')
ax.set_xlabel('Trials')
ax.set_title('HPC Activation Across Learning Trials')

ax2.plot(x, z, color = 'purple')
ax2.set_ylabel('Activation')
ax2.set_xlabel('Trials')
ax2.set_title('mPFC Activation Across Learning Trials')
plt.tight_layout()

# %%
ax = []
for a in range(0,115,1):
    ax.append(a)
x = ax

y = all_data['caudate_learning']
z = all_data['dlPFC_learning']

fig, (ax, ax2) = plt.subplots(ncols = 2, figsize=(9, 4), sharex = True, sharey = True)
ax.plot(x, y, color = 'blue')
ax.set_ylabel('Activation')
ax.set_xlabel('Trials')
ax.set_title('Caudate Activation Across Learning Trials')

ax2.plot(x, z, color = 'purple')
ax2.set_ylabel('Activation')
ax2.set_xlabel('Trials')
ax2.set_title('dlPFC Activation Across Learning Trials')
plt.tight_layout()

# %%
ax = []
for a in range(0,115,1):
    ax.append(a)
x = ax

y = all_data['putamen_learning']
z = all_data['motor_learning']

fig, (ax, ax2) = plt.subplots(ncols = 2, figsize=(9, 4), sharex = True, sharey = True)
ax.plot(x, y, color = 'blue')
ax.set_ylabel('Activation')
ax.set_xlabel('Trials')
ax.set_title('Putamen Activation Across Learning Trials')

ax2.plot(x, z, color = 'purple')
ax2.set_ylabel('Activation')
ax2.set_xlabel('Trials')
ax2.set_title('Motor Activation Across Learning Trials')
plt.tight_layout()
