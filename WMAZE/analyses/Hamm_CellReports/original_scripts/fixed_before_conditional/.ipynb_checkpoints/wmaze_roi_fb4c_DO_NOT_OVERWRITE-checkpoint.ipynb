# %% [markdown]
# # Creation of the region-specific masks using Freesurfer's Binarize

# %% [markdown]
# ### Masks for hippocampus  using FS aparc+aseg

# %%
import nipype.pipeline as pe
import nipype.interfaces.io as nio
import os
import nipype.interfaces.freesurfer as fs
from nipype import IdentityInterface

subjects_dir = '/home/data/madlab/surfaces/wmaze'
work_dir = '/scratch/madlab/wmaze/regions_workdir'
sink_dir = '/home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c/mask'

sids = ['WMAZE_001', 'WMAZE_002', 'WMAZE_004', 'WMAZE_005', 'WMAZE_006', 'WMAZE_007',
        'WMAZE_008', 'WMAZE_009', 'WMAZE_010', 'WMAZE_012', 'WMAZE_017', 'WMAZE_018',
        'WMAZE_019', 'WMAZE_020', 'WMAZE_021', 'WMAZE_022', 'WMAZE_023', 'WMAZE_024',
        'WMAZE_026', 'WMAZE_027']

wf = pe.Workflow(name = 'wf')
wf.base_dir = work_dir

# Node: subject_iterable
subj_iterable = pe.Node(IdentityInterface(fields = ['subject_id'], 
                                          mandatory_inputs = True),
                        name = 'subj_iterable')
subj_iterable.iterables = ('subject_id', sids)

info = dict(ref_epi_file = [['subject_id']],
            bbreg_xfm = [['subject_id']],
            aparc_aseg = [['subject_id']])

# Node: Datagrabber
datasource = pe.Node(nio.DataGrabber(infields = ['subject_id'],
                                     outfields = info.keys()),
                     name = 'datasource')
datasource.inputs.base_directory = os.path.abspath('/home/data/madlab/')
datasource.inputs.field_template = dict(ref_epi_file = 'data/mri/wmaze/preproc/%s/ref/*.nii.gz',
                                        bbreg_xfm = 'data/mri/wmaze/preproc/%s/bbreg/_fs_register0/*.dat',
                                        aparc_aseg = 'surfaces/wmaze/%s/mri/aparc+aseg.mgz')
datasource.inputs.template = '*'
datasource.inputs.template_args = info
datasource.inputs.sort_filelist = True
datasource.inputs.ignore_exception = False
datasource.inputs.raise_on_empty = True
wf.connect(subj_iterable, 'subject_id', datasource, 'subject_id')

#### subj_iterable (subject_id) ----> datasource (subject_id)


# MapNode: Create binarized ROI masks
anat_mask = pe.MapNode(fs.Binarize(),
                       iterfield = ['match', 'binary_file'], 
                       name = 'anat_mask')
anat_mask.inputs.match = [[17],[53]] #hippocampus
anat_mask.inputs.binary_file = ['lh-hippocampus.nii.gz','rh-hippocampus.nii.gz']
wf.connect(datasource, 'aparc_aseg', anat_mask, 'in_file')

#### datasource (aparc_aseg) ----> anat_mask (in_file)


# MapNode: Transform the masks to 1st volume of 1st run (EPI space)
anatmask_xfm = pe.MapNode(fs.ApplyVolTransform(inverse = True,
                                               interp = 'nearest'),
                          iterfield = ['target_file'],
                          name = 'anatmask_xfm')
anatmask_xfm.inputs.subjects_dir = subjects_dir
wf.connect(datasource, 'ref_epi_file', anatmask_xfm, 'source_file')
wf.connect(datasource, 'bbreg_xfm', anatmask_xfm, 'reg_file')
wf.connect(anat_mask, 'binary_file', anatmask_xfm, 'target_file')

#### datasource (ref_epi_file) ----> anatmask_xfm (source_file)
#### datasource (bbreg_xfm) ----> anatmask_xfm (reg_file)
#### datasource (binary_file) ----> anatmask_xfm (target_file)


# Node: Datasink
sinker = pe.Node(nio.DataSink(infields = None),
                 name = "sinker")
sinker.inputs._outputs = {}
sinker.inputs.base_directory = sink_dir
sinker.inputs.ignore_exception = False
sinker.inputs.parameterization = True
sinker.inputs.remove_dest_dir = False
wf.connect(anatmask_xfm, 'transformed_file', sinker, 'anat_masks')

#### anatmask_xfm (transformed_file) ----> sinker (anat_masks)

wf.run(plugin = 'LSF', plugin_args = {'bsub_args': '-q PQ_madlab'})
# Out:
# 170817-03:43:38,793 workflow INFO:
# 	 ['check', 'execution', 'logging']
# 170817-03:43:39,141 workflow INFO:
# 	 Running in parallel.
# 170817-03:43:39,153 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 170817-03:43:39,155 workflow INFO:
# 	 Submitting: datasource.a03 ID: 0
# 170817-03:43:39,341 workflow INFO:
# 	 Finished submitting: datasource.a03 ID: 0
# 170817-03:43:39,345 workflow INFO:
# 	 Submitting: datasource.a08 ID: 1
# 170817-03:43:39,497 workflow INFO:
# 	 Finished submitting: datasource.a08 ID: 1
# 170817-03:43:39,500 workflow INFO:
# 	 Submitting: datasource.a17 ID: 3
# 170817-03:43:39,650 workflow INFO:
# 	 Finished submitting: datasource.a17 ID: 3
# 170817-03:43:39,653 workflow INFO:
# 	 Submitting: datasource.a02 ID: 7
# 170817-03:43:39,806 workflow INFO:
# 	 Finished submitting: datasource.a02 ID: 7
# 170817-03:43:39,810 workflow INFO:
# 	 Submitting: datasource.a16 ID: 9
# 170817-03:43:39,991 workflow INFO:
# 	 Finished submitting: datasource.a16 ID: 9
# 170817-03:43:39,995 workflow INFO:
# 	 Submitting: datasource.a07 ID: 12
# 170817-03:43:40,148 workflow INFO:
# 	 Finished submitting: datasource.a07 ID: 12
# 170817-03:43:40,151 workflow INFO:
# 	 Submitting: datasource.a15 ID: 18
# 170817-03:43:40,306 workflow INFO:
# 	 Finished submitting: datasource.a15 ID: 18
# 170817-03:43:40,310 workflow INFO:
# 	 Submitting: datasource.a01 ID: 19
# 170817-03:43:40,463 workflow INFO:
# 	 Finished submitting: datasource.a01 ID: 19
# 170817-03:43:40,467 workflow INFO:
# 	 Submitting: datasource.a06 ID: 24
# 170817-03:43:40,616 workflow INFO:
# 	 Finished submitting: datasource.a06 ID: 24
# 170817-03:43:40,619 workflow INFO:
# 	 Submitting: datasource.a14 ID: 28
# 170817-03:43:40,770 workflow INFO:
# 	 Finished submitting: datasource.a14 ID: 28
# 170817-03:43:40,774 workflow INFO:
# 	 Submitting: datasource.a00 ID: 32
# 170817-03:43:40,926 workflow INFO:
# 	 Finished submitting: datasource.a00 ID: 32
# 170817-03:43:40,929 workflow INFO:
# 	 Submitting: datasource.a10 ID: 36
# 170817-03:43:41,78 workflow INFO:
# 	 Finished submitting: datasource.a10 ID: 36
# 170817-03:43:41,81 workflow INFO:
# 	 Submitting: datasource.a13 ID: 38
# 170817-03:43:41,229 workflow INFO:
# 	 Finished submitting: datasource.a13 ID: 38
# 170817-03:43:41,232 workflow INFO:
# 	 Submitting: datasource.a05 ID: 44
# 170817-03:43:41,385 workflow INFO:
# 	 Finished submitting: datasource.a05 ID: 44
# 170817-03:43:41,388 workflow INFO:
# 	 Submitting: datasource.a04 ID: 48
# 170817-03:43:41,554 workflow INFO:
# 	 Finished submitting: datasource.a04 ID: 48
# 170817-03:43:41,557 workflow INFO:
# 	 Submitting: datasource.a12 ID: 50
# 170817-03:43:41,705 workflow INFO:
# 	 Finished submitting: datasource.a12 ID: 50
# 170817-03:43:41,709 workflow INFO:
# 	 Submitting: datasource.a09 ID: 57
# 170817-03:43:41,866 workflow INFO:
# 	 Finished submitting: datasource.a09 ID: 57
# 170817-03:43:41,870 workflow INFO:
# 	 Submitting: datasource.a18 ID: 62
# 170817-03:43:42,19 workflow INFO:
# 	 Finished submitting: datasource.a18 ID: 62
# 170817-03:43:42,23 workflow INFO:
# 	 Submitting: datasource.a11 ID: 69
# 170817-03:43:42,176 workflow INFO:
# 	 Finished submitting: datasource.a11 ID: 69
# 170817-03:43:42,180 workflow INFO:
# 	 Submitting: datasource.a19 ID: 76
# 170817-03:43:42,333 workflow INFO:
# 	 Finished submitting: datasource.a19 ID: 76
# 170817-03:44:43,110 workflow INFO:
# 	 [Job finished] jobname: datasource.a03 jobid: 0
# 170817-03:44:43,535 workflow INFO:
# 	 [Job finished] jobname: datasource.a08 jobid: 1
# 170817-03:44:43,966 workflow INFO:
# 	 [Job finished] jobname: datasource.a17 jobid: 3
# 170817-03:44:44,521 workflow INFO:
# 	 [Job finished] jobname: datasource.a02 jobid: 7
# 170817-03:44:44,664 workflow INFO:
# 	 [Job finished] jobname: datasource.a16 jobid: 9
# 170817-03:44:44,804 workflow INFO:
# 	 [Job finished] jobname: datasource.a07 jobid: 12
# 170817-03:44:44,946 workflow INFO:
# 	 [Job finished] jobname: datasource.a15 jobid: 18
# 170817-03:44:45,89 workflow INFO:
# 	 [Job finished] jobname: datasource.a01 jobid: 19
# 170817-03:44:45,226 workflow INFO:
# 	 [Job finished] jobname: datasource.a06 jobid: 24
# 170817-03:44:45,368 workflow INFO:
# 	 [Job finished] jobname: datasource.a14 jobid: 28
# 170817-03:44:45,509 workflow INFO:
# 	 [Job finished] jobname: datasource.a00 jobid: 32
# 170817-03:44:45,643 workflow INFO:
# 	 [Job finished] jobname: datasource.a10 jobid: 36
# 170817-03:44:45,786 workflow INFO:
# 	 [Job finished] jobname: datasource.a13 jobid: 38
# 170817-03:44:45,926 workflow INFO:
# 	 [Job finished] jobname: datasource.a05 jobid: 44
# 170817-03:44:46,68 workflow INFO:
# 	 [Job finished] jobname: datasource.a04 jobid: 48
# 170817-03:44:46,209 workflow INFO:
# 	 [Job finished] jobname: datasource.a12 jobid: 50
# 170817-03:44:46,371 workflow INFO:
# 	 [Job finished] jobname: datasource.a09 jobid: 57
# 170817-03:44:46,511 workflow INFO:
# 	 [Job finished] jobname: datasource.a18 jobid: 62
# 170817-03:44:46,650 workflow INFO:
# 	 [Job finished] jobname: datasource.a11 jobid: 69
# 170817-03:44:46,786 workflow INFO:
# 	 [Job finished] jobname: datasource.a19 jobid: 76
# 170817-03:44:46,796 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 170817-03:44:46,832 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a08
# 170817-03:44:46,878 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a17
# 170817-03:44:46,921 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a02
# 170817-03:44:46,963 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a16
# 170817-03:44:47,8 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a07
# 170817-03:44:47,51 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a01
# 170817-03:44:47,95 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a06
# 170817-03:44:47,139 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a14
# 170817-03:44:47,181 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a00
# 170817-03:44:47,227 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a10
# 170817-03:44:47,270 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a13
# 170817-03:44:47,314 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a05
# 170817-03:44:47,360 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a04
# 170817-03:44:47,403 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a12
# 170817-03:44:47,445 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a15
# 170817-03:44:47,485 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a09
# 170817-03:44:47,527 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a18
# 170817-03:44:47,567 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a11
# 170817-03:44:47,611 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a03
# 170817-03:44:47,651 workflow INFO:
# 	 Adding 2 jobs for mapnode anat_mask.a19
# 170817-03:44:47,664 workflow INFO:
# 	 Pending[0] Submitting[40] jobs Slots[inf]
# 170817-03:44:47,666 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 80
# 170817-03:44:47,818 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 80
# 170817-03:44:47,822 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 81
# 170817-03:44:47,970 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 81
# 170817-03:44:47,973 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 82
# 170817-03:44:48,131 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 82
# 170817-03:44:48,134 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 83
# 170817-03:44:48,283 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 83
# 170817-03:44:48,286 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 84
# 170817-03:44:48,437 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 84
# 170817-03:44:48,440 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 85
# 170817-03:44:48,585 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 85
# 170817-03:44:48,589 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 86
# 170817-03:44:48,740 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 86
# 170817-03:44:48,743 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 87
# 170817-03:44:48,900 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 87
# 170817-03:44:48,903 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 88
# 170817-03:44:49,54 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 88
# 170817-03:44:49,58 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 89
# 170817-03:44:49,208 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 89
# 170817-03:44:49,212 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 90
# 170817-03:44:49,366 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 90
# 170817-03:44:49,370 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 91
# 170817-03:44:49,514 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 91
# 170817-03:44:49,518 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 92
# 170817-03:44:49,669 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 92
# 170817-03:44:49,673 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 93
# 170817-03:44:49,820 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 93
# 170817-03:44:49,824 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 94
# 170817-03:44:49,984 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 94
# 170817-03:44:49,987 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 95
# 170817-03:44:50,205 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 95
# 170817-03:44:50,208 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 96
# 170817-03:44:50,376 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 96
# 170817-03:44:50,379 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 97
# 170817-03:44:50,531 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 97
# 170817-03:44:50,534 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 98
# 170817-03:44:50,688 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 98
# 170817-03:44:50,692 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 99
# 170817-03:44:50,837 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 99
# 170817-03:44:50,840 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 100
# 170817-03:44:51,3 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 100
# 170817-03:44:51,7 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 101
# 170817-03:44:51,156 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 101
# 170817-03:44:51,160 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 102
# 170817-03:44:51,311 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 102
# 170817-03:44:51,315 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 103
# 170817-03:44:51,472 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 103
# 170817-03:44:51,475 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 104
# 170817-03:44:51,629 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 104
# 170817-03:44:51,633 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 105
# 170817-03:44:51,780 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 105
# 170817-03:44:51,783 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 106
# 170817-03:44:51,933 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 106
# 170817-03:44:51,937 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 107
# 170817-03:44:52,81 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 107
# 170817-03:44:52,85 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 108
# 170817-03:44:52,236 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 108
# 170817-03:44:52,239 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 109
# 170817-03:44:52,385 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 109
# 170817-03:44:52,388 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 110
# 170817-03:44:52,539 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 110
# 170817-03:44:52,543 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 111
# 170817-03:44:52,709 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 111
# 170817-03:44:52,713 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 112
# 170817-03:44:52,870 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 112
# 170817-03:44:52,874 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 113
# 170817-03:44:53,32 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 113
# 170817-03:44:53,35 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 114
# 170817-03:44:53,191 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 114
# 170817-03:44:53,194 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 115
# 170817-03:44:53,341 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 115
# 170817-03:44:53,344 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 116
# 170817-03:44:53,498 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 116
# 170817-03:44:53,502 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 117
# 170817-03:44:53,653 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 117
# 170817-03:44:53,657 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 118
# 170817-03:44:53,831 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 118
# 170817-03:44:53,835 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 119
# 170817-03:44:53,982 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 119
# 170817-03:45:54,212 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 80
# 170817-03:45:54,354 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 81
# 170817-03:45:54,501 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 82
# 170817-03:45:54,637 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 83
# 170817-03:45:54,779 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 84
# 170817-03:45:54,917 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 85
# 170817-03:45:55,59 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 86
# 170817-03:45:55,195 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 87
# 170817-03:45:55,337 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 88
# 170817-03:45:55,472 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 89
# 170817-03:45:55,613 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 90
# 170817-03:45:55,752 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 91
# 170817-03:45:55,894 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 92
# 170817-03:45:56,30 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 93
# 170817-03:45:56,170 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 94
# 170817-03:45:56,299 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 95
# 170817-03:45:56,439 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 96
# 170817-03:45:56,606 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 97
# 170817-03:45:56,752 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 98
# 170817-03:45:56,888 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 99
# 170817-03:45:57,24 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 100
# 170817-03:45:57,157 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 101
# 170817-03:45:57,298 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 102
# 170817-03:45:57,435 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 103
# 170817-03:45:57,573 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 104
# 170817-03:45:57,706 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 105
# 170817-03:45:57,848 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 106
# 170817-03:45:57,986 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 107
# 170817-03:45:58,118 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 108
# 170817-03:45:58,256 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 109
# 170817-03:45:58,401 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 110
# 170817-03:45:58,540 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 111
# 170817-03:45:58,684 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 112
# 170817-03:45:58,820 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 113
# 170817-03:45:58,959 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 114
# 170817-03:45:59,95 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 115
# 170817-03:45:59,241 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 116
# 170817-03:45:59,379 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 117
# 170817-03:45:59,520 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 118
# 170817-03:45:59,652 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 119
# 170817-03:45:59,660 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 170817-03:45:59,663 workflow INFO:
# 	 Submitting: anat_mask.a08 ID: 2
# 170817-03:45:59,834 workflow INFO:
# 	 Finished submitting: anat_mask.a08 ID: 2
# 170817-03:45:59,838 workflow INFO:
# 	 Submitting: anat_mask.a17 ID: 6
# 170817-03:45:59,995 workflow INFO:
# 	 Finished submitting: anat_mask.a17 ID: 6
# 170817-03:45:59,998 workflow INFO:
# 	 Submitting: anat_mask.a02 ID: 8
# 170817-03:46:00,154 workflow INFO:
# 	 Finished submitting: anat_mask.a02 ID: 8
# 170817-03:46:00,158 workflow INFO:
# 	 Submitting: anat_mask.a16 ID: 10
# 170817-03:46:00,310 workflow INFO:
# 	 Finished submitting: anat_mask.a16 ID: 10
# 170817-03:46:00,314 workflow INFO:
# 	 Submitting: anat_mask.a07 ID: 13
# 170817-03:46:00,470 workflow INFO:
# 	 Finished submitting: anat_mask.a07 ID: 13
# 170817-03:46:00,474 workflow INFO:
# 	 Submitting: anat_mask.a01 ID: 20
# 170817-03:46:00,630 workflow INFO:
# 	 Finished submitting: anat_mask.a01 ID: 20
# 170817-03:46:00,634 workflow INFO:
# 	 Submitting: anat_mask.a06 ID: 25
# 170817-03:46:00,791 workflow INFO:
# 	 Finished submitting: anat_mask.a06 ID: 25
# 170817-03:46:00,795 workflow INFO:
# 	 Submitting: anat_mask.a14 ID: 29
# 170817-03:46:00,952 workflow INFO:
# 	 Finished submitting: anat_mask.a14 ID: 29
# 170817-03:46:00,955 workflow INFO:
# 	 Submitting: anat_mask.a00 ID: 33
# 170817-03:46:01,105 workflow INFO:
# 	 Finished submitting: anat_mask.a00 ID: 33
# 170817-03:46:01,109 workflow INFO:
# 	 Submitting: anat_mask.a10 ID: 37
# 170817-03:46:01,262 workflow INFO:
# 	 Finished submitting: anat_mask.a10 ID: 37
# 170817-03:46:01,266 workflow INFO:
# 	 Submitting: anat_mask.a13 ID: 39
# 170817-03:46:01,417 workflow INFO:
# 	 Finished submitting: anat_mask.a13 ID: 39
# 170817-03:46:01,421 workflow INFO:
# 	 Submitting: anat_mask.a05 ID: 45
# 170817-03:46:01,571 workflow INFO:
# 	 Finished submitting: anat_mask.a05 ID: 45
# 170817-03:46:01,574 workflow INFO:
# 	 Submitting: anat_mask.a04 ID: 49
# 170817-03:46:01,740 workflow INFO:
# 	 Finished submitting: anat_mask.a04 ID: 49
# 170817-03:46:01,744 workflow INFO:
# 	 Submitting: anat_mask.a12 ID: 51
# 170817-03:46:01,896 workflow INFO:
# 	 Finished submitting: anat_mask.a12 ID: 51
# 170817-03:46:01,900 workflow INFO:
# 	 Submitting: anat_mask.a15 ID: 54
# 170817-03:46:02,50 workflow INFO:
# 	 Finished submitting: anat_mask.a15 ID: 54
# 170817-03:46:02,54 workflow INFO:
# 	 Submitting: anat_mask.a09 ID: 58
# 170817-03:46:02,232 workflow INFO:
# 	 Finished submitting: anat_mask.a09 ID: 58
# 170817-03:46:02,236 workflow INFO:
# 	 Submitting: anat_mask.a18 ID: 66
# 170817-03:46:02,403 workflow INFO:
# 	 Finished submitting: anat_mask.a18 ID: 66
# 170817-03:46:02,407 workflow INFO:
# 	 Submitting: anat_mask.a11 ID: 70
# 170817-03:46:02,562 workflow INFO:
# 	 Finished submitting: anat_mask.a11 ID: 70
# 170817-03:46:02,566 workflow INFO:
# 	 Submitting: anat_mask.a03 ID: 73
# 170817-03:46:02,720 workflow INFO:
# 	 Finished submitting: anat_mask.a03 ID: 73
# 170817-03:46:02,724 workflow INFO:
# 	 Submitting: anat_mask.a19 ID: 77
# 170817-03:46:02,878 workflow INFO:
# 	 Finished submitting: anat_mask.a19 ID: 77
# 170817-03:47:03,169 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a08 jobid: 2
# 170817-03:47:03,326 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a17 jobid: 6
# 170817-03:47:03,487 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a02 jobid: 8
# 170817-03:47:03,648 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a16 jobid: 10
# 170817-03:47:03,808 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a07 jobid: 13
# 170817-03:47:03,967 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a01 jobid: 20
# 170817-03:47:04,131 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a06 jobid: 25
# 170817-03:47:04,290 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a14 jobid: 29
# 170817-03:47:04,449 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a00 jobid: 33
# 170817-03:47:04,609 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a10 jobid: 37
# 170817-03:47:04,763 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a13 jobid: 39
# 170817-03:47:04,922 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a05 jobid: 45
# 170817-03:47:05,80 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a04 jobid: 49
# 170817-03:47:05,236 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a12 jobid: 51
# 170817-03:47:05,391 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a15 jobid: 54
# 170817-03:47:05,551 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a09 jobid: 58
# 170817-03:47:05,707 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a18 jobid: 66
# 170817-03:47:05,867 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a11 jobid: 70
# 170817-03:47:06,25 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a03 jobid: 73
# 170817-03:47:06,178 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a19 jobid: 77
# 170817-03:47:06,188 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 170817-03:47:06,291 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a08
# 170817-03:47:06,404 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a16
# 170817-03:47:06,516 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a02
# 170817-03:47:06,629 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a07
# 170817-03:47:06,741 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a17
# 170817-03:47:06,852 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a01
# 170817-03:47:06,964 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a06
# 170817-03:47:07,76 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a00
# 170817-03:47:07,190 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a13
# 170817-03:47:07,302 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a10
# 170817-03:47:07,414 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a05
# 170817-03:47:07,515 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a12
# 170817-03:47:07,611 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a15
# 170817-03:47:07,708 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a14
# 170817-03:47:07,805 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a04
# 170817-03:47:07,904 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a09
# 170817-03:47:07,997 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a18
# 170817-03:47:08,83 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a11
# 170817-03:47:08,170 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a03
# 170817-03:47:08,258 workflow INFO:
# 	 Adding 2 jobs for mapnode anatmask_xfm.a19
# 170817-03:47:08,269 workflow INFO:
# 	 Pending[0] Submitting[40] jobs Slots[inf]
# 170817-03:47:08,271 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 120
# 170817-03:47:08,443 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 120
# 170817-03:47:08,447 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 121
# 170817-03:47:08,594 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 121
# 170817-03:47:08,597 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 122
# 170817-03:47:08,750 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 122
# 170817-03:47:08,754 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 123
# 170817-03:47:08,903 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 123
# 170817-03:47:08,907 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 124
# 170817-03:47:09,78 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 124
# 170817-03:47:09,82 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 125
# 170817-03:47:09,227 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 125
# 170817-03:47:09,231 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 126
# 170817-03:47:09,382 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 126
# 170817-03:47:09,385 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 127
# 170817-03:47:09,531 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 127
# 170817-03:47:09,534 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 128
# 170817-03:47:09,685 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 128
# 170817-03:47:09,688 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 129
# 170817-03:47:09,832 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 129
# 170817-03:47:09,836 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 130
# 170817-03:47:09,987 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 130
# 170817-03:47:09,991 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 131
# 170817-03:47:10,268 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 131
# 170817-03:47:10,272 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 132
# 170817-03:47:10,426 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 132
# 170817-03:47:10,430 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 133
# 170817-03:47:10,573 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 133
# 170817-03:47:10,577 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 134
# 170817-03:47:10,718 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 134
# 170817-03:47:10,722 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 135
# 170817-03:47:10,865 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 135
# 170817-03:47:10,869 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 136
# 170817-03:47:11,31 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 136
# 170817-03:47:11,34 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 137
# 170817-03:47:11,184 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 137
# 170817-03:47:11,188 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 138
# 170817-03:47:11,339 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 138
# 170817-03:47:11,343 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 139
# 170817-03:47:11,497 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 139
# 170817-03:47:11,500 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 140
# 170817-03:47:11,661 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 140
# 170817-03:47:11,665 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 141
# 170817-03:47:11,816 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 141
# 170817-03:47:11,819 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 142
# 170817-03:47:11,971 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 142
# 170817-03:47:11,975 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 143
# 170817-03:47:12,128 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 143
# 170817-03:47:12,132 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 144
# 170817-03:47:12,307 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 144
# 170817-03:47:12,311 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 145
# 170817-03:47:12,459 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 145
# 170817-03:47:12,462 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 146
# 170817-03:47:12,607 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 146
# 170817-03:47:12,610 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 147
# 170817-03:47:12,745 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 147
# 170817-03:47:12,748 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 148
# 170817-03:47:12,883 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 148
# 170817-03:47:12,886 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 149
# 170817-03:47:13,37 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 149
# 170817-03:47:13,40 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 150
# 170817-03:47:13,197 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 150
# 170817-03:47:13,200 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 151
# 170817-03:47:13,348 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 151
# 170817-03:47:13,351 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 152
# 170817-03:47:13,481 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 152
# 170817-03:47:13,485 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 153
# 170817-03:47:13,600 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 153
# 170817-03:47:13,604 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 154
# 170817-03:47:13,723 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 154
# 170817-03:47:13,726 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 155
# 170817-03:47:13,847 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 155
# 170817-03:47:13,850 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 156
# 170817-03:47:13,979 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 156
# 170817-03:47:13,983 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 157
# 170817-03:47:14,148 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 157
# 170817-03:47:14,152 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 158
# 170817-03:47:14,326 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 158
# 170817-03:47:14,329 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 159
# 170817-03:47:14,481 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 159
# 170817-03:48:14,726 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 120
# 170817-03:48:14,872 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 121
# 170817-03:48:15,18 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 122
# 170817-03:48:15,154 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 123
# 170817-03:48:15,292 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 124
# 170817-03:48:15,424 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 125
# 170817-03:48:15,565 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 126
# 170817-03:48:15,704 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 127
# 170817-03:48:15,856 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 128
# 170817-03:48:15,995 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 129
# 170817-03:48:16,134 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 130
# 170817-03:48:16,277 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 131
# 170817-03:48:16,415 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 132
# 170817-03:48:16,556 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 133
# 170817-03:48:16,699 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 134
# 170817-03:48:16,843 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 135
# 170817-03:48:16,989 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 136
# 170817-03:48:17,128 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 137
# 170817-03:48:17,277 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 138
# 170817-03:48:17,410 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 139
# 170817-03:48:17,553 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 140
# 170817-03:48:17,700 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 141
# 170817-03:48:17,847 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 142
# 170817-03:48:17,989 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 143
# 170817-03:48:18,139 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 144
# 170817-03:48:18,282 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 145
# 170817-03:48:18,424 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 146
# 170817-03:48:18,565 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 147
# 170817-03:48:18,707 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 148
# 170817-03:48:18,845 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 149
# 170817-03:48:18,991 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 150
# 170817-03:48:19,123 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 151
# 170817-03:48:19,264 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 152
# 170817-03:48:19,402 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 153
# 170817-03:48:19,547 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 154
# 170817-03:48:19,694 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 155
# 170817-03:48:19,862 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 156
# 170817-03:48:20,3 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 157
# 170817-03:48:20,261 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 158
# 170817-03:48:20,397 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 159
# 170817-03:48:20,406 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 170817-03:48:20,408 workflow INFO:
# 	 Submitting: anatmask_xfm.a08 ID: 4
# 170817-03:48:20,600 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a08 ID: 4
# 170817-03:48:20,604 workflow INFO:
# 	 Submitting: anatmask_xfm.a16 ID: 11
# 170817-03:48:20,762 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a16 ID: 11
# 170817-03:48:20,766 workflow INFO:
# 	 Submitting: anatmask_xfm.a02 ID: 14
# 170817-03:48:20,921 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a02 ID: 14
# 170817-03:48:20,925 workflow INFO:
# 	 Submitting: anatmask_xfm.a07 ID: 16
# 170817-03:48:21,69 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a07 ID: 16
# 170817-03:48:21,73 workflow INFO:
# 	 Submitting: anatmask_xfm.a17 ID: 21
# 170817-03:48:21,215 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a17 ID: 21
# 170817-03:48:21,219 workflow INFO:
# 	 Submitting: anatmask_xfm.a01 ID: 26
# 170817-03:48:21,362 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a01 ID: 26
# 170817-03:48:21,365 workflow INFO:
# 	 Submitting: anatmask_xfm.a06 ID: 30
# 170817-03:48:21,512 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a06 ID: 30
# 170817-03:48:21,516 workflow INFO:
# 	 Submitting: anatmask_xfm.a00 ID: 34
# 170817-03:48:21,668 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a00 ID: 34
# 170817-03:48:21,672 workflow INFO:
# 	 Submitting: anatmask_xfm.a13 ID: 40
# 170817-03:48:21,835 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a13 ID: 40
# 170817-03:48:21,838 workflow INFO:
# 	 Submitting: anatmask_xfm.a10 ID: 42
# 170817-03:48:21,978 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a10 ID: 42
# 170817-03:48:21,981 workflow INFO:
# 	 Submitting: anatmask_xfm.a05 ID: 46
# 170817-03:48:22,107 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a05 ID: 46
# 170817-03:48:22,110 workflow INFO:
# 	 Submitting: anatmask_xfm.a12 ID: 52
# 170817-03:48:22,240 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a12 ID: 52
# 170817-03:48:22,243 workflow INFO:
# 	 Submitting: anatmask_xfm.a15 ID: 55
# 170817-03:48:22,368 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a15 ID: 55
# 170817-03:48:22,371 workflow INFO:
# 	 Submitting: anatmask_xfm.a14 ID: 59
# 170817-03:48:22,506 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a14 ID: 59
# 170817-03:48:22,509 workflow INFO:
# 	 Submitting: anatmask_xfm.a04 ID: 60
# 170817-03:48:22,646 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a04 ID: 60
# 170817-03:48:22,649 workflow INFO:
# 	 Submitting: anatmask_xfm.a09 ID: 63
# 170817-03:48:22,792 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a09 ID: 63
# 170817-03:48:22,795 workflow INFO:
# 	 Submitting: anatmask_xfm.a18 ID: 67
# 170817-03:48:22,924 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a18 ID: 67
# 170817-03:48:22,928 workflow INFO:
# 	 Submitting: anatmask_xfm.a11 ID: 71
# 170817-03:48:23,61 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a11 ID: 71
# 170817-03:48:23,64 workflow INFO:
# 	 Submitting: anatmask_xfm.a03 ID: 74
# 170817-03:48:23,235 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a03 ID: 74
# 170817-03:48:23,238 workflow INFO:
# 	 Submitting: anatmask_xfm.a19 ID: 78
# 170817-03:48:23,368 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a19 ID: 78
# 170817-03:49:23,539 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a08 jobid: 4
# 170817-03:49:23,693 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a16 jobid: 11
# 170817-03:49:23,854 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a02 jobid: 14
# 170817-03:49:24,15 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a07 jobid: 16
# 170817-03:49:24,175 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a17 jobid: 21
# 170817-03:49:24,346 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a01 jobid: 26
# 170817-03:49:24,506 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a06 jobid: 30
# 170817-03:49:24,668 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a00 jobid: 34
# 170817-03:49:24,822 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a13 jobid: 40
# 170817-03:49:24,978 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a10 jobid: 42
# 170817-03:49:25,130 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a05 jobid: 46
# 170817-03:49:25,291 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a12 jobid: 52
# 170817-03:49:25,446 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a15 jobid: 55
# 170817-03:49:25,602 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a14 jobid: 59
# 170817-03:49:25,744 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a04 jobid: 60
# 170817-03:49:25,893 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a09 jobid: 63
# 170817-03:49:26,38 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a18 jobid: 67
# 170817-03:49:26,190 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a11 jobid: 71
# 170817-03:49:26,331 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a03 jobid: 74
# 170817-03:49:26,475 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a19 jobid: 78
# 170817-03:49:26,486 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 170817-03:49:26,488 workflow INFO:
# 	 Submitting: sinker.a08 ID: 5
# 170817-03:49:26,710 workflow INFO:
# 	 Finished submitting: sinker.a08 ID: 5
# 170817-03:49:26,713 workflow INFO:
# 	 Submitting: sinker.a02 ID: 15
# 170817-03:49:26,913 workflow INFO:
# 	 Finished submitting: sinker.a02 ID: 15
# 170817-03:49:26,917 workflow INFO:
# 	 Submitting: sinker.a07 ID: 17
# 170817-03:49:27,126 workflow INFO:
# 	 Finished submitting: sinker.a07 ID: 17
# 170817-03:49:27,129 workflow INFO:
# 	 Submitting: sinker.a17 ID: 22
# 170817-03:49:27,332 workflow INFO:
# 	 Finished submitting: sinker.a17 ID: 22
# 170817-03:49:27,335 workflow INFO:
# 	 Submitting: sinker.a16 ID: 23
# 170817-03:49:27,532 workflow INFO:
# 	 Finished submitting: sinker.a16 ID: 23
# 170817-03:49:27,536 workflow INFO:
# 	 Submitting: sinker.a01 ID: 27
# 170817-03:49:27,739 workflow INFO:
# 	 Finished submitting: sinker.a01 ID: 27
# 170817-03:49:27,742 workflow INFO:
# 	 Submitting: sinker.a06 ID: 31
# 170817-03:49:27,943 workflow INFO:
# 	 Finished submitting: sinker.a06 ID: 31
# 170817-03:49:27,946 workflow INFO:
# 	 Submitting: sinker.a00 ID: 35
# 170817-03:49:28,133 workflow INFO:
# 	 Finished submitting: sinker.a00 ID: 35
# 170817-03:49:28,136 workflow INFO:
# 	 Submitting: sinker.a13 ID: 41
# 170817-03:49:28,328 workflow INFO:
# 	 Finished submitting: sinker.a13 ID: 41
# 170817-03:49:28,332 workflow INFO:
# 	 Submitting: sinker.a10 ID: 43
# 170817-03:49:28,534 workflow INFO:
# 	 Finished submitting: sinker.a10 ID: 43
# 170817-03:49:28,537 workflow INFO:
# 	 Submitting: sinker.a05 ID: 47
# 170817-03:49:28,740 workflow INFO:
# 	 Finished submitting: sinker.a05 ID: 47
# 170817-03:49:28,744 workflow INFO:
# 	 Submitting: sinker.a12 ID: 53
# 170817-03:49:28,946 workflow INFO:
# 	 Finished submitting: sinker.a12 ID: 53
# 170817-03:49:28,949 workflow INFO:
# 	 Submitting: sinker.a15 ID: 56
# 170817-03:49:29,131 workflow INFO:
# 	 Finished submitting: sinker.a15 ID: 56
# 170817-03:49:29,135 workflow INFO:
# 	 Submitting: sinker.a04 ID: 61
# 170817-03:49:29,340 workflow INFO:
# 	 Finished submitting: sinker.a04 ID: 61
# 170817-03:49:29,343 workflow INFO:
# 	 Submitting: sinker.a09 ID: 64
# 170817-03:49:29,552 workflow INFO:
# 	 Finished submitting: sinker.a09 ID: 64
# 170817-03:49:29,555 workflow INFO:
# 	 Submitting: sinker.a14 ID: 65
# 170817-03:49:29,758 workflow INFO:
# 	 Finished submitting: sinker.a14 ID: 65
# 170817-03:49:29,761 workflow INFO:
# 	 Submitting: sinker.a18 ID: 68
# 170817-03:49:29,965 workflow INFO:
# 	 Finished submitting: sinker.a18 ID: 68
# 170817-03:49:29,969 workflow INFO:
# 	 Submitting: sinker.a11 ID: 72
# 170817-03:49:30,309 workflow INFO:
# 	 Finished submitting: sinker.a11 ID: 72
# 170817-03:49:30,312 workflow INFO:
# 	 Submitting: sinker.a03 ID: 75
# 170817-03:49:30,516 workflow INFO:
# 	 Finished submitting: sinker.a03 ID: 75
# 170817-03:49:30,520 workflow INFO:
# 	 Submitting: sinker.a19 ID: 79
# 170817-03:49:30,724 workflow INFO:
# 	 Finished submitting: sinker.a19 ID: 79
# 170817-03:50:30,914 workflow INFO:
# 	 [Job finished] jobname: sinker.a08 jobid: 5
# 170817-03:50:31,57 workflow INFO:
# 	 [Job finished] jobname: sinker.a02 jobid: 15
# 170817-03:50:31,197 workflow INFO:
# 	 [Job finished] jobname: sinker.a07 jobid: 17
# 170817-03:50:31,335 workflow INFO:
# 	 [Job finished] jobname: sinker.a17 jobid: 22
# 170817-03:50:31,472 workflow INFO:
# 	 [Job finished] jobname: sinker.a16 jobid: 23
# 170817-03:50:31,612 workflow INFO:
# 	 [Job finished] jobname: sinker.a01 jobid: 27
# 170817-03:50:31,836 workflow INFO:
# 	 [Job finished] jobname: sinker.a00 jobid: 35
# 170817-03:50:31,973 workflow INFO:
# 	 [Job finished] jobname: sinker.a13 jobid: 41
# 170817-03:50:32,474 workflow INFO:
# 	 [Job finished] jobname: sinker.a04 jobid: 61
# 170817-03:50:32,605 workflow INFO:
# 	 [Job finished] jobname: sinker.a09 jobid: 64
# 170817-03:51:33,323 workflow INFO:
# 	 [Job finished] jobname: sinker.a06 jobid: 31
# 170817-03:51:33,460 workflow INFO:
# 	 [Job finished] jobname: sinker.a10 jobid: 43
# 170817-03:51:33,597 workflow INFO:
# 	 [Job finished] jobname: sinker.a05 jobid: 47
# 170817-03:51:33,734 workflow INFO:
# 	 [Job finished] jobname: sinker.a12 jobid: 53
# 170817-03:51:33,872 workflow INFO:
# 	 [Job finished] jobname: sinker.a15 jobid: 56
# 170817-03:51:34,14 workflow INFO:
# 	 [Job finished] jobname: sinker.a14 jobid: 65
# 170817-03:51:34,149 workflow INFO:
# 	 [Job finished] jobname: sinker.a18 jobid: 68
# 170817-03:51:34,286 workflow INFO:
# 	 [Job finished] jobname: sinker.a11 jobid: 72
# 170817-03:51:34,425 workflow INFO:
# 	 [Job finished] jobname: sinker.a03 jobid: 75
# 170817-03:51:34,560 workflow INFO:
# 	 [Job finished] jobname: sinker.a19 jobid: 79

# %% [markdown]
# ### Use Glob to grab all newly created anatomy masks and 2nd lvl cope files

# %%
from glob import glob

sids = ['WMAZE_001', 'WMAZE_002', 'WMAZE_004', 'WMAZE_005', 'WMAZE_006', 
        'WMAZE_007', 'WMAZE_008', 'WMAZE_009', 'WMAZE_010', 'WMAZE_017', 
        'WMAZE_018', 'WMAZE_019', 'WMAZE_020', 'WMAZE_021', 'WMAZE_022', 
        'WMAZE_023', 'WMAZE_024', 'WMAZE_026', 'WMAZE_027']

proj_dir = '/home/data/madlab/data/mri/wmaze'
 
mask_filenames = []
cope_files = []

for SID in sids:
    mask_filenames_glob = glob(proj_dir + '/roi_analysis/MRthesis/fb4c/mask/anat_masks/_subject_id_' + SID + '/_anatmask_xfm*/*')
    mask_filenames.append(mask_filenames_glob)

    subjcopes_glob = glob(proj_dir + '/scndlvl/wmaze_MRthesis/fixed_before_conditional/' + SID + '/fixedfx/cope_*')
    cope_files.append(subjcopes_glob)
    if len(cope_files[-1]) == 0:
        print(SID)
# Out:
# WMAZE_023

# %%
print(mask_filenames[0][0]) #Left hippocampus
print(mask_filenames[0][1]) #Right hippocampus

print(cope_files[0][0]) #corr_B_after_A
print(cope_files[0][1]) #incorr_B_after_A
print(cope_files[0][2]) #corr_B_after_C
print(cope_files[0][3]) #incorr_B_after_C
print(cope_files[0][4]) #AB_corr_minus_AB_incorr
print(cope_files[0][5]) #AB_incorr_minus_AC_corr
print(cope_files[0][6]) #CB_corr_minus_CB_incorr
print(cope_files[0][7]) #CB_incorr_minus_CB_corr
print(cope_files[0][8]) #all_corr_vs_all_incorr
print(cope_files[0][9]) #all_incorr_vs_all_corr
for i in cope_files:
    print(len(i))
subjcopes_glob = glob(proj_dir + '/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_012/fixedfx/cope_*')
print (proj_dir + '/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_012/fixedfx/ \n')
# Out:
# /home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c/mask/anat_masks/_subject_id_WMAZE_001/_anatmask_xfm0/lh-hippocampus_warped.nii.gz
# /home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c/mask/anat_masks/_subject_id_WMAZE_001/_anatmask_xfm1/rh-hippocampus_warped.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_corr_B_after_A.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_incorr_B_after_A.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_corr_B_after_C.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_incorr_B_after_C.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_AB_corr_minus_AB_incorr.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_AB_incorr_minus_AB_corr.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_CB_corr_minus_CB_incorr.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_CB_incorr_minus_CB_corr.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_all_corr_vs_all_incorr.nii.gz
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_001/fixedfx/cope_all_incorr_vs_all_corr.nii.gz
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/WMAZE_012/fixedfx/

# %% [markdown]
# ### Use binarized mask to obtain activation in left & right hemisphere for each region of interest

# %%
import nibabel as nb
import pandas as pd
import numpy as np


#Dictionary containing multiple arrays referenced by keywords
all_data = {'subjid':[],
            'lhhp_corr_B_after_A':[], 'rhhp_corr_B_after_A':[],
            'lhhp_incorr_B_after_A':[], 'rhhp_incorr_B_after_A':[],
            'lhhp_corr_B_after_C':[], 'rhhp_corr_B_after_C':[],
            'lhhp_incorr_B_after_C':[], 'rhhp_incorr_B_after_C':[],
            'lhhp_AB_corr_minus_AB_incorr':[], 'rhhp_AB_corr_minus_AB_incorr':[], 
            'lhhp_AB_incorr_minus_AB_corr':[], 'rhhp_AB_incorr_minus_AB_corr':[],
            'lhhp_CB_corr_minus_CB_incorr':[], 'rhhp_CB_corr_minus_CB_incorr':[], 
            'lhhp_CB_incorr_minus_CB_corr':[], 'rhhp_CB_incorr_minus_CB_corr':[],
            'lhhp_all_corr_vs_all_incorr':[], 'rhhp_all_corr_vs_all_incorr':[], 
            'lhhp_all_incorr_vs_all_corr':[], 'rhhp_all_incorr_vs_all_corr':[]}


# For each interation in the length of subject ids
for i in range(len(sids)):
    #Append the subject id
    all_data['subjid'].append(sids[i])
    #Load the left and right hippocampus mask files using Nibabel 
    lh_hp_img = nb.load(mask_filenames[i][0])
    rh_hp_img = nb.load(mask_filenames[i][1])

    
    #Load copes for individual trial types
    corr_B_after_A_img = nb.load(cope_files[i][0])
    incorr_B_after_A_img = nb.load(cope_files[i][1])
    corr_B_after_C_img = nb.load(cope_files[i][2])
    incorr_B_after_C_img = nb.load(cope_files[i][3])
    AB_corr_minus_AB_incorr_img = nb.load(cope_files[i][4])
    AB_incorr_minus_AB_corr_img = nb.load(cope_files[i][5])
    CB_corr_minus_CB_incorr_img = nb.load(cope_files[i][6])
    CB_incorr_minus_CB_corr_img = nb.load(cope_files[i][7])
    all_corr_vs_all_incorr_img = nb.load(cope_files[i][8])
    all_incorr_vs_all_corr_img = nb.load(cope_files[i][9])
    
    
    #Left Hippocampus
    # corr_B_after_A
    lh_hp_corr_B_after_A_data = corr_B_after_A_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_corr_B_after_A'].append(np.mean(lh_hp_corr_B_after_A_data))
    
    # incorr_B_after_A
    lh_hp_incorr_B_after_A_data = incorr_B_after_A_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_incorr_B_after_A'].append(np.mean(lh_hp_incorr_B_after_A_data))
    
    # corr_B_after_C
    lh_hp_corr_B_after_C_data = corr_B_after_C_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_corr_B_after_C'].append(np.mean(lh_hp_corr_B_after_C_data))
    
    # incorr_B_after_C
    lh_hp_incorr_B_after_C_data = incorr_B_after_C_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_incorr_B_after_C'].append(np.mean(lh_hp_incorr_B_after_C_data))
    
    # AB_corr_minus_AB_incorr
    lh_hp_AB_corr_minus_AB_incorr_data = AB_corr_minus_AB_incorr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_AB_corr_minus_AB_incorr'].append(np.mean(lh_hp_AB_corr_minus_AB_incorr_data)) 
    
    # AB_incorr_minus_AB_corr
    lh_hp_AB_incorr_minus_AB_corr_data = AB_incorr_minus_AB_corr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_AB_incorr_minus_AB_corr'].append(np.mean(lh_hp_AB_incorr_minus_AB_corr_data)) 
    
    # CB_corr_minus_CB_incorr
    lh_hp_CB_corr_minus_CB_incorr_data = CB_corr_minus_CB_incorr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_CB_corr_minus_CB_incorr'].append(np.mean(lh_hp_CB_corr_minus_CB_incorr_data)) 
    
    # CB_incorr_minus_CB_corr
    lh_hp_CB_incorr_minus_CB_corr_data = CB_incorr_minus_CB_corr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_CB_incorr_minus_CB_corr'].append(np.mean(lh_hp_CB_incorr_minus_CB_corr_data)) 
    
    # all_corr_vs_all_incorr
    lh_hp_all_corr_vs_all_incorr_data = all_corr_vs_all_incorr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_all_corr_vs_all_incorr'].append(np.mean(lh_hp_all_corr_vs_all_incorr_data)) 
    
    # all_incorr_vs_all_corr
    lh_hp_all_incorr_vs_all_corr_data = all_incorr_vs_all_corr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_all_incorr_vs_all_corr'].append(np.mean(lh_hp_all_incorr_vs_all_corr_data)) 
    
    
    #Right Hippocampus
    # corr_B_after_A
    rh_hp_corr_B_after_A_data = corr_B_after_A_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_corr_B_after_A'].append(np.mean(rh_hp_corr_B_after_A_data))
    
    # incorr_B_after_A
    rh_hp_incorr_B_after_A_data = incorr_B_after_A_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_incorr_B_after_A'].append(np.mean(rh_hp_incorr_B_after_A_data))
    
    # corr_B_after_C
    rh_hp_corr_B_after_C_data = corr_B_after_C_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_corr_B_after_C'].append(np.mean(rh_hp_corr_B_after_C_data))
    
    # incorr_B_after_C
    rh_hp_incorr_B_after_C_data = incorr_B_after_C_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_incorr_B_after_C'].append(np.mean(rh_hp_incorr_B_after_C_data))
    
    # AB_corr_minus_AB_incorr
    rh_hp_AB_corr_minus_AB_incorr_data = AB_corr_minus_AB_incorr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_AB_corr_minus_AB_incorr'].append(np.mean(rh_hp_AB_corr_minus_AB_incorr_data)) 
    
    # AB_incorr_minus_AB_corr
    rh_hp_AB_incorr_minus_AB_corr_data = AB_incorr_minus_AB_corr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_AB_incorr_minus_AB_corr'].append(np.mean(rh_hp_AB_incorr_minus_AB_corr_data)) 
    
    # CB_corr_minus_CB_incorr
    rh_hp_CB_corr_minus_CB_incorr_data = CB_corr_minus_CB_incorr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_CB_corr_minus_CB_incorr'].append(np.mean(rh_hp_CB_corr_minus_CB_incorr_data)) 
    
    # CB_incorr_minus_CB_corr
    rh_hp_CB_incorr_minus_CB_corr_data = CB_incorr_minus_CB_corr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_CB_incorr_minus_CB_corr'].append(np.mean(rh_hp_CB_incorr_minus_CB_corr_data)) 
    
    # all_corr_vs_all_incorr
    rh_hp_all_corr_vs_all_incorr_data = all_corr_vs_all_incorr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_all_corr_vs_all_incorr'].append(np.mean(rh_hp_all_corr_vs_all_incorr_data)) 
    
    # all_incorr_vs_all_corr
    rh_hp_all_incorr_vs_all_corr_data = all_incorr_vs_all_corr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_all_incorr_vs_all_corr'].append(np.mean(rh_hp_all_incorr_vs_all_corr_data)) 

    
all_data_df = pd.DataFrame(all_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c0a0697328ec> in <module>()
#      19
#      20 # For each interation in the length of subject ids
# ---> 21 for i in range(len(sids)):
#      22     #Append the subject id
#      23     all_data['subjid'].append(sids[i])
#
# NameError: name 'sids' is not defined

# %% [markdown]
# ### Combine the two hemispheres to create one regional average

# %%
#Hippocampus average for each trial type
all_data_df['hp_corr_B_after_A'] = (all_data_df['lhhp_corr_B_after_A'] + all_data_df['rhhp_corr_B_after_A'])/2.
all_data_df['hp_incorr_B_after_A'] = (all_data_df['lhhp_incorr_B_after_A'] + all_data_df['rhhp_incorr_B_after_A'])/2.
all_data_df['hp_corr_B_after_C'] = (all_data_df['lhhp_corr_B_after_C'] + all_data_df['rhhp_corr_B_after_C'])/2.
all_data_df['hp_incorr_B_after_C'] = (all_data_df['lhhp_incorr_B_after_C'] + all_data_df['rhhp_incorr_B_after_C'])/2.
all_data_df['hp_AB_corr_minus_AB_incorr'] = (all_data_df['lhhp_AB_corr_minus_AB_incorr'] + 
                                             all_data_df['rhhp_AB_corr_minus_AB_incorr'])/2.
all_data_df['hp_AB_incorr_minus_AB_corr'] = (all_data_df['lhhp_AB_incorr_minus_AB_corr'] + 
                                             all_data_df['rhhp_AB_incorr_minus_AB_corr'])/2.
all_data_df['hp_CB_corr_minus_CB_incorr'] = (all_data_df['lhhp_CB_corr_minus_CB_incorr'] + 
                                             all_data_df['rhhp_CB_corr_minus_CB_incorr'])/2.
all_data_df['hp_CB_incorr_minus_CB_corr'] = (all_data_df['lhhp_CB_incorr_minus_CB_corr'] + 
                                             all_data_df['rhhp_CB_incorr_minus_CB_corr'])/2.
all_data_df['hp_all_corr_vs_all_incorr'] = (all_data_df['lhhp_all_corr_vs_all_incorr'] + 
                                            all_data_df['rhhp_all_corr_vs_all_incorr'])/2.
all_data_df['hp_all_incorr_vs_all_corr'] = (all_data_df['lhhp_all_incorr_vs_all_corr'] + 
                                            all_data_df['rhhp_all_incorr_vs_all_corr'])/2.

# %% [markdown]
# ## Hippocampus Activation: Fixed Before Conditional Trials

# %%
from scipy import stats

print 'corr_B_after_A mean'
print all_data_df['hp_corr_B_after_A'].mean()
print 'incorr_B_after_A'
print all_data_df['hp_incorr_B_after_A'].mean()
print 'corr_B_after_C mean'
print all_data_df['hp_corr_B_after_C'].mean()
print 'incorr_B_after_C mean'
print all_data_df['hp_incorr_B_after_C'].mean()



print 'T-test: Hippocampus corr_B_after_A vs. incorr_B_after_A'
print stats.ttest_rel(all_data_df['hp_corr_B_after_A'], all_data_df['hp_incorr_B_after_A'])
print 'T-test: Hippocampus corr_B_after_C vs. incorr_B_after_C'
print stats.ttest_rel(all_data_df['hp_corr_B_after_C'], all_data_df['hp_incorr_B_after_C'])

print 'ANOVA: Hippocampus corr_B_after_A vs. incorr_B_after_A vs. corr_B_after_C vs. incorr_B_after_C'
print stats.f_oneway(all_data_df['hp_corr_B_after_A'], all_data_df['hp_incorr_B_after_A'],
                     all_data_df['hp_corr_B_after_C'], all_data_df['hp_incorr_B_after_C'])
# Out:
# corr_B_after_A mean
# -0.196748012456
# incorr_B_after_A
# -1.58083775757
# corr_B_after_C mean
# -0.194153900209
# incorr_B_after_C mean
# -1.67262555625
# T-test: Hippocampus corr_B_after_A vs. incorr_B_after_A
# Ttest_relResult(statistic=3.5130388563398625, pvalue=0.0024837584991411646)
# T-test: Hippocampus corr_B_after_C vs. incorr_B_after_C
# Ttest_relResult(statistic=3.6434921750086691, pvalue=0.0018583603663876577)
# ANOVA: Hippocampus corr_B_after_A vs. incorr_B_after_A vs. corr_B_after_C vs. incorr_B_after_C
# F_onewayResult(statistic=4.6819200600030033, pvalue=0.0048159467909553314)

# %%
import matplotlib.pyplot as plt

N = 4
conditions = ['A -> correct B', 'A -> incorrect B', 'C -> correct B', 'C -> incorrect B']
bar_colors = ['red', 'blue', 'green', 'orange']
hp_means_allsubjs = [all_data_df['hp_corr_B_after_A'].mean(), 
                     all_data_df['hp_incorr_B_after_A'].mean(), 
                     all_data_df['hp_corr_B_after_C'].mean(),
                     all_data_df['hp_incorr_B_after_C'].mean()]
hp_sem_allsubjs = [all_data_df['hp_corr_B_after_A'].std()/(np.sqrt(len(sids))), 
                   all_data_df['hp_incorr_B_after_A'].std()/(np.sqrt(len(sids))),
                   all_data_df['hp_corr_B_after_C'].std()/(np.sqrt(len(sids))),
                   all_data_df['hp_incorr_B_after_C'].std()/(np.sqrt(len(sids)))]

ind = np.arange(N)
width = 0.5

fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.bar(ind, hp_means_allsubjs, width, color = bar_colors, ecolor = 'black', 
       yerr = hp_sem_allsubjs, align = 'center', bottom = 0)
#ax.boxplot([all_data_df['hp_ACtrials'],all_data_df['hp_Btrials']], positions=[1,2])

ax.set_xticks(ind)
ax.set_xticklabels(conditions)
ax.set_ylabel("Arbitrary units")

plt.show()
