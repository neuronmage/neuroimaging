# %% [markdown]
# # Creation of the region-specific masks using Freesurfer's Binarize

# %% [markdown]
# ### Includes the BL modeled into the "all_remaining" regressor

# %% [markdown]
# ### Masks for hippocampus and caudate using FS aparc+aseg

# %%
import nipype.pipeline as pe
import nipype.interfaces.io as nio
import os
import nipype.interfaces.freesurfer as fs
from nipype import IdentityInterface


subjects_dir = '/home/data/madlab/surfaces/wmaze'
work_dir = '/scratch/madlab/wmaze/regions_workdir'
sink_dir = '/home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c_2/mask'

sids = ['WMAZE_001', 'WMAZE_002', 'WMAZE_004', 'WMAZE_005', 'WMAZE_006', 
        'WMAZE_007', 'WMAZE_008', 'WMAZE_009', 'WMAZE_010', 'WMAZE_012', 
        'WMAZE_017', 'WMAZE_018', 'WMAZE_019', 'WMAZE_020', 'WMAZE_021', 
        'WMAZE_022', 'WMAZE_023', 'WMAZE_024', 'WMAZE_026', 'WMAZE_027']

wf = pe.Workflow(name = 'wf')
wf.base_dir = work_dir

# Node: subject_iterable
subj_iterable = pe.Node(IdentityInterface(fields = ['subject_id'], 
                                          mandatory_inputs = True),
                        name = 'subj_iterable')
subj_iterable.iterables = ('subject_id', sids)

info = dict(ref_epi_file = [['subject_id']],
            bbreg_xfm = [['subject_id']],
            aparc_aseg = [['subject_id']])

# Node: Datagrabber
datasource = pe.Node(nio.DataGrabber(infields = ['subject_id'],
                                     outfields = info.keys()),
                     name = 'datasource')
datasource.inputs.base_directory = os.path.abspath('/home/data/madlab/')
datasource.inputs.field_template = dict(ref_epi_file = 'data/mri/wmaze/preproc/%s/ref/*.nii.gz',
                                        bbreg_xfm = 'data/mri/wmaze/preproc/%s/bbreg/_fs_register0/*.dat',
                                        aparc_aseg = 'surfaces/wmaze/%s/mri/aparc+aseg.mgz')
datasource.inputs.template = '*'
datasource.inputs.template_args = info
datasource.inputs.sort_filelist = True
datasource.inputs.ignore_exception = False
datasource.inputs.raise_on_empty = True
wf.connect(subj_iterable, 'subject_id', datasource, 'subject_id')

#### subj_iterable (subject_id) ----> datasource (subject_id)


# MapNode: Create binarized ROI masks
anat_mask = pe.MapNode(fs.Binarize(),
                       iterfield = ['match', 'binary_file'], 
                       name = 'anat_mask')
anat_mask.inputs.match = [[17],[53], #hippocampus
                          [12], [51]] #putamen
                          
anat_mask.inputs.binary_file = ['lh-hippocampus.nii.gz','rh-hippocampus.nii.gz',
                                'lh-putamen.nii.gz', 'rh-putamen.nii.gz']
wf.connect(datasource, 'aparc_aseg', anat_mask, 'in_file')

#### datasource (aparc_aseg) ----> anat_mask (in_file)


# MapNode: Transform the masks to 1st volume of 1st run (EPI space)
anatmask_xfm = pe.MapNode(fs.ApplyVolTransform(inverse = True,
                                               interp = 'nearest'),
                          iterfield = ['target_file'],
                          name = 'anatmask_xfm')
anatmask_xfm.inputs.subjects_dir = subjects_dir
wf.connect(datasource, 'ref_epi_file', anatmask_xfm, 'source_file')
wf.connect(datasource, 'bbreg_xfm', anatmask_xfm, 'reg_file')
wf.connect(anat_mask, 'binary_file', anatmask_xfm, 'target_file')

#### datasource (ref_epi_file) ----> anatmask_xfm (source_file)
#### datasource (bbreg_xfm) ----> anatmask_xfm (reg_file)
#### datasource (binary_file) ----> anatmask_xfm (target_file)


# Node: Datasink
sinker = pe.Node(nio.DataSink(infields = None),
                 name = "sinker")
sinker.inputs._outputs = {}
sinker.inputs.base_directory = sink_dir
sinker.inputs.ignore_exception = False
sinker.inputs.parameterization = True
sinker.inputs.remove_dest_dir = False
wf.connect(anatmask_xfm, 'transformed_file', sinker, 'anat_masks')

#### anatmask_xfm (transformed_file) ----> sinker (anat_masks)

wf.run(plugin = 'LSF', plugin_args = {'bsub_args': '-q PQ_madlab'})
# Out:
# 171020-22:09:00,874 workflow INFO:
# 	 ['check', 'execution', 'logging']
# 171020-22:09:01,342 workflow INFO:
# 	 Running in parallel.
# 171020-22:09:01,442 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 171020-22:09:01,449 workflow INFO:
# 	 Submitting: datasource.a06 ID: 0
# 171020-22:09:01,631 workflow INFO:
# 	 Finished submitting: datasource.a06 ID: 0
# 171020-22:09:01,637 workflow INFO:
# 	 Submitting: datasource.a14 ID: 1
# 171020-22:09:01,739 workflow INFO:
# 	 Finished submitting: datasource.a14 ID: 1
# 171020-22:09:01,745 workflow INFO:
# 	 Submitting: datasource.a11 ID: 3
# 171020-22:09:01,848 workflow INFO:
# 	 Finished submitting: datasource.a11 ID: 3
# 171020-22:09:01,855 workflow INFO:
# 	 Submitting: datasource.a00 ID: 5
# 171020-22:09:01,965 workflow INFO:
# 	 Finished submitting: datasource.a00 ID: 5
# 171020-22:09:01,971 workflow INFO:
# 	 Submitting: datasource.a10 ID: 9
# 171020-22:09:02,235 workflow INFO:
# 	 Finished submitting: datasource.a10 ID: 9
# 171020-22:09:02,242 workflow INFO:
# 	 Submitting: datasource.a13 ID: 10
# 171020-22:09:02,323 workflow INFO:
# 	 Finished submitting: datasource.a13 ID: 10
# 171020-22:09:02,329 workflow INFO:
# 	 Submitting: datasource.a12 ID: 15
# 171020-22:09:02,418 workflow INFO:
# 	 Finished submitting: datasource.a12 ID: 15
# 171020-22:09:02,423 workflow INFO:
# 	 Submitting: datasource.a15 ID: 16
# 171020-22:09:02,503 workflow INFO:
# 	 Finished submitting: datasource.a15 ID: 16
# 171020-22:09:02,510 workflow INFO:
# 	 Submitting: datasource.a19 ID: 19
# 171020-22:09:02,604 workflow INFO:
# 	 Finished submitting: datasource.a19 ID: 19
# 171020-22:09:02,612 workflow INFO:
# 	 Submitting: datasource.a05 ID: 20
# 171020-22:09:02,703 workflow INFO:
# 	 Finished submitting: datasource.a05 ID: 20
# 171020-22:09:02,710 workflow INFO:
# 	 Submitting: datasource.a16 ID: 24
# 171020-22:09:02,794 workflow INFO:
# 	 Finished submitting: datasource.a16 ID: 24
# 171020-22:09:02,801 workflow INFO:
# 	 Submitting: datasource.a04 ID: 26
# 171020-22:09:02,882 workflow INFO:
# 	 Finished submitting: datasource.a04 ID: 26
# 171020-22:09:02,889 workflow INFO:
# 	 Submitting: datasource.a09 ID: 30
# 171020-22:09:02,970 workflow INFO:
# 	 Finished submitting: datasource.a09 ID: 30
# 171020-22:09:02,977 workflow INFO:
# 	 Submitting: datasource.a18 ID: 31
# 171020-22:09:03,58 workflow INFO:
# 	 Finished submitting: datasource.a18 ID: 31
# 171020-22:09:03,65 workflow INFO:
# 	 Submitting: datasource.a17 ID: 41
# 171020-22:09:03,148 workflow INFO:
# 	 Finished submitting: datasource.a17 ID: 41
# 171020-22:09:03,155 workflow INFO:
# 	 Submitting: datasource.a03 ID: 42
# 171020-22:09:03,240 workflow INFO:
# 	 Finished submitting: datasource.a03 ID: 42
# 171020-22:09:03,248 workflow INFO:
# 	 Submitting: datasource.a08 ID: 48
# 171020-22:09:03,463 workflow INFO:
# 	 Finished submitting: datasource.a08 ID: 48
# 171020-22:09:03,468 workflow INFO:
# 	 Submitting: datasource.a02 ID: 57
# 171020-22:09:03,670 workflow INFO:
# 	 Finished submitting: datasource.a02 ID: 57
# 171020-22:09:03,679 workflow INFO:
# 	 Submitting: datasource.a07 ID: 62
# 171020-22:09:03,887 workflow INFO:
# 	 Finished submitting: datasource.a07 ID: 62
# 171020-22:09:03,892 workflow INFO:
# 	 Submitting: datasource.a01 ID: 76
# 171020-22:09:04,30 workflow INFO:
# 	 Finished submitting: datasource.a01 ID: 76
# 171020-22:10:04,603 workflow INFO:
# 	 [Job finished] jobname: datasource.a06 jobid: 0
# 171020-22:10:04,849 workflow INFO:
# 	 [Job finished] jobname: datasource.a14 jobid: 1
# 171020-22:10:04,960 workflow INFO:
# 	 [Job finished] jobname: datasource.a11 jobid: 3
# 171020-22:10:05,66 workflow INFO:
# 	 [Job finished] jobname: datasource.a00 jobid: 5
# 171020-22:10:05,170 workflow INFO:
# 	 [Job finished] jobname: datasource.a10 jobid: 9
# 171020-22:10:05,277 workflow INFO:
# 	 [Job finished] jobname: datasource.a13 jobid: 10
# 171020-22:10:05,380 workflow INFO:
# 	 [Job finished] jobname: datasource.a12 jobid: 15
# 171020-22:10:05,488 workflow INFO:
# 	 [Job finished] jobname: datasource.a15 jobid: 16
# 171020-22:10:05,600 workflow INFO:
# 	 [Job finished] jobname: datasource.a19 jobid: 19
# 171020-22:10:05,696 workflow INFO:
# 	 [Job finished] jobname: datasource.a05 jobid: 20
# 171020-22:10:05,795 workflow INFO:
# 	 [Job finished] jobname: datasource.a16 jobid: 24
# 171020-22:10:05,895 workflow INFO:
# 	 [Job finished] jobname: datasource.a04 jobid: 26
# 171020-22:10:06,27 workflow INFO:
# 	 [Job finished] jobname: datasource.a09 jobid: 30
# 171020-22:10:06,127 workflow INFO:
# 	 [Job finished] jobname: datasource.a18 jobid: 31
# 171020-22:10:06,233 workflow INFO:
# 	 [Job finished] jobname: datasource.a17 jobid: 41
# 171020-22:10:06,330 workflow INFO:
# 	 [Job finished] jobname: datasource.a03 jobid: 42
# 171020-22:10:06,430 workflow INFO:
# 	 [Job finished] jobname: datasource.a08 jobid: 48
# 171020-22:10:06,536 workflow INFO:
# 	 [Job finished] jobname: datasource.a02 jobid: 57
# 171020-22:10:06,647 workflow INFO:
# 	 [Job finished] jobname: datasource.a07 jobid: 62
# 171020-22:10:06,759 workflow INFO:
# 	 [Job finished] jobname: datasource.a01 jobid: 76
# 171020-22:10:06,768 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 171020-22:10:06,821 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a06
# 171020-22:10:06,930 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a11
# 171020-22:10:06,984 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a00
# 171020-22:10:07,37 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a14
# 171020-22:10:07,122 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a13
# 171020-22:10:07,195 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a10
# 171020-22:10:07,281 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a15
# 171020-22:10:07,339 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a05
# 171020-22:10:07,399 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a16
# 171020-22:10:07,462 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a04
# 171020-22:10:07,517 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a09
# 171020-22:10:07,575 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a12
# 171020-22:10:07,635 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a19
# 171020-22:10:07,706 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a03
# 171020-22:10:07,783 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a18
# 171020-22:10:07,811 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a08
# 171020-22:10:07,837 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a17
# 171020-22:10:07,865 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a02
# 171020-22:10:07,891 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a07
# 171020-22:10:07,915 workflow INFO:
# 	 Adding 4 jobs for mapnode anat_mask.a01
# 171020-22:10:07,937 workflow INFO:
# 	 Pending[0] Submitting[80] jobs Slots[inf]
# 171020-22:10:07,937 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 80
# 171020-22:10:08,1 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 80
# 171020-22:10:08,2 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 81
# 171020-22:10:08,59 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 81
# 171020-22:10:08,60 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 82
# 171020-22:10:08,136 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 82
# 171020-22:10:08,138 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 83
# 171020-22:10:08,265 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 83
# 171020-22:10:08,271 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 84
# 171020-22:10:08,591 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 84
# 171020-22:10:08,594 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 85
# 171020-22:10:08,921 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 85
# 171020-22:10:08,926 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 86
# 171020-22:10:09,137 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 86
# 171020-22:10:09,145 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 87
# 171020-22:10:09,239 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 87
# 171020-22:10:09,246 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 88
# 171020-22:10:09,507 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 88
# 171020-22:10:09,510 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 89
# 171020-22:10:09,710 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 89
# 171020-22:10:09,718 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 90
# 171020-22:10:09,828 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 90
# 171020-22:10:09,840 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 91
# 171020-22:10:09,970 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 91
# 171020-22:10:09,977 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 92
# 171020-22:10:10,70 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 92
# 171020-22:10:10,77 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 93
# 171020-22:10:10,170 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 93
# 171020-22:10:10,177 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 94
# 171020-22:10:10,282 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 94
# 171020-22:10:10,289 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 95
# 171020-22:10:10,409 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 95
# 171020-22:10:10,416 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 96
# 171020-22:10:10,523 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 96
# 171020-22:10:10,530 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 97
# 171020-22:10:10,630 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 97
# 171020-22:10:10,637 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 98
# 171020-22:10:11,26 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 98
# 171020-22:10:11,33 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 99
# 171020-22:10:11,124 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 99
# 171020-22:10:11,131 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 100
# 171020-22:10:11,307 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 100
# 171020-22:10:11,311 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 101
# 171020-22:10:11,655 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 101
# 171020-22:10:11,666 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 102
# 171020-22:10:11,772 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 102
# 171020-22:10:11,779 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 103
# 171020-22:10:11,873 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 103
# 171020-22:10:11,879 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 104
# 171020-22:10:11,974 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 104
# 171020-22:10:11,978 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 105
# 171020-22:10:12,84 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 105
# 171020-22:10:12,91 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 106
# 171020-22:10:12,187 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 106
# 171020-22:10:12,194 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 107
# 171020-22:10:12,287 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 107
# 171020-22:10:12,294 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 108
# 171020-22:10:12,402 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 108
# 171020-22:10:12,409 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 109
# 171020-22:10:12,513 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 109
# 171020-22:10:12,521 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 110
# 171020-22:10:12,624 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 110
# 171020-22:10:12,631 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 111
# 171020-22:10:12,730 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 111
# 171020-22:10:12,737 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 112
# 171020-22:10:12,838 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 112
# 171020-22:10:12,848 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 113
# 171020-22:10:12,948 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 113
# 171020-22:10:12,955 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 114
# 171020-22:10:13,59 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 114
# 171020-22:10:13,66 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 115
# 171020-22:10:13,174 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 115
# 171020-22:10:13,179 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 116
# 171020-22:10:13,288 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 116
# 171020-22:10:13,295 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 117
# 171020-22:10:13,392 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 117
# 171020-22:10:13,396 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 118
# 171020-22:10:13,507 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 118
# 171020-22:10:13,511 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 119
# 171020-22:10:13,644 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 119
# 171020-22:10:13,650 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 120
# 171020-22:10:13,783 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 120
# 171020-22:10:13,790 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 121
# 171020-22:10:13,906 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 121
# 171020-22:10:13,913 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 122
# 171020-22:10:14,67 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 122
# 171020-22:10:14,76 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 123
# 171020-22:10:14,210 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 123
# 171020-22:10:14,217 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 124
# 171020-22:10:14,341 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 124
# 171020-22:10:14,348 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 125
# 171020-22:10:14,469 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 125
# 171020-22:10:14,476 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 126
# 171020-22:10:14,634 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 126
# 171020-22:10:14,641 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 127
# 171020-22:10:14,797 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 127
# 171020-22:10:14,807 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 128
# 171020-22:10:14,927 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 128
# 171020-22:10:14,935 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 129
# 171020-22:10:15,79 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 129
# 171020-22:10:15,86 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 130
# 171020-22:10:15,249 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 130
# 171020-22:10:15,253 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 131
# 171020-22:10:15,431 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 131
# 171020-22:10:15,440 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 132
# 171020-22:10:15,545 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 132
# 171020-22:10:15,552 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 133
# 171020-22:10:15,677 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 133
# 171020-22:10:15,687 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 134
# 171020-22:10:16,3 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 134
# 171020-22:10:16,10 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 135
# 171020-22:10:16,234 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 135
# 171020-22:10:16,241 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 136
# 171020-22:10:16,345 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 136
# 171020-22:10:16,352 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 137
# 171020-22:10:16,465 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 137
# 171020-22:10:16,472 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 138
# 171020-22:10:16,577 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 138
# 171020-22:10:16,581 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 139
# 171020-22:10:16,722 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 139
# 171020-22:10:16,729 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 140
# 171020-22:10:16,833 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 140
# 171020-22:10:16,840 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 141
# 171020-22:10:16,954 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 141
# 171020-22:10:16,963 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 142
# 171020-22:10:17,245 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 142
# 171020-22:10:17,248 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 143
# 171020-22:10:17,615 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 143
# 171020-22:10:17,627 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 144
# 171020-22:10:17,988 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 144
# 171020-22:10:17,998 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 145
# 171020-22:10:18,415 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 145
# 171020-22:10:18,424 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 146
# 171020-22:10:18,797 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 146
# 171020-22:10:18,800 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 147
# 171020-22:10:19,118 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 147
# 171020-22:10:19,120 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 148
# 171020-22:10:19,431 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 148
# 171020-22:10:19,434 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 149
# 171020-22:10:19,729 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 149
# 171020-22:10:19,737 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 150
# 171020-22:10:19,885 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 150
# 171020-22:10:19,892 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 151
# 171020-22:10:19,978 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 151
# 171020-22:10:19,983 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 152
# 171020-22:10:20,221 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 152
# 171020-22:10:20,228 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 153
# 171020-22:10:20,347 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 153
# 171020-22:10:20,354 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 154
# 171020-22:10:20,441 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 154
# 171020-22:10:20,448 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 155
# 171020-22:10:20,537 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 155
# 171020-22:10:20,544 workflow INFO:
# 	 Submitting: _anat_mask0 ID: 156
# 171020-22:10:20,628 workflow INFO:
# 	 Finished submitting: _anat_mask0 ID: 156
# 171020-22:10:20,635 workflow INFO:
# 	 Submitting: _anat_mask1 ID: 157
# 171020-22:10:20,725 workflow INFO:
# 	 Finished submitting: _anat_mask1 ID: 157
# 171020-22:10:20,729 workflow INFO:
# 	 Submitting: _anat_mask2 ID: 158
# 171020-22:10:20,823 workflow INFO:
# 	 Finished submitting: _anat_mask2 ID: 158
# 171020-22:10:20,834 workflow INFO:
# 	 Submitting: _anat_mask3 ID: 159
# 171020-22:10:21,119 workflow INFO:
# 	 Finished submitting: _anat_mask3 ID: 159
# 171020-22:11:21,715 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 80
# 171020-22:11:21,917 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 81
# 171020-22:11:22,149 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 82
# 171020-22:11:22,315 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 83
# 171020-22:11:22,675 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 84
# 171020-22:11:22,978 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 85
# 171020-22:11:23,117 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 86
# 171020-22:11:23,255 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 87
# 171020-22:11:23,416 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 88
# 171020-22:11:23,555 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 89
# 171020-22:11:23,687 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 90
# 171020-22:11:23,823 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 91
# 171020-22:11:23,950 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 92
# 171020-22:11:24,109 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 93
# 171020-22:11:24,294 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 95
# 171020-22:11:24,411 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 96
# 171020-22:11:24,522 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 97
# 171020-22:11:24,628 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 98
# 171020-22:11:24,721 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 99
# 171020-22:11:24,823 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 100
# 171020-22:11:24,920 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 101
# 171020-22:11:25,16 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 102
# 171020-22:11:25,112 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 103
# 171020-22:11:25,215 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 104
# 171020-22:11:25,382 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 107
# 171020-22:11:25,516 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 109
# 171020-22:11:25,613 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 110
# 171020-22:11:25,695 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 111
# 171020-22:11:25,779 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 112
# 171020-22:11:25,866 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 113
# 171020-22:11:25,951 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 114
# 171020-22:11:26,57 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 115
# 171020-22:11:26,149 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 116
# 171020-22:11:26,689 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 130
# 171020-22:11:26,768 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 131
# 171020-22:11:26,849 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 132
# 171020-22:11:26,929 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 133
# 171020-22:11:27,2 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 134
# 171020-22:11:27,75 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 135
# 171020-22:11:27,237 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 137
# 171020-22:11:27,412 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 138
# 171020-22:11:27,600 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 139
# 171020-22:11:27,785 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 140
# 171020-22:11:27,980 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 141
# 171020-22:11:28,251 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 142
# 171020-22:11:28,858 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 143
# 171020-22:11:29,50 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 144
# 171020-22:11:29,228 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 145
# 171020-22:11:29,401 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 146
# 171020-22:11:29,570 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 147
# 171020-22:11:29,741 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 148
# 171020-22:11:29,895 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 149
# 171020-22:11:30,69 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 150
# 171020-22:11:30,216 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 151
# 171020-22:11:30,351 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 152
# 171020-22:11:30,772 workflow INFO:
# 	 Pending[25] Submitting[10] jobs Slots[inf]
# 171020-22:11:30,780 workflow INFO:
# 	 Submitting: anat_mask.a06 ID: 2
# 171020-22:11:30,917 workflow INFO:
# 	 Finished submitting: anat_mask.a06 ID: 2
# 171020-22:11:30,925 workflow INFO:
# 	 Submitting: anat_mask.a11 ID: 4
# 171020-22:11:31,65 workflow INFO:
# 	 Finished submitting: anat_mask.a11 ID: 4
# 171020-22:11:31,73 workflow INFO:
# 	 Submitting: anat_mask.a00 ID: 6
# 171020-22:11:31,205 workflow INFO:
# 	 Finished submitting: anat_mask.a00 ID: 6
# 171020-22:11:31,212 workflow INFO:
# 	 Submitting: anat_mask.a13 ID: 11
# 171020-22:11:31,324 workflow INFO:
# 	 Finished submitting: anat_mask.a13 ID: 11
# 171020-22:11:31,331 workflow INFO:
# 	 Submitting: anat_mask.a10 ID: 12
# 171020-22:11:31,441 workflow INFO:
# 	 Finished submitting: anat_mask.a10 ID: 12
# 171020-22:11:31,449 workflow INFO:
# 	 Submitting: anat_mask.a16 ID: 25
# 171020-22:11:31,558 workflow INFO:
# 	 Finished submitting: anat_mask.a16 ID: 25
# 171020-22:11:31,565 workflow INFO:
# 	 Submitting: anat_mask.a03 ID: 45
# 171020-22:11:31,673 workflow INFO:
# 	 Finished submitting: anat_mask.a03 ID: 45
# 171020-22:11:31,680 workflow INFO:
# 	 Submitting: anat_mask.a08 ID: 50
# 171020-22:11:31,771 workflow INFO:
# 	 Finished submitting: anat_mask.a08 ID: 50
# 171020-22:11:31,778 workflow INFO:
# 	 Submitting: anat_mask.a17 ID: 54
# 171020-22:11:31,893 workflow INFO:
# 	 Finished submitting: anat_mask.a17 ID: 54
# 171020-22:11:31,902 workflow INFO:
# 	 Submitting: anat_mask.a02 ID: 59
# 171020-22:11:32,5 workflow INFO:
# 	 Finished submitting: anat_mask.a02 ID: 59
# 171020-22:12:32,255 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 94
# 171020-22:12:32,527 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 105
# 171020-22:12:32,749 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 106
# 171020-22:12:32,949 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 108
# 171020-22:12:33,160 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 117
# 171020-22:12:33,332 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 118
# 171020-22:12:33,511 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 119
# 171020-22:12:33,677 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 120
# 171020-22:12:33,815 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 121
# 171020-22:12:33,945 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 122
# 171020-22:12:34,97 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 123
# 171020-22:12:34,236 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 124
# 171020-22:12:34,390 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 125
# 171020-22:12:34,514 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 126
# 171020-22:12:34,640 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 127
# 171020-22:12:34,762 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 128
# 171020-22:12:34,876 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 129
# 171020-22:12:34,992 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 136
# 171020-22:12:35,172 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 153
# 171020-22:12:35,320 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 154
# 171020-22:12:35,432 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 155
# 171020-22:12:35,552 workflow INFO:
# 	 [Job finished] jobname: _anat_mask0 jobid: 156
# 171020-22:12:35,738 workflow INFO:
# 	 [Job finished] jobname: _anat_mask1 jobid: 157
# 171020-22:12:35,847 workflow INFO:
# 	 [Job finished] jobname: _anat_mask2 jobid: 158
# 171020-22:12:35,956 workflow INFO:
# 	 [Job finished] jobname: _anat_mask3 jobid: 159
# 171020-22:12:36,89 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a06 jobid: 2
# 171020-22:12:36,360 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a11 jobid: 4
# 171020-22:12:36,487 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a00 jobid: 6
# 171020-22:12:36,613 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a13 jobid: 11
# 171020-22:12:36,736 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a10 jobid: 12
# 171020-22:12:36,860 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a16 jobid: 25
# 171020-22:12:36,989 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a03 jobid: 45
# 171020-22:12:37,122 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a08 jobid: 50
# 171020-22:12:37,241 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a17 jobid: 54
# 171020-22:12:37,361 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a02 jobid: 59
# 171020-22:12:37,371 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 171020-22:12:37,567 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a00
# 171020-22:12:38,97 workflow INFO:
# 	 Submitting: anat_mask.a14 ID: 8
# 171020-22:12:38,253 workflow INFO:
# 	 Finished submitting: anat_mask.a14 ID: 8
# 171020-22:12:38,565 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a10
# 171020-22:12:38,596 workflow INFO:
# 	 Submitting: anat_mask.a15 ID: 17
# 171020-22:12:38,867 workflow INFO:
# 	 Finished submitting: anat_mask.a15 ID: 17
# 171020-22:12:38,877 workflow INFO:
# 	 Submitting: anat_mask.a05 ID: 21
# 171020-22:12:39,144 workflow INFO:
# 	 Finished submitting: anat_mask.a05 ID: 21
# 171020-22:12:39,148 workflow INFO:
# 	 Submitting: anat_mask.a04 ID: 27
# 171020-22:12:39,283 workflow INFO:
# 	 Finished submitting: anat_mask.a04 ID: 27
# 171020-22:12:39,290 workflow INFO:
# 	 Submitting: anat_mask.a09 ID: 32
# 171020-22:12:39,409 workflow INFO:
# 	 Finished submitting: anat_mask.a09 ID: 32
# 171020-22:12:39,419 workflow INFO:
# 	 Submitting: anat_mask.a12 ID: 35
# 171020-22:12:39,538 workflow INFO:
# 	 Finished submitting: anat_mask.a12 ID: 35
# 171020-22:12:39,545 workflow INFO:
# 	 Submitting: anat_mask.a19 ID: 36
# 171020-22:12:39,669 workflow INFO:
# 	 Finished submitting: anat_mask.a19 ID: 36
# 171020-22:12:39,849 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a16
# 171020-22:12:39,994 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a13
# 171020-22:12:40,110 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a03
# 171020-22:12:40,121 workflow INFO:
# 	 Submitting: anat_mask.a18 ID: 49
# 171020-22:12:40,262 workflow INFO:
# 	 Finished submitting: anat_mask.a18 ID: 49
# 171020-22:12:40,402 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a08
# 171020-22:12:40,534 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a17
# 171020-22:12:40,683 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a02
# 171020-22:12:40,694 workflow INFO:
# 	 Submitting: anat_mask.a07 ID: 65
# 171020-22:12:40,977 workflow INFO:
# 	 Finished submitting: anat_mask.a07 ID: 65
# 171020-22:12:41,115 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a11
# 171020-22:12:41,259 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a06
# 171020-22:12:41,270 workflow INFO:
# 	 Submitting: anat_mask.a01 ID: 77
# 171020-22:12:41,392 workflow INFO:
# 	 Finished submitting: anat_mask.a01 ID: 77
# 171020-22:12:41,401 workflow INFO:
# 	 Pending[10] Submitting[40] jobs Slots[inf]
# 171020-22:12:41,402 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 160
# 171020-22:12:41,561 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 160
# 171020-22:12:41,568 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 161
# 171020-22:12:41,691 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 161
# 171020-22:12:41,697 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 162
# 171020-22:12:41,857 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 162
# 171020-22:12:41,865 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 163
# 171020-22:12:41,994 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 163
# 171020-22:12:42,4 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 164
# 171020-22:12:42,134 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 164
# 171020-22:12:42,141 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 165
# 171020-22:12:42,272 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 165
# 171020-22:12:42,279 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 166
# 171020-22:12:42,429 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 166
# 171020-22:12:42,433 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 167
# 171020-22:12:42,559 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 167
# 171020-22:12:42,564 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 168
# 171020-22:12:42,685 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 168
# 171020-22:12:42,692 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 169
# 171020-22:12:42,810 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 169
# 171020-22:12:42,816 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 170
# 171020-22:12:42,940 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 170
# 171020-22:12:42,948 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 171
# 171020-22:12:43,70 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 171
# 171020-22:12:43,79 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 172
# 171020-22:12:43,198 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 172
# 171020-22:12:43,205 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 173
# 171020-22:12:43,327 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 173
# 171020-22:12:43,334 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 174
# 171020-22:12:43,457 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 174
# 171020-22:12:43,464 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 175
# 171020-22:12:43,584 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 175
# 171020-22:12:43,592 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 176
# 171020-22:12:43,709 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 176
# 171020-22:12:43,716 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 177
# 171020-22:12:43,837 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 177
# 171020-22:12:43,845 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 178
# 171020-22:12:43,964 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 178
# 171020-22:12:43,972 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 179
# 171020-22:12:44,94 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 179
# 171020-22:12:44,101 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 180
# 171020-22:12:44,212 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 180
# 171020-22:12:44,221 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 181
# 171020-22:12:44,345 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 181
# 171020-22:12:44,354 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 182
# 171020-22:12:44,511 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 182
# 171020-22:12:44,518 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 183
# 171020-22:12:44,671 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 183
# 171020-22:12:44,679 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 184
# 171020-22:12:44,799 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 184
# 171020-22:12:44,806 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 185
# 171020-22:12:44,932 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 185
# 171020-22:12:44,939 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 186
# 171020-22:12:45,70 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 186
# 171020-22:12:45,77 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 187
# 171020-22:12:45,202 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 187
# 171020-22:12:45,210 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 188
# 171020-22:12:45,327 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 188
# 171020-22:12:45,334 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 189
# 171020-22:12:45,453 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 189
# 171020-22:12:45,460 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 190
# 171020-22:12:45,583 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 190
# 171020-22:12:45,588 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 191
# 171020-22:12:45,711 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 191
# 171020-22:12:45,718 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 192
# 171020-22:12:45,838 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 192
# 171020-22:12:45,845 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 193
# 171020-22:12:45,973 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 193
# 171020-22:12:45,980 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 194
# 171020-22:12:46,129 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 194
# 171020-22:12:46,134 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 195
# 171020-22:12:46,264 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 195
# 171020-22:12:46,271 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 196
# 171020-22:12:46,409 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 196
# 171020-22:12:46,416 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 197
# 171020-22:12:46,539 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 197
# 171020-22:12:46,546 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 198
# 171020-22:12:46,669 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 198
# 171020-22:12:46,677 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 199
# 171020-22:12:46,801 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 199
# 171020-22:13:47,178 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a14 jobid: 8
# 171020-22:13:47,476 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a15 jobid: 17
# 171020-22:13:47,745 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a05 jobid: 21
# 171020-22:13:47,984 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a04 jobid: 27
# 171020-22:13:48,215 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a09 jobid: 32
# 171020-22:13:48,444 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a12 jobid: 35
# 171020-22:13:48,644 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a19 jobid: 36
# 171020-22:13:48,835 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a18 jobid: 49
# 171020-22:13:49,3 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a07 jobid: 65
# 171020-22:13:49,169 workflow INFO:
# 	 [Job finished] jobname: anat_mask.a01 jobid: 77
# 171020-22:13:49,296 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 160
# 171020-22:13:49,414 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 161
# 171020-22:13:49,536 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 162
# 171020-22:13:49,696 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 163
# 171020-22:13:49,817 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 164
# 171020-22:13:49,986 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 165
# 171020-22:13:50,96 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 166
# 171020-22:13:50,206 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 167
# 171020-22:13:50,321 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 168
# 171020-22:13:50,472 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 169
# 171020-22:13:50,581 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 170
# 171020-22:13:50,708 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 171
# 171020-22:13:50,852 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 172
# 171020-22:13:50,962 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 173
# 171020-22:13:51,66 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 174
# 171020-22:13:51,173 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 175
# 171020-22:13:51,282 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 176
# 171020-22:13:51,382 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 177
# 171020-22:13:51,521 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 179
# 171020-22:13:51,628 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 180
# 171020-22:13:51,732 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 181
# 171020-22:13:51,828 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 182
# 171020-22:13:51,972 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 184
# 171020-22:13:52,85 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 185
# 171020-22:13:52,185 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 186
# 171020-22:13:52,290 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 187
# 171020-22:13:52,393 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 188
# 171020-22:13:52,488 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 189
# 171020-22:13:52,588 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 190
# 171020-22:13:52,691 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 191
# 171020-22:13:52,797 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 192
# 171020-22:13:52,934 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 194
# 171020-22:13:53,28 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 195
# 171020-22:13:53,133 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 196
# 171020-22:13:53,226 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 197
# 171020-22:13:53,326 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 198
# 171020-22:13:53,454 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 199
# 171020-22:13:53,463 workflow INFO:
# 	 Pending[3] Submitting[17] jobs Slots[inf]
# 171020-22:13:53,464 workflow INFO:
# 	 Submitting: anatmask_xfm.a00 ID: 7
# 171020-22:13:53,632 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a00 ID: 7
# 171020-22:13:53,637 workflow INFO:
# 	 Submitting: anatmask_xfm.a10 ID: 13
# 171020-22:13:53,769 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a10 ID: 13
# 171020-22:13:53,889 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a15
# 171020-22:13:54,18 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a05
# 171020-22:13:54,157 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a04
# 171020-22:13:54,299 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a09
# 171020-22:13:54,426 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a19
# 171020-22:13:54,438 workflow INFO:
# 	 Submitting: anatmask_xfm.a16 ID: 39
# 171020-22:13:54,572 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a16 ID: 39
# 171020-22:13:54,579 workflow INFO:
# 	 Submitting: anatmask_xfm.a13 ID: 43
# 171020-22:13:54,760 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a13 ID: 43
# 171020-22:13:54,915 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a12
# 171020-22:13:54,926 workflow INFO:
# 	 Submitting: anatmask_xfm.a17 ID: 55
# 171020-22:13:55,62 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a17 ID: 55
# 171020-22:13:55,69 workflow INFO:
# 	 Submitting: anatmask_xfm.a02 ID: 60
# 171020-22:13:55,201 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a02 ID: 60
# 171020-22:13:55,327 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a14
# 171020-22:13:55,452 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a07
# 171020-22:13:55,578 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a18
# 171020-22:13:55,589 workflow INFO:
# 	 Submitting: anatmask_xfm.a06 ID: 72
# 171020-22:13:55,717 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a06 ID: 72
# 171020-22:13:55,836 workflow INFO:
# 	 Adding 4 jobs for mapnode anatmask_xfm.a01
# 171020-22:13:55,853 workflow INFO:
# 	 Pending[10] Submitting[40] jobs Slots[inf]
# 171020-22:13:55,855 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 200
# 171020-22:13:56,14 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 200
# 171020-22:13:56,21 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 201
# 171020-22:13:56,159 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 201
# 171020-22:13:56,166 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 202
# 171020-22:13:56,297 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 202
# 171020-22:13:56,304 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 203
# 171020-22:13:56,439 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 203
# 171020-22:13:56,448 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 204
# 171020-22:13:56,578 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 204
# 171020-22:13:56,585 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 205
# 171020-22:13:56,736 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 205
# 171020-22:13:56,743 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 206
# 171020-22:13:56,877 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 206
# 171020-22:13:56,884 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 207
# 171020-22:13:57,14 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 207
# 171020-22:13:57,22 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 208
# 171020-22:13:57,157 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 208
# 171020-22:13:57,164 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 209
# 171020-22:13:57,293 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 209
# 171020-22:13:57,302 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 210
# 171020-22:13:57,428 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 210
# 171020-22:13:57,436 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 211
# 171020-22:13:57,588 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 211
# 171020-22:13:57,595 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 212
# 171020-22:13:57,725 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 212
# 171020-22:13:57,732 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 213
# 171020-22:13:57,862 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 213
# 171020-22:13:57,869 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 214
# 171020-22:13:58,121 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 214
# 171020-22:13:58,128 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 215
# 171020-22:13:58,472 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 215
# 171020-22:13:58,481 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 216
# 171020-22:13:58,935 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 216
# 171020-22:13:58,950 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 217
# 171020-22:13:59,242 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 217
# 171020-22:13:59,252 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 218
# 171020-22:13:59,385 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 218
# 171020-22:13:59,396 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 219
# 171020-22:13:59,547 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 219
# 171020-22:13:59,554 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 220
# 171020-22:13:59,696 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 220
# 171020-22:13:59,703 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 221
# 171020-22:13:59,841 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 221
# 171020-22:13:59,849 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 222
# 171020-22:13:59,994 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 222
# 171020-22:14:00,1 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 223
# 171020-22:14:00,151 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 223
# 171020-22:14:00,158 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 224
# 171020-22:14:00,300 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 224
# 171020-22:14:00,307 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 225
# 171020-22:14:00,445 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 225
# 171020-22:14:00,453 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 226
# 171020-22:14:00,591 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 226
# 171020-22:14:00,598 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 227
# 171020-22:14:00,754 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 227
# 171020-22:14:00,765 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 228
# 171020-22:14:00,901 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 228
# 171020-22:14:00,908 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 229
# 171020-22:14:01,59 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 229
# 171020-22:14:01,71 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 230
# 171020-22:14:01,201 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 230
# 171020-22:14:01,211 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 231
# 171020-22:14:01,343 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 231
# 171020-22:14:01,350 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 232
# 171020-22:14:01,495 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 232
# 171020-22:14:01,502 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 233
# 171020-22:14:01,636 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 233
# 171020-22:14:01,645 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 234
# 171020-22:14:01,781 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 234
# 171020-22:14:01,790 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 235
# 171020-22:14:01,927 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 235
# 171020-22:14:01,936 workflow INFO:
# 	 Submitting: _anatmask_xfm0 ID: 236
# 171020-22:14:02,71 workflow INFO:
# 	 Finished submitting: _anatmask_xfm0 ID: 236
# 171020-22:14:02,80 workflow INFO:
# 	 Submitting: _anatmask_xfm1 ID: 237
# 171020-22:14:02,216 workflow INFO:
# 	 Finished submitting: _anatmask_xfm1 ID: 237
# 171020-22:14:02,225 workflow INFO:
# 	 Submitting: _anatmask_xfm2 ID: 238
# 171020-22:14:02,364 workflow INFO:
# 	 Finished submitting: _anatmask_xfm2 ID: 238
# 171020-22:14:02,373 workflow INFO:
# 	 Submitting: _anatmask_xfm3 ID: 239
# 171020-22:14:02,510 workflow INFO:
# 	 Finished submitting: _anatmask_xfm3 ID: 239
# 171020-22:15:03,420 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 178
# 171020-22:15:04,369 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 183
# 171020-22:15:04,611 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 193
# 171020-22:15:04,886 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a00 jobid: 7
# 171020-22:15:05,240 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a10 jobid: 13
# 171020-22:15:05,484 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a16 jobid: 39
# 171020-22:15:05,728 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a13 jobid: 43
# 171020-22:15:05,939 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a17 jobid: 55
# 171020-22:15:06,138 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a02 jobid: 60
# 171020-22:15:06,310 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a06 jobid: 72
# 171020-22:15:06,459 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 200
# 171020-22:15:06,617 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 201
# 171020-22:15:06,738 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 202
# 171020-22:15:06,869 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 203
# 171020-22:15:06,991 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 204
# 171020-22:15:07,192 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 205
# 171020-22:15:07,307 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 206
# 171020-22:15:07,425 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 207
# 171020-22:15:07,552 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 208
# 171020-22:15:07,674 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 209
# 171020-22:15:07,780 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 210
# 171020-22:15:07,882 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 211
# 171020-22:15:07,984 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 212
# 171020-22:15:08,138 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 213
# 171020-22:15:08,248 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 214
# 171020-22:15:08,361 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 215
# 171020-22:15:08,497 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 216
# 171020-22:15:08,601 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 217
# 171020-22:15:08,704 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 218
# 171020-22:15:08,812 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 219
# 171020-22:15:08,922 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 220
# 171020-22:15:09,38 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 221
# 171020-22:15:09,155 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 222
# 171020-22:15:09,265 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 223
# 171020-22:15:09,376 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 224
# 171020-22:15:09,482 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 225
# 171020-22:15:09,599 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 226
# 171020-22:15:09,715 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 227
# 171020-22:15:09,840 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 228
# 171020-22:15:09,950 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 229
# 171020-22:15:10,60 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 230
# 171020-22:15:10,180 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 231
# 171020-22:15:10,300 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 232
# 171020-22:15:10,415 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 233
# 171020-22:15:10,526 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 234
# 171020-22:15:10,627 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 235
# 171020-22:15:10,739 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm0 jobid: 236
# 171020-22:15:10,852 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm1 jobid: 237
# 171020-22:15:10,961 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm2 jobid: 238
# 171020-22:15:11,86 workflow INFO:
# 	 [Job finished] jobname: _anatmask_xfm3 jobid: 239
# 171020-22:15:11,95 workflow INFO:
# 	 Pending[0] Submitting[20] jobs Slots[inf]
# 171020-22:15:11,97 workflow INFO:
# 	 Submitting: sinker.a10 ID: 14
# 171020-22:15:11,322 workflow INFO:
# 	 Finished submitting: sinker.a10 ID: 14
# 171020-22:15:11,329 workflow INFO:
# 	 Submitting: anatmask_xfm.a15 ID: 18
# 171020-22:15:11,473 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a15 ID: 18
# 171020-22:15:11,484 workflow INFO:
# 	 Submitting: anatmask_xfm.a05 ID: 22
# 171020-22:15:11,655 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a05 ID: 22
# 171020-22:15:11,662 workflow INFO:
# 	 Submitting: anatmask_xfm.a04 ID: 28
# 171020-22:15:11,805 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a04 ID: 28
# 171020-22:15:11,812 workflow INFO:
# 	 Submitting: anatmask_xfm.a09 ID: 33
# 171020-22:15:11,961 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a09 ID: 33
# 171020-22:15:11,968 workflow INFO:
# 	 Submitting: anatmask_xfm.a19 ID: 37
# 171020-22:15:12,110 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a19 ID: 37
# 171020-22:15:12,118 workflow INFO:
# 	 Submitting: sinker.a16 ID: 40
# 171020-22:15:12,301 workflow INFO:
# 	 Finished submitting: sinker.a16 ID: 40
# 171020-22:15:12,308 workflow INFO:
# 	 Submitting: sinker.a13 ID: 44
# 171020-22:15:12,489 workflow INFO:
# 	 Finished submitting: sinker.a13 ID: 44
# 171020-22:15:12,496 workflow INFO:
# 	 Submitting: anatmask_xfm.a03 ID: 46
# 171020-22:15:12,640 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a03 ID: 46
# 171020-22:15:12,647 workflow INFO:
# 	 Submitting: anatmask_xfm.a08 ID: 51
# 171020-22:15:12,790 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a08 ID: 51
# 171020-22:15:12,797 workflow INFO:
# 	 Submitting: anatmask_xfm.a12 ID: 53
# 171020-22:15:12,941 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a12 ID: 53
# 171020-22:15:12,949 workflow INFO:
# 	 Submitting: sinker.a17 ID: 56
# 171020-22:15:13,140 workflow INFO:
# 	 Finished submitting: sinker.a17 ID: 56
# 171020-22:15:13,147 workflow INFO:
# 	 Submitting: sinker.a00 ID: 58
# 171020-22:15:13,330 workflow INFO:
# 	 Finished submitting: sinker.a00 ID: 58
# 171020-22:15:13,337 workflow INFO:
# 	 Submitting: sinker.a02 ID: 61
# 171020-22:15:13,520 workflow INFO:
# 	 Finished submitting: sinker.a02 ID: 61
# 171020-22:15:13,527 workflow INFO:
# 	 Submitting: anatmask_xfm.a14 ID: 63
# 171020-22:15:13,660 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a14 ID: 63
# 171020-22:15:13,667 workflow INFO:
# 	 Submitting: anatmask_xfm.a07 ID: 66
# 171020-22:15:13,810 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a07 ID: 66
# 171020-22:15:13,817 workflow INFO:
# 	 Submitting: anatmask_xfm.a11 ID: 68
# 171020-22:15:13,960 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a11 ID: 68
# 171020-22:15:13,967 workflow INFO:
# 	 Submitting: anatmask_xfm.a18 ID: 70
# 171020-22:15:14,118 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a18 ID: 70
# 171020-22:15:14,122 workflow INFO:
# 	 Submitting: sinker.a06 ID: 74
# 171020-22:15:14,315 workflow INFO:
# 	 Finished submitting: sinker.a06 ID: 74
# 171020-22:15:14,322 workflow INFO:
# 	 Submitting: anatmask_xfm.a01 ID: 78
# 171020-22:15:14,467 workflow INFO:
# 	 Finished submitting: anatmask_xfm.a01 ID: 78
# 171020-22:16:14,767 workflow INFO:
# 	 [Job finished] jobname: sinker.a10 jobid: 14
# 171020-22:16:15,107 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a15 jobid: 18
# 171020-22:16:15,434 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a05 jobid: 22
# 171020-22:16:15,729 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a04 jobid: 28
# 171020-22:16:15,977 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a09 jobid: 33
# 171020-22:16:16,239 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a19 jobid: 37
# 171020-22:16:16,415 workflow INFO:
# 	 [Job finished] jobname: sinker.a16 jobid: 40
# 171020-22:16:16,586 workflow INFO:
# 	 [Job finished] jobname: sinker.a13 jobid: 44
# 171020-22:16:16,769 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a03 jobid: 46
# 171020-22:16:16,951 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a08 jobid: 51
# 171020-22:16:17,153 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a12 jobid: 53
# 171020-22:16:17,285 workflow INFO:
# 	 [Job finished] jobname: sinker.a17 jobid: 56
# 171020-22:16:17,439 workflow INFO:
# 	 [Job finished] jobname: sinker.a00 jobid: 58
# 171020-22:16:17,568 workflow INFO:
# 	 [Job finished] jobname: sinker.a02 jobid: 61
# 171020-22:16:17,720 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a14 jobid: 63
# 171020-22:16:17,861 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a07 jobid: 66
# 171020-22:16:18,5 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a11 jobid: 68
# 171020-22:16:18,147 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a18 jobid: 70
# 171020-22:16:18,258 workflow INFO:
# 	 [Job finished] jobname: sinker.a06 jobid: 74
# 171020-22:16:18,386 workflow INFO:
# 	 [Job finished] jobname: anatmask_xfm.a01 jobid: 78
# 171020-22:16:18,397 workflow INFO:
# 	 Pending[0] Submitting[13] jobs Slots[inf]
# 171020-22:16:18,399 workflow INFO:
# 	 Submitting: sinker.a05 ID: 23
# 171020-22:16:18,667 workflow INFO:
# 	 Finished submitting: sinker.a05 ID: 23
# 171020-22:16:18,675 workflow INFO:
# 	 Submitting: sinker.a04 ID: 29
# 171020-22:16:18,867 workflow INFO:
# 	 Finished submitting: sinker.a04 ID: 29
# 171020-22:16:18,875 workflow INFO:
# 	 Submitting: sinker.a09 ID: 34
# 171020-22:16:19,232 workflow INFO:
# 	 Finished submitting: sinker.a09 ID: 34
# 171020-22:16:19,240 workflow INFO:
# 	 Submitting: sinker.a15 ID: 38
# 171020-22:16:19,440 workflow INFO:
# 	 Finished submitting: sinker.a15 ID: 38
# 171020-22:16:19,447 workflow INFO:
# 	 Submitting: sinker.a03 ID: 47
# 171020-22:16:19,637 workflow INFO:
# 	 Finished submitting: sinker.a03 ID: 47
# 171020-22:16:19,649 workflow INFO:
# 	 Submitting: sinker.a08 ID: 52
# 171020-22:16:19,847 workflow INFO:
# 	 Finished submitting: sinker.a08 ID: 52
# 171020-22:16:19,854 workflow INFO:
# 	 Submitting: sinker.a14 ID: 64
# 171020-22:16:20,44 workflow INFO:
# 	 Finished submitting: sinker.a14 ID: 64
# 171020-22:16:20,51 workflow INFO:
# 	 Submitting: sinker.a07 ID: 67
# 171020-22:16:20,238 workflow INFO:
# 	 Finished submitting: sinker.a07 ID: 67
# 171020-22:16:20,245 workflow INFO:
# 	 Submitting: sinker.a11 ID: 69
# 171020-22:16:20,434 workflow INFO:
# 	 Finished submitting: sinker.a11 ID: 69
# 171020-22:16:20,442 workflow INFO:
# 	 Submitting: sinker.a18 ID: 71
# 171020-22:16:20,673 workflow INFO:
# 	 Finished submitting: sinker.a18 ID: 71
# 171020-22:16:20,681 workflow INFO:
# 	 Submitting: sinker.a12 ID: 73
# 171020-22:16:20,863 workflow INFO:
# 	 Finished submitting: sinker.a12 ID: 73
# 171020-22:16:20,871 workflow INFO:
# 	 Submitting: sinker.a19 ID: 75
# 171020-22:16:21,73 workflow INFO:
# 	 Finished submitting: sinker.a19 ID: 75
# 171020-22:16:21,80 workflow INFO:
# 	 Submitting: sinker.a01 ID: 79
# 171020-22:16:21,277 workflow INFO:
# 	 Finished submitting: sinker.a01 ID: 79
# 171020-22:17:21,676 workflow INFO:
# 	 [Job finished] jobname: sinker.a05 jobid: 23
# 171020-22:17:21,943 workflow INFO:
# 	 [Job finished] jobname: sinker.a04 jobid: 29
# 171020-22:17:22,183 workflow INFO:
# 	 [Job finished] jobname: sinker.a09 jobid: 34
# 171020-22:17:22,398 workflow INFO:
# 	 [Job finished] jobname: sinker.a15 jobid: 38
# 171020-22:17:22,595 workflow INFO:
# 	 [Job finished] jobname: sinker.a03 jobid: 47
# 171020-22:17:22,829 workflow INFO:
# 	 [Job finished] jobname: sinker.a08 jobid: 52
# 171020-22:17:23,4 workflow INFO:
# 	 [Job finished] jobname: sinker.a14 jobid: 64
# 171020-22:17:23,171 workflow INFO:
# 	 [Job finished] jobname: sinker.a07 jobid: 67
# 171020-22:17:23,330 workflow INFO:
# 	 [Job finished] jobname: sinker.a11 jobid: 69
# 171020-22:17:23,493 workflow INFO:
# 	 [Job finished] jobname: sinker.a18 jobid: 71
# 171020-22:17:23,658 workflow INFO:
# 	 [Job finished] jobname: sinker.a12 jobid: 73
# 171020-22:17:23,834 workflow INFO:
# 	 [Job finished] jobname: sinker.a19 jobid: 75
# 171020-22:17:23,979 workflow INFO:
# 	 [Job finished] jobname: sinker.a01 jobid: 79

# %% [markdown]
# ### Use Glob to grab all newly created anatomy masks and 2nd lvl cope files

# %%
from glob import glob

sids = ['WMAZE_001', 'WMAZE_002', 'WMAZE_004', 'WMAZE_005', 'WMAZE_006', 
        'WMAZE_007', 'WMAZE_008', 'WMAZE_009', 'WMAZE_010', 'WMAZE_012',  
        'WMAZE_017', 'WMAZE_018', 'WMAZE_019', 'WMAZE_020', 'WMAZE_021',  
        'WMAZE_022', 'WMAZE_023', 'WMAZE_024', 'WMAZE_026', 'WMAZE_027']

proj_dir = '/home/data/madlab/data/mri/wmaze'
 
mask_filenames = []
cope_files = []

for SID in sids:
    mask_filenames_glob = glob(proj_dir + '/roi_analysis/MRthesis/fb4c_2/mask/anat_masks/_subject_id_' + SID + '/_anatmask_xfm*/*')
    mask_filenames.append(mask_filenames_glob)

    subjcopes_glob = glob(proj_dir + '/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/' + SID + '/fixedfx/cope_*')
    cope_files.append(subjcopes_glob)
    if len(cope_files[-1]) == 0:
        print(SID)

# %% [markdown]
# ## Cell to double-check the array indexing

# %%
print 'left hippocampus'
print(mask_filenames[0][0]) #lh-hippocampus
print 'left caudate'
print(mask_filenames[0][1]) #lh-caudate
print 'right caudate'
print(mask_filenames[0][2]) #rh-caudate
print 'right hippocampus'
print(mask_filenames[0][3]) #rh-hippocamus
print 'left putamen'
print(mask_filenames[0][4]) #lh-putamen
print 'right putamen'
print(mask_filenames[0][5]) #rh-putamen

print '-----'

print 'A_before_B_corr'
print(cope_files[0][0]) #A_before_B_corr
print 'A_before_B_incorr'
print(cope_files[0][1]) #A_before_B_incorr
print 'C_before_B_corr'
print(cope_files[0][2]) #C_before_B_corr
print 'C_before_B_incorr'
print(cope_files[0][3]) #C_before_B_incorr
print 'all_A_and_C'
print(cope_files[0][4]) #all_A_and_C
print 'all_remaining'
print(cope_files[0][5]) #AB_corr_vs_AB_incorr
print 'AB_incorr_vs_AB_corr'
print(cope_files[0][6]) #AB_incorr_vs_AB_corr
print'CB_corr_vs_CB_incorr'
print(cope_files[0][7]) #CB_corr_vs_CB_incorr
print 'CB_incorr_vs_CB_corr'
print(cope_files[0][8]) #CB_incorr_vs_CB_corr
print 'AC_corr_vs_AC_incorr'
print(cope_files[0][9]) #AC_corr_vs_AC_incorr
print 'AC_incorr_vs_AC_corr'
print(cope_files[0][10]) #AC_incorr_vs_AC_corr


for i in cope_files:
    print(len(i))
# Out:
# left hippocampus
# /home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c_2/mask/anat_masks/_subject_id_WMAZE_001/_anatmask_xfm0/lh-hippocampus_warped.nii.gz
# left caudate
# /home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c_2/mask/anat_masks/_subject_id_WMAZE_001/_anatmask_xfm0/lh_caudate_anat_mask_warped.nii.gz
# right caudate
# /home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c_2/mask/anat_masks/_subject_id_WMAZE_001/_anatmask_xfm0/rh_caudate_anat_mask_warped.nii.gz
# right hippocampus
# /home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c_2/mask/anat_masks/_subject_id_WMAZE_001/_anatmask_xfm1/rh-hippocampus_warped.nii.gz
# left putamen
# /home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c_2/mask/anat_masks/_subject_id_WMAZE_001/_anatmask_xfm2/lh-putamen_warped.nii.gz
# right putamen
# /home/data/madlab/data/mri/wmaze/roi_analysis/MRthesis/fb4c_2/mask/anat_masks/_subject_id_WMAZE_001/_anatmask_xfm3/rh-putamen_warped.nii.gz
# -----
# A_before_B_corr
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_A_before_B_corr.nii.gz
# A_before_B_incorr
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_A_before_B_incorr.nii.gz
# C_before_B_corr
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_C_before_B_corr.nii.gz
# C_before_B_incorr
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_C_before_B_incorr.nii.gz
# all_A_and_C
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_all_A_and_C.nii.gz
# all_remaining
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_AB_corr_minus_AB_incorr.nii.gz
# AB_incorr_vs_AB_corr
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_AB_incorr_minus_AB_corr.nii.gz
# CB_corr_vs_CB_incorr
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_CB_corr_minus_CB_incorr.nii.gz
# CB_incorr_vs_CB_corr
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_CB_incorr_minus_CB_corr.nii.gz
# AC_corr_vs_AC_incorr
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_AC_corr_vs_AC_incorr.nii.gz
# AC_incorr_vs_AC_corr
# /home/data/madlab/data/mri/wmaze/scndlvl/wmaze_MRthesis/fixed_before_conditional/model1/WMAZE_001/fixedfx/cope_AC_incorr_vs_AC_corr.nii.gz
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11

# %% [markdown]
# ### Use binarized mask to obtain activation in left & right hemisphere for each region of interest

# %%
import nibabel as nb
import pandas as pd
import numpy as np


#Dictionary containing multiple arrays referenced by keywords
all_data = {'subjid':[],
            'lhhp_A_before_B_corr':[], 'rhhp_A_before_B_corr':[], 
            'lhhp_A_before_B_incorr':[], 'rhhp_A_before_B_incorr':[],
            'lhhp_C_before_B_corr':[], 'rhhp_C_before_B_corr':[], 
            'lhhp_C_before_B_incorr':[], 'rhhp_C_before_B_incorr':[],
            'lhhp_all_A_and_C':[], 'rhhp_all_A_and_C':[],
            'lhhp_AB_corr_vs_AB_incorr':[], 'rhhp_AB_corr_vs_AB_incorr':[], 
            'lhhp_AB_incorr_vs_AB_corr':[], 'rhhp_AB_incorr_vs_AB_corr':[],
            'lhhp_CB_corr_vs_CB_incorr':[], 'rhhp_CB_corr_vs_CB_incorr':[], 
            'lhhp_CB_incorr_vs_CB_corr':[], 'rhhp_CB_incorr_vs_CB_corr':[],
            'lhhp_AC_corr_vs_AC_incorr':[], 'rhhp_AC_corr_vs_AC_incorr':[], 
            'lhhp_AC_incorr_vs_AC_corr':[], 'rhhp_AC_incorr_vs_AC_corr':[],
            
            'lhcaudate_A_before_B_corr':[], 'rhcaudate_A_before_B_corr':[], 
            'lhcaudate_A_before_B_incorr':[], 'rhcaudate_A_before_B_incorr':[],
            'lhcaudate_C_before_B_corr':[], 'rhcaudate_C_before_B_corr':[], 
            'lhcaudate_C_before_B_incorr':[], 'rhcaudate_C_before_B_incorr':[],
            'lhcaudate_all_A_and_C':[], 'rhcaudate_all_A_and_C':[],
            'lhcaudate_AB_corr_vs_AB_incorr':[], 'rhcaudate_AB_corr_vs_AB_incorr':[], 
            'lhcaudate_AB_incorr_vs_AB_corr':[], 'rhcaudate_AB_incorr_vs_AB_corr':[],
            'lhcaudate_CB_corr_vs_CB_incorr':[], 'rhcaudate_CB_corr_vs_CB_incorr':[], 
            'lhcaudate_CB_incorr_vs_CB_corr':[], 'rhcaudate_CB_incorr_vs_CB_corr':[],
            'lhcaudate_AC_corr_vs_AC_incorr':[], 'rhcaudate_AC_corr_vs_AC_incorr':[], 
            'lhcaudate_AC_incorr_vs_AC_corr':[], 'rhcaudate_AC_incorr_vs_AC_corr':[],
            
            'lhputamen_A_before_B_corr':[], 'rhputamen_A_before_B_corr':[], 
            'lhputamen_A_before_B_incorr':[], 'rhputamen_A_before_B_incorr':[],
            'lhputamen_C_before_B_corr':[], 'rhputamen_C_before_B_corr':[], 
            'lhputamen_C_before_B_incorr':[], 'rhputamen_C_before_B_incorr':[],
            'lhputamen_all_A_and_C':[], 'rhputamen_all_A_and_C':[],
            'lhputamen_AB_corr_vs_AB_incorr':[], 'rhputamen_AB_corr_vs_AB_incorr':[], 
            'lhputamen_AB_incorr_vs_AB_corr':[], 'rhputamen_AB_incorr_vs_AB_corr':[],
            'lhputamen_CB_corr_vs_CB_incorr':[], 'rhputamen_CB_corr_vs_CB_incorr':[], 
            'lhputamen_CB_incorr_vs_CB_corr':[], 'rhputamen_CB_incorr_vs_CB_corr':[],
            'lhputamen_AC_corr_vs_AC_incorr':[], 'rhputamen_AC_corr_vs_AC_incorr':[], 
            'lhputamen_AC_incorr_vs_AC_corr':[], 'rhputamen_AC_incorr_vs_AC_corr':[]}


# For each interation in the length of subject ids
for i in range(len(sids)):
    #Append the subject id
    all_data['subjid'].append(sids[i])
    #Load the left and right hippocampus mask files using Nibabel 
    lh_hp_img = nb.load(mask_filenames[i][0])
    rh_hp_img = nb.load(mask_filenames[i][3])
    lh_caudate_img = nb.load(mask_filenames[i][1])
    rh_caudate_img = nb.load(mask_filenames[i][2])
    lh_putamen_img = nb.load(mask_filenames[i][4])
    rh_putamen_img = nb.load(mask_filenames[i][5])

    
    #Load copes for individual trial types
    A_before_B_corr_img = nb.load(cope_files[i][0])
    A_before_B_incorr_img = nb.load(cope_files[i][1])
    C_before_B_corr_img = nb.load(cope_files[i][2])
    C_before_B_incorr_img = nb.load(cope_files[i][3])
    all_A_and_C_img = nb.load(cope_files[i][4])
    AB_corr_vs_AB_incorr_img = nb.load(cope_files[i][5])
    AB_incorr_vs_AB_corr_img = nb.load(cope_files[i][6])
    CB_corr_vs_CB_incorr_img = nb.load(cope_files[i][7])
    CB_incorr_vs_CB_corr_img = nb.load(cope_files[i][8])
    AC_corr_vs_AC_incorr_img = nb.load(cope_files[i][9])
    AC_incorr_vs_AC_corr_img = nb.load(cope_files[i][10])
    
    
    ########################
    ### Left Hippocampus ###
    ########################
    
    # A_before_B_corr
    lh_hp_A_before_B_corr_data = A_before_B_corr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_A_before_B_corr'].append(np.mean(lh_hp_A_before_B_corr_data))
    
    # A_before_B_incorr
    lh_hp_A_before_B_incorr_data = A_before_B_incorr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_A_before_B_incorr'].append(np.mean(lh_hp_A_before_B_incorr_data))
    
    # C_before_B_corr
    lh_hp_C_before_B_corr_data = C_before_B_corr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_C_before_B_corr'].append(np.mean(lh_hp_C_before_B_corr_data))
    
    # C_before_B_incorr
    lh_hp_C_before_B_incorr_data = C_before_B_incorr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_C_before_B_incorr'].append(np.mean(lh_hp_C_before_B_incorr_data))
    
    # all_A_and_C
    lh_hp_all_A_and_C_data = all_A_and_C_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_all_A_and_C'].append(np.mean(lh_hp_all_A_and_C_data))    
       
    # AB_corr_vs_AB_incorr
    lh_hp_AB_corr_vs_AB_incorr_data = AB_corr_vs_AB_incorr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_AB_corr_vs_AB_incorr'].append(np.mean(lh_hp_AB_corr_vs_AB_incorr_data)) 
    
    # AB_incorr_vs_AB_corr
    lh_hp_AB_incorr_vs_AB_corr_data = AB_incorr_vs_AB_corr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_AB_incorr_vs_AB_corr'].append(np.mean(lh_hp_AB_incorr_vs_AB_corr_data)) 
    
    # CB_corr_vs_CB_incorr
    lh_hp_CB_corr_vs_CB_incorr_data = CB_corr_vs_CB_incorr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_CB_corr_vs_CB_incorr'].append(np.mean(lh_hp_CB_corr_vs_CB_incorr_data)) 
    
    # CB_incorr_vs_CB_corr
    lh_hp_CB_incorr_vs_CB_corr_data = CB_incorr_vs_CB_corr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_CB_incorr_vs_CB_corr'].append(np.mean(lh_hp_CB_incorr_vs_CB_corr_data)) 
    
    # AC_corr_vs_AC_incorr
    lh_hp_AC_corr_vs_AC_incorr_data = AC_corr_vs_AC_incorr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_AC_corr_vs_AC_incorr'].append(np.mean(lh_hp_AC_corr_vs_AC_incorr_data)) 
    
    # AC_incorr_vs_AC_corr
    lh_hp_AC_incorr_vs_AC_corr_data = AC_incorr_vs_AC_corr_img.get_data()[lh_hp_img.get_data() > 0.]
    all_data['lhhp_AC_incorr_vs_AC_corr'].append(np.mean(lh_hp_AC_incorr_vs_AC_corr_data)) 
    
    #########################
    ### Right Hippocampus ###
    #########################
    
    # A_before_B_corr
    rh_hp_A_before_B_corr_data = A_before_B_corr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_A_before_B_corr'].append(np.mean(rh_hp_A_before_B_corr_data))

    # A_before_B_incorr
    rh_hp_A_before_B_incorr_data = A_before_B_incorr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_A_before_B_incorr'].append(np.mean(rh_hp_A_before_B_incorr_data))

    # C_before_B_corr
    rh_hp_C_before_B_corr_data = C_before_B_corr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_C_before_B_corr'].append(np.mean(rh_hp_C_before_B_corr_data))

    # C_before_B_incorr
    rh_hp_C_before_B_incorr_data = C_before_B_incorr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_C_before_B_incorr'].append(np.mean(rh_hp_C_before_B_incorr_data))
    
    # all_A_and_C
    rh_hp_all_A_and_C_data = all_A_and_C_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_all_A_and_C'].append(np.mean(rh_hp_all_A_and_C_data))

    # AB_corr_vs_AB_incorr
    rh_hp_AB_corr_vs_AB_incorr_data = AB_corr_vs_AB_incorr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_AB_corr_vs_AB_incorr'].append(np.mean(rh_hp_AB_corr_vs_AB_incorr_data)) 

    # AB_incorr_vs_AB_corr
    rh_hp_AB_incorr_vs_AB_corr_data = AB_incorr_vs_AB_corr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_AB_incorr_vs_AB_corr'].append(np.mean(rh_hp_AB_incorr_vs_AB_corr_data)) 

    # CB_corr_vs_CB_incorr
    rh_hp_CB_corr_vs_CB_incorr_data = CB_corr_vs_CB_incorr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_CB_corr_vs_CB_incorr'].append(np.mean(rh_hp_CB_corr_vs_CB_incorr_data)) 

    # CB_incorr_vs_CB_corr
    rh_hp_CB_incorr_vs_CB_corr_data = CB_incorr_vs_CB_corr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_CB_incorr_vs_CB_corr'].append(np.mean(rh_hp_CB_incorr_vs_CB_corr_data)) 

    # AC_corr_vs_AC_incorr
    rh_hp_AC_corr_vs_AC_incorr_data = AC_corr_vs_AC_incorr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_AC_corr_vs_AC_incorr'].append(np.mean(rh_hp_AC_corr_vs_AC_incorr_data)) 

    # AC_incorr_vs_AC_corr
    rh_hp_AC_incorr_vs_AC_corr_data = AC_incorr_vs_AC_corr_img.get_data()[rh_hp_img.get_data() > 0.]
    all_data['rhhp_AC_incorr_vs_AC_corr'].append(np.mean(rh_hp_AC_incorr_vs_AC_corr_data))
    
    
    ####################
    ### Left Caudate ###
    ####################
    
    # A_before_B_corr
    lh_caudate_A_before_B_corr_data = A_before_B_corr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_A_before_B_corr'].append(np.mean(lh_caudate_A_before_B_corr_data))
    
    # A_before_B_incorr
    lh_caudate_A_before_B_incorr_data = A_before_B_incorr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_A_before_B_incorr'].append(np.mean(lh_caudate_A_before_B_incorr_data))
    
    # C_before_B_corr
    lh_caudate_C_before_B_corr_data = C_before_B_corr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_C_before_B_corr'].append(np.mean(lh_caudate_C_before_B_corr_data))
    
    # C_before_B_incorr
    lh_caudate_C_before_B_incorr_data = C_before_B_incorr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_C_before_B_incorr'].append(np.mean(lh_caudate_C_before_B_incorr_data))
    
    # all_A_and_C
    lh_caudate_all_A_and_C_data = all_A_and_C_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_all_A_and_C'].append(np.mean(lh_caudate_all_A_and_C_data))
       
    # AB_corr_vs_AB_incorr
    lh_caudate_AB_corr_vs_AB_incorr_data = AB_corr_vs_AB_incorr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_AB_corr_vs_AB_incorr'].append(np.mean(lh_caudate_AB_corr_vs_AB_incorr_data)) 
    
    # AB_incorr_vs_AB_corr
    lh_caudate_AB_incorr_vs_AB_corr_data = AB_incorr_vs_AB_corr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_AB_incorr_vs_AB_corr'].append(np.mean(lh_caudate_AB_incorr_vs_AB_corr_data)) 
    
    # CB_corr_vs_CB_incorr
    lh_caudate_CB_corr_vs_CB_incorr_data = CB_corr_vs_CB_incorr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_CB_corr_vs_CB_incorr'].append(np.mean(lh_caudate_CB_corr_vs_CB_incorr_data)) 
    
    # CB_incorr_vs_CB_corr
    lh_caudate_CB_incorr_vs_CB_corr_data = CB_incorr_vs_CB_corr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_CB_incorr_vs_CB_corr'].append(np.mean(lh_caudate_CB_incorr_vs_CB_corr_data)) 
    
    # AC_corr_vs_AC_incorr
    lh_caudate_AC_corr_vs_AC_incorr_data = AC_corr_vs_AC_incorr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_AC_corr_vs_AC_incorr'].append(np.mean(lh_caudate_AC_corr_vs_AC_incorr_data)) 
    
    # AC_incorr_vs_AC_corr
    lh_caudate_AC_incorr_vs_AC_corr_data = AC_incorr_vs_AC_corr_img.get_data()[lh_caudate_img.get_data() > 0.]
    all_data['lhcaudate_AC_incorr_vs_AC_corr'].append(np.mean(lh_caudate_AC_incorr_vs_AC_corr_data)) 
    
    
    #####################
    ### Right Caudate ###
    ##################### 
    
    # A_before_B_corr
    rh_caudate_A_before_B_corr_data = A_before_B_corr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_A_before_B_corr'].append(np.mean(rh_caudate_A_before_B_corr_data))

    # A_before_B_incorr
    rh_caudate_A_before_B_incorr_data = A_before_B_incorr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_A_before_B_incorr'].append(np.mean(rh_caudate_A_before_B_incorr_data))

    # C_before_B_corr
    rh_caudate_C_before_B_corr_data = C_before_B_corr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_C_before_B_corr'].append(np.mean(rh_caudate_C_before_B_corr_data))

    # C_before_B_incorr
    rh_caudate_C_before_B_incorr_data = C_before_B_incorr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_C_before_B_incorr'].append(np.mean(rh_caudate_C_before_B_incorr_data))
    
    # all_A_and_C
    rh_caudate_all_A_and_C_data = all_A_and_C_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_all_A_and_C'].append(np.mean(rh_caudate_all_A_and_C_data))

    # AB_corr_vs_AB_incorr
    rh_caudate_AB_corr_vs_AB_incorr_data = AB_corr_vs_AB_incorr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_AB_corr_vs_AB_incorr'].append(np.mean(rh_caudate_AB_corr_vs_AB_incorr_data)) 

    # AB_incorr_vs_AB_corr
    rh_caudate_AB_incorr_vs_AB_corr_data = AB_incorr_vs_AB_corr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_AB_incorr_vs_AB_corr'].append(np.mean(rh_caudate_AB_incorr_vs_AB_corr_data)) 

    # CB_corr_vs_CB_incorr
    rh_caudate_CB_corr_vs_CB_incorr_data = CB_corr_vs_CB_incorr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_CB_corr_vs_CB_incorr'].append(np.mean(rh_caudate_CB_corr_vs_CB_incorr_data)) 

    # CB_incorr_vs_CB_corr
    rh_caudate_CB_incorr_vs_CB_corr_data = CB_incorr_vs_CB_corr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_CB_incorr_vs_CB_corr'].append(np.mean(rh_caudate_CB_incorr_vs_CB_corr_data)) 

    # AC_corr_vs_AC_incorr
    rh_caudate_AC_corr_vs_AC_incorr_data = AC_corr_vs_AC_incorr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_AC_corr_vs_AC_incorr'].append(np.mean(rh_caudate_AC_corr_vs_AC_incorr_data)) 

    # AC_incorr_vs_AC_corr
    rh_caudate_AC_incorr_vs_AC_corr_data = AC_incorr_vs_AC_corr_img.get_data()[rh_caudate_img.get_data() > 0.]
    all_data['rhcaudate_AC_incorr_vs_AC_corr'].append(np.mean(rh_caudate_AC_incorr_vs_AC_corr_data)) 
    
    
    ####################
    ### Left Putamen ###
    ####################
    # A_before_B_corr
    lh_putamen_A_before_B_corr_data = A_before_B_corr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_A_before_B_corr'].append(np.mean(lh_putamen_A_before_B_corr_data))
    
    # A_before_B_incorr
    lh_putamen_A_before_B_incorr_data = A_before_B_incorr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_A_before_B_incorr'].append(np.mean(lh_putamen_A_before_B_incorr_data))
    
    # C_before_B_corr
    lh_putamen_C_before_B_corr_data = C_before_B_corr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_C_before_B_corr'].append(np.mean(lh_putamen_C_before_B_corr_data))
    
    # C_before_B_incorr
    lh_putamen_C_before_B_incorr_data = C_before_B_incorr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_C_before_B_incorr'].append(np.mean(lh_putamen_C_before_B_incorr_data))
    
    # all_A_and_C
    lh_putamen_all_A_and_C_data = all_A_and_C_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_all_A_and_C'].append(np.mean(lh_putamen_all_A_and_C_data))
       
    # AB_corr_vs_AB_incorr
    lh_putamen_AB_corr_vs_AB_incorr_data = AB_corr_vs_AB_incorr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_AB_corr_vs_AB_incorr'].append(np.mean(lh_putamen_AB_corr_vs_AB_incorr_data)) 
    
    # AB_incorr_vs_AB_corr
    lh_putamen_AB_incorr_vs_AB_corr_data = AB_incorr_vs_AB_corr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_AB_incorr_vs_AB_corr'].append(np.mean(lh_putamen_AB_incorr_vs_AB_corr_data)) 
    
    # CB_corr_vs_CB_incorr
    lh_putamen_CB_corr_vs_CB_incorr_data = CB_corr_vs_CB_incorr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_CB_corr_vs_CB_incorr'].append(np.mean(lh_putamen_CB_corr_vs_CB_incorr_data)) 
    
    # CB_incorr_vs_CB_corr
    lh_putamen_CB_incorr_vs_CB_corr_data = CB_incorr_vs_CB_corr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_CB_incorr_vs_CB_corr'].append(np.mean(lh_putamen_CB_incorr_vs_CB_corr_data)) 
    
    # AC_corr_vs_AC_incorr
    lh_putamen_AC_corr_vs_AC_incorr_data = AC_corr_vs_AC_incorr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_AC_corr_vs_AC_incorr'].append(np.mean(lh_putamen_AC_corr_vs_AC_incorr_data)) 
    
    # AC_incorr_vs_AC_corr
    lh_putamen_AC_incorr_vs_AC_corr_data = AC_incorr_vs_AC_corr_img.get_data()[lh_putamen_img.get_data() > 0.]
    all_data['lhputamen_AC_incorr_vs_AC_corr'].append(np.mean(lh_putamen_AC_incorr_vs_AC_corr_data)) 
    
    
    #####################
    ### Right Putamen ###
    #####################
    
    # A_before_B_corr
    rh_putamen_A_before_B_corr_data = A_before_B_corr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_A_before_B_corr'].append(np.mean(rh_putamen_A_before_B_corr_data))

    # A_before_B_incorr
    rh_putamen_A_before_B_incorr_data = A_before_B_incorr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_A_before_B_incorr'].append(np.mean(rh_putamen_A_before_B_incorr_data))

    # C_before_B_corr
    rh_putamen_C_before_B_corr_data = C_before_B_corr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_C_before_B_corr'].append(np.mean(rh_putamen_C_before_B_corr_data))

    # C_before_B_incorr
    rh_putamen_C_before_B_incorr_data = C_before_B_incorr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_C_before_B_incorr'].append(np.mean(rh_putamen_C_before_B_incorr_data))
    
    # all_A_and_C
    rh_putamen_all_A_and_C_data = all_A_and_C_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_all_A_and_C'].append(np.mean(rh_putamen_all_A_and_C_data))

    # AB_corr_vs_AB_incorr
    rh_putamen_AB_corr_vs_AB_incorr_data = AB_corr_vs_AB_incorr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_AB_corr_vs_AB_incorr'].append(np.mean(rh_putamen_AB_corr_vs_AB_incorr_data)) 

    # AB_incorr_vs_AB_corr
    rh_putamen_AB_incorr_vs_AB_corr_data = AB_incorr_vs_AB_corr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_AB_incorr_vs_AB_corr'].append(np.mean(rh_putamen_AB_incorr_vs_AB_corr_data)) 

    # CB_corr_vs_CB_incorr
    rh_putamen_CB_corr_vs_CB_incorr_data = CB_corr_vs_CB_incorr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_CB_corr_vs_CB_incorr'].append(np.mean(rh_putamen_CB_corr_vs_CB_incorr_data)) 

    # CB_incorr_vs_CB_corr
    rh_putamen_CB_incorr_vs_CB_corr_data = CB_incorr_vs_CB_corr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_CB_incorr_vs_CB_corr'].append(np.mean(rh_putamen_CB_incorr_vs_CB_corr_data)) 

    # AC_corr_vs_AC_incorr
    rh_putamen_AC_corr_vs_AC_incorr_data = AC_corr_vs_AC_incorr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_AC_corr_vs_AC_incorr'].append(np.mean(rh_putamen_AC_corr_vs_AC_incorr_data)) 

    # AC_incorr_vs_AC_corr
    rh_putamen_AC_incorr_vs_AC_corr_data = AC_incorr_vs_AC_corr_img.get_data()[rh_putamen_img.get_data() > 0.]
    all_data['rhputamen_AC_incorr_vs_AC_corr'].append(np.mean(rh_putamen_AC_incorr_vs_AC_corr_data)) 
    
    
all_data_df = pd.DataFrame(all_data)

# %% [markdown]
# ### Combine the two hemispheres to create one regional average

# %%
#Hippocampus average for each trial type
all_data_df['hp_A_before_B_corr'] = (all_data_df['lhhp_A_before_B_corr'] + 
                                     all_data_df['rhhp_A_before_B_corr'])/2.
all_data_df['hp_A_before_B_incorr'] = (all_data_df['lhhp_A_before_B_incorr'] + 
                                       all_data_df['rhhp_A_before_B_incorr'])/2.
all_data_df['hp_C_before_B_corr'] = (all_data_df['lhhp_C_before_B_corr'] + 
                                     all_data_df['rhhp_C_before_B_corr'])/2.
all_data_df['hp_C_before_B_incorr'] = (all_data_df['lhhp_C_before_B_incorr'] + 
                                       all_data_df['rhhp_C_before_B_incorr'])/2.
all_data_df['hp_all_A_and_C'] = (all_data_df['lhhp_all_A_and_C'] + 
                                 all_data_df['rhhp_all_A_and_C'])/2.
all_data_df['hp_AB_corr_vs_AB_incorr'] = (all_data_df['lhhp_AB_corr_vs_AB_incorr'] + 
                                             all_data_df['rhhp_AB_corr_vs_AB_incorr'])/2.
all_data_df['hp_AB_incorr_vs_AB_corr'] = (all_data_df['lhhp_AB_incorr_vs_AB_corr'] + 
                                             all_data_df['rhhp_AB_incorr_vs_AB_corr'])/2.
all_data_df['hp_CB_corr_vs_CB_incorr'] = (all_data_df['lhhp_CB_corr_vs_CB_incorr'] + 
                                             all_data_df['rhhp_CB_corr_vs_CB_incorr'])/2.
all_data_df['hp_CB_incorr_vs_CB_corr'] = (all_data_df['lhhp_CB_incorr_vs_CB_corr'] + 
                                             all_data_df['rhhp_CB_incorr_vs_CB_corr'])/2.
all_data_df['hp_AC_corr_vs_AC_incorr'] = (all_data_df['lhhp_AC_corr_vs_AC_incorr'] + 
                                             all_data_df['rhhp_AC_corr_vs_AC_incorr'])/2.
all_data_df['hp_AC_incorr_vs_AC_corr'] = (all_data_df['lhhp_AC_incorr_vs_AC_corr'] + 
                                             all_data_df['rhhp_AC_incorr_vs_AC_corr'])/2.

#Caudate average for each trial type
all_data_df['caudate_A_before_B_corr'] = (all_data_df['lhcaudate_A_before_B_corr'] + 
                                          all_data_df['rhcaudate_A_before_B_corr'])/2.
all_data_df['caudate_A_before_B_incorr'] = (all_data_df['lhcaudate_A_before_B_incorr'] + 
                                            all_data_df['rhcaudate_A_before_B_incorr'])/2.
all_data_df['caudate_C_before_B_corr'] = (all_data_df['lhcaudate_C_before_B_corr'] + 
                                          all_data_df['rhcaudate_C_before_B_corr'])/2.
all_data_df['caudate_C_before_B_incorr'] = (all_data_df['lhcaudate_C_before_B_incorr'] + 
                                            all_data_df['rhcaudate_C_before_B_incorr'])/2.
all_data_df['caudate_all_A_and_C'] = (all_data_df['lhcaudate_all_A_and_C'] + 
                                      all_data_df['rhcaudate_all_A_and_C'])/2.
all_data_df['caudate_AB_corr_vs_AB_incorr'] = (all_data_df['lhcaudate_AB_corr_vs_AB_incorr'] + 
                                                  all_data_df['rhcaudate_AB_corr_vs_AB_incorr'])/2.
all_data_df['caudate_AB_incorr_vs_AB_corr'] = (all_data_df['lhcaudate_AB_incorr_vs_AB_corr'] + 
                                                  all_data_df['rhcaudate_AB_incorr_vs_AB_corr'])/2.
all_data_df['caudate_CB_corr_vs_CB_incorr'] = (all_data_df['lhcaudate_CB_corr_vs_CB_incorr'] + 
                                                  all_data_df['rhcaudate_CB_corr_vs_CB_incorr'])/2.
all_data_df['caudate_CB_incorr_vs_CB_corr'] = (all_data_df['lhcaudate_CB_incorr_vs_CB_corr'] + 
                                                  all_data_df['rhcaudate_CB_incorr_vs_CB_corr'])/2.
all_data_df['caudate_AC_corr_vs_AC_incorr'] = (all_data_df['lhcaudate_AC_corr_vs_AC_incorr'] + 
                                                  all_data_df['rhcaudate_AC_corr_vs_AC_incorr'])/2.
all_data_df['caudate_AC_incorr_vs_AC_corr'] = (all_data_df['lhcaudate_AC_incorr_vs_AC_corr'] + 
                                                  all_data_df['rhcaudate_AC_incorr_vs_AC_corr'])/2.

#Putamen average for each trial type
all_data_df['putamen_A_before_B_corr'] = (all_data_df['lhputamen_A_before_B_corr'] + 
                                          all_data_df['rhputamen_A_before_B_corr'])/2.
all_data_df['putamen_A_before_B_incorr'] = (all_data_df['lhputamen_A_before_B_incorr'] + 
                                            all_data_df['rhputamen_A_before_B_incorr'])/2.
all_data_df['putamen_C_before_B_corr'] = (all_data_df['lhputamen_C_before_B_corr'] + 
                                          all_data_df['rhputamen_C_before_B_corr'])/2.
all_data_df['putamen_C_before_B_incorr'] = (all_data_df['lhputamen_C_before_B_incorr'] + 
                                            all_data_df['rhputamen_C_before_B_incorr'])/2.
all_data_df['putamen_all_A_and_C'] = (all_data_df['lhputamen_all_A_and_C'] + 
                                      all_data_df['rhputamen_all_A_and_C'])/2.
all_data_df['putamen_AB_corr_vs_AB_incorr'] = (all_data_df['lhputamen_AB_corr_vs_AB_incorr'] + 
                                                  all_data_df['rhputamen_AB_corr_vs_AB_incorr'])/2.
all_data_df['putamen_AB_incorr_vs_AB_corr'] = (all_data_df['lhputamen_AB_incorr_vs_AB_corr'] + 
                                                  all_data_df['rhputamen_AB_incorr_vs_AB_corr'])/2.
all_data_df['putamen_CB_corr_vs_CB_incorr'] = (all_data_df['lhputamen_CB_corr_vs_CB_incorr'] + 
                                                  all_data_df['rhputamen_CB_corr_vs_CB_incorr'])/2.
all_data_df['putamen_CB_incorr_vs_CB_corr'] = (all_data_df['lhputamen_CB_incorr_vs_CB_corr'] + 
                                                  all_data_df['rhputamen_CB_incorr_vs_CB_corr'])/2.
all_data_df['putamen_AC_corr_vs_AC_incorr'] = (all_data_df['lhputamen_AC_corr_vs_AC_incorr'] + 
                                                  all_data_df['rhputamen_AC_corr_vs_AC_incorr'])/2.
all_data_df['putamen_AC_incorr_vs_AC_corr'] = (all_data_df['lhputamen_AC_incorr_vs_AC_corr'] + 
                                                  all_data_df['rhputamen_AC_incorr_vs_AC_corr'])/2.

# %% [markdown]
# ## Hippocampus Activation: Fixed vs. Conditional Trials

# %%
from scipy import stats

print 'A_before_B_corr mean'
print all_data_df['hp_A_before_B_corr'].mean()
print 'A_before_B_incorr'
print all_data_df['hp_A_before_B_incorr'].mean()
print 'C_before_B_corr'
print all_data_df['hp_C_before_B_corr'].mean()
print 'C_before_B_incorr'
print all_data_df['hp_C_before_B_incorr'].mean()



print 'T-test: Hippocampus A_before_B_corr vs. A_before_B_incorr'
print stats.ttest_rel(all_data_df['hp_A_before_B_corr'], all_data_df['hp_A_before_B_incorr'])
print 'T-test: Hippocampus C_before_B_corr vs. C_before_B_incorr'
print stats.ttest_rel(all_data_df['hp_C_before_B_corr'], all_data_df['hp_C_before_B_incorr'])
# Out:
# A_before_B_corr mean
# -0.628393648285
# A_before_B_incorr
# -1.04232699107
# C_before_B_corr
# -0.714452012815
# C_before_B_incorr
# -1.13064365592
# T-test: Hippocampus A_before_B_corr vs. A_before_B_incorr
# Ttest_relResult(statistic=1.1561906547656648, pvalue=0.26193487621716993)
# T-test: Hippocampus C_before_B_corr vs. C_before_B_incorr
# Ttest_relResult(statistic=1.4255147394152399, pvalue=0.17023086101500653)

# %% [markdown]
# ### Hippocampus Activation: Fixed Before Correct vs. Incorrect Conditional Trials

# %%
import seaborn as sns
#sns.set_style("ticks")
sns.set_palette('muted')
import matplotlib.pyplot as plt

N = 4
conditions = ['A -> correct B', 'A -> incorrect B', 'C -> correct B', 'C -> incorrect B']
bar_colors = ['red', 'blue', 'green', 'orange']
hp_means_allsubjs = [all_data_df['hp_A_before_B_corr'].mean(), 
                     all_data_df['hp_A_before_B_incorr'].mean(), 
                     all_data_df['hp_C_before_B_corr'].mean(),
                     all_data_df['hp_C_before_B_incorr'].mean()]
hp_sem_allsubjs = [all_data_df['hp_A_before_B_corr'].std()/(np.sqrt(len(sids))), 
                   all_data_df['hp_A_before_B_incorr'].std()/(np.sqrt(len(sids))),
                   all_data_df['hp_C_before_B_corr'].std()/(np.sqrt(len(sids))),
                   all_data_df['hp_C_before_B_incorr'].std()/(np.sqrt(len(sids)))]

ind = np.arange(N)
width = 0.5

fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax = sns.barplot(ind, hp_means_allsubjs, yerr = hp_sem_allsubjs, ecolor = 'black')

ax.set_xticks(ind)
ax.set_xticklabels(conditions)
ax.set_ylabel("Arbitrary units")
ax.set_xlabel("Trial Type")
ax.set_title("Hippocampal Activation")

plt.show()

# %% [markdown]
# ### Caudate Stats

# %%
from scipy import stats

print 'A_before_B_corr'
print all_data_df['caudate_A_before_B_corr'].mean()
print 'A_before_B_incorr'
print all_data_df['caudate_A_before_B_incorr'].mean()
print 'C_before_B_corr'
print all_data_df['caudate_C_before_B_corr'].mean()
print 'C_before_B_incorr'
print all_data_df['caudate_C_before_B_incorr'].mean()



print 'T-test: Caudate A_before_B_corr vs. A_before_B_incorr'
print stats.ttest_rel(all_data_df['caudate_A_before_B_corr'], all_data_df['caudate_A_before_B_incorr'])
print 'T-test: Caudate C_before_B_corr vs. C_before_B_incorr'
print stats.ttest_rel(all_data_df['caudate_C_before_B_corr'], all_data_df['caudate_C_before_B_incorr'])
# Out:
# A_before_B_corr
# 1.16153410841
# A_before_B_incorr
# 1.07881282307
# C_before_B_corr
# 0.79675340103
# C_before_B_incorr
# 2.10180060279
# T-test: Caudate A_before_B_corr vs. A_before_B_incorr
# Ttest_relResult(statistic=0.22372000283081198, pvalue=0.82536310605174157)
# T-test: Caudate C_before_B_corr vs. C_before_B_incorr
# Ttest_relResult(statistic=-2.3643224511172756, pvalue=0.028864350812658954)

# %%
import seaborn as sns
#sns.set_style("ticks")
sns.set_palette('muted')
import matplotlib.pyplot as plt

N = 4
conditions = ['A -> correct B', 'A -> incorrect B', 'C -> correct B', 'C -> incorrect B']
bar_colors = ['red', 'blue', 'green', 'orange']
caudate_means_allsubjs = [all_data_df['caudate_A_before_B_corr'].mean(), 
                     all_data_df['caudate_A_before_B_incorr'].mean(), 
                     all_data_df['caudate_C_before_B_corr'].mean(),
                     all_data_df['caudate_C_before_B_incorr'].mean()]
caudate_sem_allsubjs = [all_data_df['caudate_A_before_B_corr'].std()/(np.sqrt(len(sids))), 
                   all_data_df['caudate_A_before_B_incorr'].std()/(np.sqrt(len(sids))),
                   all_data_df['caudate_C_before_B_corr'].std()/(np.sqrt(len(sids))),
                   all_data_df['caudate_C_before_B_incorr'].std()/(np.sqrt(len(sids)))]

ind = np.arange(N)
width = 0.5

fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax = sns.barplot(ind, caudate_means_allsubjs, yerr = caudate_sem_allsubjs, ecolor = 'black')

ax.set_xticks(ind)
ax.set_xticklabels(conditions)
ax.set_ylabel("Arbitrary units")
ax.set_xlabel("Trial Type")
ax.set_title("Caudate Activation")

plt.show()

# %% [markdown]
# ### Putamen Stats

# %%
from scipy import stats

print 'A_before_B_corr'
print all_data_df['putamen_A_before_B_corr'].mean()
print 'A_before_B_incorr'
print all_data_df['putamen_A_before_B_incorr'].mean()
print 'C_before_B_corr'
print all_data_df['putamen_C_before_B_corr'].mean()
print 'C_before_B_incorr'
print all_data_df['putamen_C_before_B_incorr'].mean()



print 'T-test: putamen A_before_B_corr vs. A_before_B_incorr'
print stats.ttest_rel(all_data_df['putamen_A_before_B_corr'], all_data_df['putamen_A_before_B_incorr'])
print 'T-test: putamen C_before_B_corr vs. C_before_B_incorr'
print stats.ttest_rel(all_data_df['putamen_C_before_B_corr'], all_data_df['putamen_C_before_B_incorr'])
# Out:
# A_before_B_corr
# 0.691734991875
# A_before_B_incorr
# -0.383968440443
# C_before_B_corr
# 0.536999601401
# C_before_B_incorr
# 0.415896315176
# T-test: putamen A_before_B_corr vs. A_before_B_incorr
# Ttest_relResult(statistic=3.2989429053451627, pvalue=0.0037743277678390151)
# T-test: putamen C_before_B_corr vs. C_before_B_incorr
# Ttest_relResult(statistic=0.33529584365386933, pvalue=0.74107567730708124)

# %%
import seaborn as sns
#sns.set_style("ticks")
sns.set_palette('muted')
import matplotlib.pyplot as plt

N = 4
conditions = ['A -> correct B', 'A -> incorrect B', 'C -> correct B', 'C -> incorrect B']
bar_colors = ['red', 'blue', 'green', 'orange']
putamen_means_allsubjs = [all_data_df['putamen_A_before_B_corr'].mean(), 
                     all_data_df['putamen_A_before_B_incorr'].mean(), 
                     all_data_df['putamen_C_before_B_corr'].mean(),
                     all_data_df['putamen_C_before_B_incorr'].mean()]
putamen_sem_allsubjs = [all_data_df['putamen_A_before_B_corr'].std()/(np.sqrt(len(sids))), 
                   all_data_df['putamen_A_before_B_incorr'].std()/(np.sqrt(len(sids))),
                   all_data_df['putamen_C_before_B_corr'].std()/(np.sqrt(len(sids))),
                   all_data_df['putamen_C_before_B_incorr'].std()/(np.sqrt(len(sids)))]

ind = np.arange(N)
width = 0.5

fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax = sns.barplot(ind, putamen_means_allsubjs, yerr = putamen_sem_allsubjs, ecolor = 'black')

ax.set_xticks(ind)
ax.set_xticklabels(conditions)
ax.set_ylabel("Arbitrary units")
ax.set_xlabel("Trial Type")
ax.set_title("Putamen Activation")

plt.show()

# %%
# %matplotlib inline
from os.path import join
import numpy as np
import pandas as pd
from glob import glob
from pylab import *
import matplotlib.pyplot as plt

subs = ['WMAZE_001', 'WMAZE_002', 'WMAZE_004', 'WMAZE_005', 'WMAZE_006', 'WMAZE_007',
        'WMAZE_008', 'WMAZE_009', 'WMAZE_010', 'WMAZE_012', 'WMAZE_017', 'WMAZE_018',
        'WMAZE_019', 'WMAZE_020', 'WMAZE_021', 'WMAZE_022', 'WMAZE_023', 'WMAZE_024',
        'WMAZE_026', 'WMAZE_027']


all_corr_B = []

for sub in subs:
    # Array containing path to behavior files
    sub_dir = '/home/data/madlab/data/mri/wmaze/scanner_behav/{0}/'.format(sub)
    # Array containing current sub's 6 behavior file runs
    dir_file = glob(join(sub_dir, '{0}_wmazebl_2015*.txt'.format(sub)))    
    # Sort current sub's txt files in order of run
    dir_file.sort() 
    
    
    data_run1 = pd.read_table(dir_file[0])
    data_run2 = pd.read_table(dir_file[1])
    data_run3 = pd.read_table(dir_file[2])
    data_run4 = pd.read_table(dir_file[3])
    data_run5 = pd.read_table(dir_file[4])
    data_run6 = pd.read_table(dir_file[5])
    
    all_runs = [data_run1, data_run2, data_run3, data_run4, data_run5, data_run6]
    
    data_set = pd.concat(all_runs)
     
    all_Bs = data_set.query('TrialType == "B"')
    corr_Bs = all_Bs['Correct']
    tot_corr_B = np.sum(corr_Bs)/240    
    
    
    all_corr_B.append(tot_corr_B)
    
#print all_corr_B
#print len(all_corr_B)

# %%
# Scatterplot

x = all_data_df['hp_all_A_and_C']
y = all_corr_B
print len(x)
print len(y)
fig, ax = plt.subplots()
fit = np.polyfit(x, y, deg = 1)
ax.plot(x, fit[0] * x + fit[1], color = 'red')
ax.scatter(x, y, c = 'blue', alpha = 0.5)
ax.set_xlabel('HPC - All A and C Trials')
ax.set_ylabel('Avg Performance on B Trials')
# Out:
# 20
# 20

# %%
import pandas as pd
corr_chart = {}
corr_chart['ac_hpc'] = all_data_df['hp_all_A_and_C']
corr_chart['b_per'] = all_corr_B
corr_chart_df = pd.DataFrame.from_dict(corr_chart)

# %%
corr_chart_df.corr()
# Out:
#           ac_hpc     b_per
# ac_hpc  1.000000  0.383486
# b_per   0.383486  1.000000

# %%
from scipy import stats

stats.pearsonr(all_data_df['hp_all_A_and_C'], all_corr_B)
# Out:
# (0.38348590768882573, 0.095098917407379704)
